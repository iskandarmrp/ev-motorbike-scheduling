# %%
battery_swap_station = [[85,60], [90,50]]

ev = {
    0: {'battery_now': 87, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'idle', 'energy_distance': [18, 10], 'travel_time': [18, 10], 'order_schedule': {}, 'swap_schedule': {}},
    1: {'battery_now': 100, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'active order', 'energy_distance': [12, 13], 'travel_time': [12, 13], 'order_schedule': {'latitude': -6, 'longitude': 106, 'duration': 10, 'energy_needed': 10}, 'swap_schedule': {'assigned': True, 'battery_now': 15, 'battery_station': 1, 'slot': 0, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 20, 'exchanged_battery': 10, 'received_battery': 20}},
    2: {'battery_now': 90, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'heading to BSS', 'energy_distance': [14, 20], 'travel_time': [14, 20], 'order_schedule': {}, 'swap_schedule': {'assigned': True, 'battery_now': 15, 'battery_station': 1, 'slot': 0, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 20, 'exchanged_battery': 10, 'received_battery': 20}},
    3: {'battery_now': 85, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'active order', 'energy_distance': [20, 24], 'travel_time': [20, 24], 'order_schedule': {'latitude': -6, 'longitude': 106, 'duration': 10, 'energy_needed': 10}, 'swap_schedule': {}},
    4: {'battery_now': 78, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'idle', 'energy_distance': [30, 27], 'travel_time': [30, 27], 'order_schedule': {}, 'swap_schedule': {}},
    5: {'battery_now': 60, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'idle', 'energy_distance': [33, 12], 'travel_time': [33, 12], 'order_schedule': {}, 'swap_schedule': {}},
    6: {'battery_now': 20, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'idle', 'energy_distance': [21, 30], 'travel_time': [21, 30], 'order_schedule': {}, 'swap_schedule': {}},
    7: {'battery_now': 24, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'idle', 'energy_distance': [14, 20], 'travel_time': [14, 20], 'order_schedule': {}, 'swap_schedule': {}},
    8: {'battery_now': 91, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'idle', 'energy_distance': [10, 30], 'travel_time': [10, 30], 'order_schedule': {}, 'swap_schedule': {}},
    9: {'battery_now': 35, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'idle', 'energy_distance': [11, 17], 'travel_time': [11, 17], 'order_schedule': {}, 'swap_schedule': {}},
}


# [87, 100, 90, 85, 78, 60, 20, 24, 91, 35]

# energy_distance = [
#     [18, 10],
#     [12, 13],
#     [14, 20],
#     [20, 24],
#     [30, 27],
#     [33, 12],
#     [21, 30],
#     [14, 20],
#     [10, 30],
#     [11, 17]
# ]

# travel_time = [
#     [18, 10],
#     [12, 13],
#     [14, 20],
#     [20, 24],
#     [30, 27],
#     [33, 12],
#     [21, 30],
#     [14, 20],
#     [10, 30],
#     [11, 17]
# ]

threshold = 15

# Stasiun, Slot, Durasi, Waiting Time
battery_swap_schedule = {
    0: {'assigned': True, 'battery_now': 15, 'battery_station': 1, 'slot': 0, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 20, 'exchanged_battery': 10, 'received_battery': 20},
    1: {'assigned': True, 'battery_now': 14, 'battery_station': 1, 'slot': 0, 'energy_distance': 20, 'travel_time': 12, 'waiting_time': 0, 'exchanged_battery': 10, 'received_battery': 20},
    2: {'assigned': False, 'battery_now': 80, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None},
    3: {'assigned': False, 'battery_now': 60, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None},
    4: {'assigned': False, 'battery_now': 55, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None},
    5: {'assigned': False, 'battery_now': 99, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None},
    6: {'assigned': True, 'battery_now': 12, 'battery_station': 0, 'slot': 1, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 0, 'exchanged_battery': 10, 'received_battery': 20},
    7: {'assigned': True, 'battery_now': 13, 'battery_station': 0, 'slot': 0, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 0, 'exchanged_battery': 10, 'received_battery': 20},
    8: {'assigned': False, 'battery_now': 87, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None},
    9: {'assigned': False, 'battery_now': 87, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None},
}

print(battery_swap_schedule)
# Out:
# {0: {'assigned': True, 'battery_now': 15, 'battery_station': 1, 'slot': 0, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 20, 'exchanged_battery': 10, 'received_battery': 20}, 1: {'assigned': True, 'battery_now': 14, 'battery_station': 1, 'slot': 0, 'energy_distance': 20, 'travel_time': 12, 'waiting_time': 0, 'exchanged_battery': 10, 'received_battery': 20}, 2: {'assigned': False, 'battery_now': 80, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None}, 3: {'assigned': False, 'battery_now': 60, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None}, 4: {'assigned': False, 'battery_now': 55, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None}, 5: {'assigned': False, 'battery_now': 99, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None}, 6: {'assigned': True, 'battery_now': 12, 'battery_station': 0, 'slot': 1, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 0, 'exchanged_battery': 10, 'received_battery': 20}, 7: {'assigned': True, 'battery_now': 13, 'battery_station': 0, 'slot': 0, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 0, 'exchanged_battery': 10, 'received_battery': 20}, 8: {'assigned': False, 'battery_now': 87, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None}, 9: {'assigned': False, 'battery_now': 87, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None}}

# %%
def evaluate(battery_swap_schedule):
    total_travel_time = 0
    total_waiting_time = 0
    battery_urgency_score = 0
    active_fleet_batery_score = 0
    total_battery_cycle = 0
    # for i in range(len(battery_swap_schedule)):
    #     if battery_swap_schedule[i]["assigned"]:
    #         total_travel_time += battery_swap_schedule[i]["travel_time"]
    #         total_waiting_time += battery_swap_schedule[i]["waiting_time"]
    #         battery_urgency_score += ((100 - battery_swap_schedule[i]["exchanged_battery"]) ** 2)
    #         active_fleet_batery_score += (battery_swap_schedule[i]["received_battery"] ** 2)
    #     else:
    #         active_fleet_batery_score += battery_swap_schedule[i]["battery_now"]
    for ev_id, sched in battery_swap_schedule.items():
        if sched and sched.get("assigned"):
            total_travel_time += sched["travel_time"]
            total_waiting_time += sched["waiting_time"]
            battery_urgency_score += ((100 - sched["exchanged_battery"]) ** 2)
            active_fleet_batery_score += (sched["received_battery"] ** 2)
            total_battery_cycle += sched["received_battery_cycle"]
        elif sched:
            active_fleet_batery_score += sched["battery_now"]
    if total_travel_time or total_waiting_time:
        total_score = (battery_urgency_score + active_fleet_batery_score) / ((total_travel_time + (10 * total_waiting_time))/60 + total_battery_cycle/8)
    else:
        total_score = battery_urgency_score + active_fleet_batery_score

    return total_score

# %%
# score = evaluate(battery_swap_schedule)
# print(score)

# %%
import copy
import random

# SOKIN: Setiap algo mau jalan, itung dulu semua travel time, waiting time, baterai sekarang, dll ulang (sesuai jam yang udah dilewatin, dan schedule nya juga)

def random_initialization(battery_swap_station, ev, threshold, charging_rate, required_battery_threshold=80):
    solution = {}
    station_batteries = copy.deepcopy(battery_swap_station)
    slot_timeline = {}

    # Kumpulkan semua swap_schedule yang ada ke dalam list dulu
    scheduled_swaps = []

    for i, data in ev.items():
        if data['swap_schedule']:
            swap = copy.deepcopy(data['swap_schedule'])
            ready_time = swap['travel_time'] + swap['waiting_time']
            scheduled_swaps.append((i, swap, ready_time))

    # Urutkan berdasarkan arrival_time (yang datang lebih cepat duluan)
    scheduled_swaps.sort(key=lambda x: x[2])

    # Masukkan ke slot_timeline secara terurut
    for i, swap, ready_time in scheduled_swaps:
        solution[i] = swap
        key = (swap['battery_station'], swap['slot'])
        exchanged_battery = swap['exchanged_battery']
        if key not in slot_timeline:
            slot_timeline[key] = [(ready_time, exchanged_battery)]
        else:
            slot_timeline[key].append((ready_time, exchanged_battery))


    for i, data in ev.items():
        if data['swap_schedule']:
            # Nanti setiap algo jalan lagi itung dulu semua travel time dan waiting time, tar dikurangin
            continue

        energy_to_nearest = min(data['energy_distance'])
        if data['battery_now'] - energy_to_nearest > threshold:
            solution[i] = {'assigned': False, 'battery_now': data['battery_now'], 'battery_station': None,
                           'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None,
                           'exchanged_battery': None, 'received_battery': None}
            continue

        valid_slots = []
        for station_idx, (ed, tt) in enumerate(zip(data['energy_distance'], data['travel_time'])):
            if data['battery_now'] - ed < 0:
                continue
            for slot_idx, initial_battery in enumerate(battery_swap_station[station_idx]):
                key = (station_idx, slot_idx)
                if key not in slot_timeline:
                    time_to_80 = max(0, (required_battery_threshold - initial_battery) / charging_rate)
                    ready_time = time_to_80
                else:
                    last_ready_time, last_insert = slot_timeline[key][-1]
                    time_to_80 = max(0, (required_battery_threshold - last_insert) / charging_rate)
                    ready_time = last_ready_time + time_to_80
                valid_slots.append((ready_time, station_idx, slot_idx, ed, tt))

        if not valid_slots:
            solution[i] = {'assigned': False, 'battery_now': data['battery_now'], 'battery_station': None,
                           'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None,
                           'exchanged_battery': None, 'received_battery': None}
            continue

        ready_time, station_idx, slot_idx, energy_dist, travel_time = random.choice(valid_slots)
        key = (station_idx, slot_idx)
        exchanged_battery = data['battery_now'] - energy_dist

        if key not in slot_timeline:
            waiting_time = max(0, ready_time - travel_time)
            slot_timeline[key] = [(travel_time + waiting_time, exchanged_battery)]
            current_slot_battery = station_batteries[station_idx][slot_idx]
            received_battery = min(100, current_slot_battery + (travel_time + waiting_time) * charging_rate)
        else:
            waiting_time = max(0, ready_time - travel_time)
            last_ready_time, last_insert = copy.deepcopy(slot_timeline[key][-1])
            slot_timeline[key].append((travel_time + waiting_time, exchanged_battery))
            if ready_time < travel_time:
                 received_battery = min(100, 80 + (travel_time - ready_time) * charging_rate)
            else:
                received_battery = 80

        solution[i] = {
            'assigned': True,
            'battery_now': data['battery_now'],
            'battery_station': station_idx,
            'slot': slot_idx,
            'energy_distance': energy_dist,
            'travel_time': travel_time,
            'waiting_time': round(waiting_time, 2),
            'exchanged_battery': exchanged_battery,
            'received_battery': round(received_battery, 2)
        }

    return solution

# %%
import copy
import random

def queue_update(solution, ev, battery_swap_station, charging_rate, required_battery_threshold=80):
    slot_timeline = {}
    station_batteries = copy.deepcopy(battery_swap_station)

    swaps = []

    # 1. Masukkan jadwal tetap (dari ev['swap_schedule']) dulu ke slot_timeline
    # Kumpulkan semua jadwal tetap dari ev['swap_schedule']
    temp_queue = {}

    for ev_id, data in ev.items():
        sched = copy.deepcopy(data.get('swap_schedule'))
        if sched and sched.get('assigned'):
            key = (sched['battery_station'], sched['slot'])
            ready_time = sched['travel_time'] + sched['waiting_time']
            exchanged_battery = sched['exchanged_battery']
            exchanged_battery_cycle = sched['battery_cycle']

            if key not in temp_queue:
                temp_queue[key] = [(ready_time, exchanged_battery, exchanged_battery_cycle)]
            else:
                temp_queue[key].append((ready_time, exchanged_battery, exchanged_battery_cycle))

    # Urutkan setiap antrian berdasarkan arrival_time
    slot_timeline = {
        key: sorted(entries, key=lambda x: x[0])
        for key, entries in temp_queue.items()
    }

    # 2. Kumpulkan EV dari solusi yang assigned, tapi hanya yang tidak punya jadwal tetap
    for ev_id, sched in solution.items():
        if sched['assigned'] and not ev[ev_id]['swap_schedule']:
            arrival_time = sched['travel_time']
            key = (sched['battery_station'], sched['slot'])
            swaps.append((arrival_time, ev_id, key))

    # 3. Urutkan berdasarkan arrival_time (yang datang duluan diproses lebih dulu)
    swaps.sort()

    # 4. Proses masing-masing EV, hitung ulang waiting_time dan received_battery
    for _, ev_id, key in swaps:
        sched = solution[ev_id]
        station_idx, slot_idx = key

        if key not in slot_timeline:
            last_ready_time = 0
            last_insert = battery_swap_station[station_idx][slot_idx][0]
            last_insert_cycle = battery_swap_station[station_idx][slot_idx][1]
        else:
            last_ready_time, last_insert, last_insert_cycle = slot_timeline[key][-1]

        arrival_time = sched['travel_time']
        time_to_80 = max(0, (required_battery_threshold - last_insert) / charging_rate)
        ready_time = last_ready_time + time_to_80
        waiting_time = max(0, ready_time - arrival_time)

        exchanged_battery = sched['exchanged_battery']
        received_battery = min(100, last_insert + (arrival_time + waiting_time - last_ready_time) * charging_rate)
        exchanged_battery_cycle = sched['battery_cycle']
        received_battery_cycle = last_insert_cycle + (received_battery - last_insert) / 100

        # Update ke dalam solution
        solution[ev_id]['waiting_time'] = round(waiting_time, 2)
        solution[ev_id]['received_battery'] = round(received_battery, 2)
        solution[ev_id]['received_battery_cycle'] = round(received_battery_cycle, 2)

        # Tambahkan ke slot_timeline untuk update antrian selanjutnya
        if key not in slot_timeline:
            slot_timeline[key] = [(arrival_time + waiting_time, exchanged_battery, exchanged_battery_cycle)]
        else:
            slot_timeline[key].append((arrival_time + waiting_time, exchanged_battery, exchanged_battery_cycle))

    return solution



def random_initialization(battery_swap_station, ev, threshold, charging_rate, required_battery_threshold=80):
    solution = {}
    station_batteries = copy.deepcopy(battery_swap_station)

    # Inisialisasi semua EV yang punya schedule tetap
    for i, data in ev.items():
        if data['swap_schedule']:
            solution[i] = copy.deepcopy(data['swap_schedule'])

    # Ambil EV yang layak dijadwalkan
    candidates = []
    for i, data in ev.items():
        if data['swap_schedule']:
            continue
        energy_to_nearest = min(data['energy_distance'])
        if data['battery_now'] - energy_to_nearest < threshold:
            candidates.append(i)

    # Acak urutan EV
    random.shuffle(candidates)

    # Jadwalkan secara acak ke slot kosong
    slot_keys = [(i, j) for i in range(len(battery_swap_station)) for j in range(len(battery_swap_station[i]))]
    slot_usage = {k: [] for k in slot_keys}

    for i in candidates:
        data = ev[i]
        valid_options = []

        for station_idx, (ed, tt) in enumerate(zip(data['energy_distance'], data['travel_time'])):
            if data['battery_now'] - ed < 0:
                continue
            for slot_idx in range(len(battery_swap_station[station_idx])):
                valid_options.append((station_idx, slot_idx, ed, tt))

        if not valid_options:
            solution[i] = {
                'assigned': False,
                'battery_now': data['battery_now'],
                'battery_cycle': data['battery_cycle'],
                'battery_station': None,
                'slot': None,
                'energy_distance': None,
                'travel_time': None,
                'waiting_time': None,
                'exchanged_battery': None,
                'received_battery': None,
                'received_battery_cycle': None
            }
            continue

        # Pilih slot acak dari opsi valid
        station_idx, slot_idx, energy_dist, travel_time = random.choice(valid_options)
        key = (station_idx, slot_idx)
        exchanged_battery = data['battery_now'] - energy_dist

        solution[i] = {
            'assigned': True,
            'battery_now': data['battery_now'],
            'battery_cycle': data['battery_cycle'],
            'battery_station': station_idx,
            'slot': slot_idx,
            'energy_distance': energy_dist,
            'travel_time': travel_time,
            'waiting_time': 0,  # akan diupdate
            'exchanged_battery': exchanged_battery,
            'received_battery': 0,  # akan diupdate
            'received_battery_cycle': 0 # akan diupdate
        }

    # Update ulang waiting_time dan received_battery
    solution = queue_update(solution, ev, battery_swap_station, charging_rate, required_battery_threshold)
    return solution

# %%
battery_swap_station_demo = [
    [[60, 200], [50,100]],  # Station 0: Slot 0, Slot 1
    [[45,100], [55,150]]   # Station 1: Slot 0, Slot 1
]

ev_demo = {
    0: {'battery_now': 20, 'battery_cycle': 100, 'energy_distance': [10, 14], 'travel_time': [10, 14], 'swap_schedule': {}},
    1: {'battery_now': 25, 'battery_cycle': 100,'energy_distance': [12, 17], 'travel_time': [11, 16], 'swap_schedule': {}},
    2: {'battery_now': 87, 'battery_cycle': 100,'energy_distance': [35, 40], 'travel_time': [30, 35], 'swap_schedule': {}},
    3: {'battery_now': 38, 'battery_cycle': 100,'energy_distance': [15, 18], 'travel_time': [13, 17], 'swap_schedule': {}},
    4: {'battery_now': 35, 'battery_cycle': 100,'energy_distance': [14, 17], 'travel_time': [12, 17], 'swap_schedule': {
        'assigned': True, 'battery_now': 35, 'battery_cycle': 100, 'battery_station': 0, 'slot': 1,
        'energy_distance': 12, 'travel_time': 12, 'waiting_time': 5,
        'exchanged_battery': 23, 'received_battery': 85, 'received_battery_cycle': 100
    }},
    5: {'battery_now': 90, 'battery_cycle': 100, 'energy_distance': [40, 36], 'travel_time': [35, 31], 'swap_schedule': {}},
    6: {'battery_now': 33, 'battery_cycle': 100,'energy_distance': [13, 12], 'travel_time': [13, 12], 'swap_schedule': {}},
    7: {'battery_now': 19, 'battery_cycle': 100,'energy_distance': [15, 13], 'travel_time': [15, 13], 'swap_schedule': {
        'assigned': True, 'battery_now': 19, 'battery_cycle': 100,'battery_station': 1, 'slot': 1,
        'energy_distance': 13, 'travel_time': 13, 'waiting_time': 7,
        'exchanged_battery': 6, 'received_battery': 83, 'received_battery_cycle': 100
    }},
    8: {'battery_now': 60, 'battery_cycle': 100,'energy_distance': [16, 14], 'travel_time': [16, 14], 'swap_schedule': {}},
    9: {'battery_now': 50, 'battery_cycle': 100,'energy_distance': [11, 19], 'travel_time': [11, 19], 'swap_schedule': {}},
    10: {'battery_now': 28, 'battery_cycle': 100,'energy_distance': [13, 15], 'travel_time': [11, 14], 'swap_schedule': {}},
    11: {'battery_now': 24, 'battery_cycle': 100,'energy_distance': [12, 18], 'travel_time': [10, 16], 'swap_schedule': {}},
    12: {'battery_now': 45, 'battery_cycle': 100,'energy_distance': [20, 25], 'travel_time': [18, 22], 'swap_schedule': {}},
    13: {'battery_now': 42, 'battery_cycle': 100,'energy_distance': [19, 17], 'travel_time': [17, 15], 'swap_schedule': {}},
    14: {'battery_now': 31, 'battery_cycle': 100,'energy_distance': [12, 13], 'travel_time': [11, 12], 'swap_schedule': {}},
    15: {'battery_now': 36, 'battery_cycle': 100,'energy_distance': [15, 18], 'travel_time': [14, 17], 'swap_schedule': {}},
    16: {'battery_now': 65, 'battery_cycle': 100,'energy_distance': [25, 30], 'travel_time': [22, 27], 'swap_schedule': {}},
    17: {'battery_now': 58, 'battery_cycle': 100,'energy_distance': [20, 22], 'travel_time': [20, 22], 'swap_schedule': {}},
    18: {'battery_now': 49, 'battery_cycle': 100,'energy_distance': [16, 19], 'travel_time': [15, 18], 'swap_schedule': {}},
    19: {'battery_now': 22, 'battery_cycle': 100,'energy_distance': [11, 14], 'travel_time': [10, 13], 'swap_schedule': {}},
}




solution = random_initialization(battery_swap_station_demo, ev_demo, 15, 100 / 240)
print(solution)
print(evaluate(solution))
# Out:
# {4: {'assigned': True, 'battery_now': 35, 'battery_cycle': 100, 'battery_station': 0, 'slot': 1, 'energy_distance': 12, 'travel_time': 12, 'waiting_time': 5, 'exchanged_battery': 23, 'received_battery': 85, 'received_battery_cycle': 100}, 7: {'assigned': True, 'battery_now': 19, 'battery_cycle': 100, 'battery_station': 1, 'slot': 1, 'energy_distance': 13, 'travel_time': 13, 'waiting_time': 7, 'exchanged_battery': 6, 'received_battery': 83, 'received_battery_cycle': 100}, 1: {'assigned': True, 'battery_now': 25, 'battery_cycle': 100, 'battery_station': 1, 'slot': 0, 'energy_distance': 17, 'travel_time': 16, 'waiting_time': 418.4, 'exchanged_battery': 8, 'received_battery': 80.0, 'received_battery_cycle': 100.74}, 11: {'assigned': True, 'battery_now': 24, 'battery_cycle': 100, 'battery_station': 1, 'slot': 1, 'energy_distance': 18, 'travel_time': 16, 'waiting_time': 181.6, 'exchanged_battery': 6, 'received_battery': 80.0, 'received_battery_cycle': 100.74}, 19: {'assigned': True, 'battery_now': 22, 'battery_cycle': 100, 'battery_station': 1, 'slot': 0, 'energy_distance': 14, 'travel_time': 13, 'waiting_time': 71.0, 'exchanged_battery': 8, 'received_battery': 80.0, 'received_battery_cycle': 100.35}, 0: {'assigned': True, 'battery_now': 20, 'battery_cycle': 100, 'battery_station': 1, 'slot': 0, 'energy_distance': 14, 'travel_time': 14, 'waiting_time': 242.8, 'exchanged_battery': 6, 'received_battery': 80.0, 'received_battery_cycle': 100.72}}
# 385.5920785650515

# %%
import copy
import random
import math

def get_neighbor(solution, ev, battery_swap_station, charging_rate, threshold=15, required_battery_threshold=80):
    neighbor = copy.deepcopy(solution)

    # Ambil daftar EV yang assigned di solution tetapi tidak punya swap_schedule tetap di ev
    movable_ev_ids = [
        ev_id for ev_id in neighbor
        if neighbor[ev_id] and neighbor[ev_id].get("assigned") and not ev[ev_id].get("swap_schedule")
    ]

    if not movable_ev_ids:
        return neighbor  # Tidak ada yang bisa diubah

    # Pilih satu EV secara acak dari yang bisa diubah
    ev_id = random.choice(movable_ev_ids)
    data = ev[ev_id]

    # Cari opsi stasiun-slot valid untuk EV ini
    valid_options = []
    for station_idx, (ed, tt) in enumerate(zip(data['energy_distance'], data['travel_time'])):
        if data['battery_now'] - ed < 0:
            continue
        for slot_idx in range(len(battery_swap_station[station_idx])):
            valid_options.append((station_idx, slot_idx, ed, tt))

    if not valid_options:
        # Jika tidak ada opsi valid, set jadi unassigned
        neighbor[ev_id] = {
            'assigned': False,
            'battery_now': data['battery_now'],
            'battery_cycle': data['battery_cycle'],
            'battery_station': None,
            'slot': None,
            'energy_distance': None,
            'travel_time': None,
            'waiting_time': None,
            'exchanged_battery': None,
            'received_battery': None,
            'received_battery_cycle': None
        }
    else:
        # Acak salah satu pilihan valid
        station_idx, slot_idx, energy_dist, travel_time = random.choice(valid_options)
        exchanged_battery = data['battery_now'] - energy_dist
        neighbor[ev_id] = {
            'assigned': True,
            'battery_now': data['battery_now'],
            'battery_cycle': data['battery_cycle'],
            'battery_station': station_idx,
            'slot': slot_idx,
            'energy_distance': energy_dist,
            'travel_time': travel_time,
            'waiting_time': 0,  # akan diupdate
            'exchanged_battery': exchanged_battery,
            'received_battery': 0,  # akan diupdate
            'received_battery_cycle': 0 # akan diupdate
        }

    # Update ulang nilai waiting_time dan received_battery setelah perubahan
    neighbor = queue_update(neighbor, ev, battery_swap_station, charging_rate, required_battery_threshold)
    return neighbor


# def temperature_schedule(t, initial_temp, num_of_cycle):
#     """
#     Temperature schedule function that returns 0 when t reaches num_of_cycle.
    
#     Parameters:
#     - t: Current cycle/iteration
#     - initial_temp: Initial temperature
#     - num_of_cycle: Number of cycles after which temperature becomes 0
    
#     Returns:
#     - Temperature value
#     """
#     if t >= num_of_cycle:
#         return 0
    
#     # Linear cooling schedule that reaches 0 at num_of_cycle
#     return initial_temp * (1 - t / num_of_cycle)

def simulated_annealing_strategy(
    battery_swap_station,
    ev,
    threshold,
    charging_rate,
    initial_temp=100.0,
    alpha=0.95,
    T_min=0.001,
    max_iter=200
):
    current_ev = copy.deepcopy(ev)
    current_solution = random_initialization(battery_swap_station, current_ev, threshold, charging_rate)
    current_score = evaluate(current_solution)

    best_solution = copy.deepcopy(current_solution)
    best_score = current_score

    T = initial_temp
    for iteration in range(max_iter):
        if T < T_min:
            break

        new_solution = get_neighbor(current_solution, ev, battery_swap_station, charging_rate, threshold=15, required_battery_threshold=80)
        new_score = evaluate(new_solution)
        delta = new_score - current_score

        if delta > 0 or random.random() < math.exp(delta / T):
            current_solution = new_solution
            current_score = new_score
            if new_score > best_score:
                best_solution = new_solution
                best_score = new_score

        print(f"Iter {iteration+1}: Best Score = {round(best_score, 4)}")
        T *= alpha

    return best_solution, best_score

# %%
import random

import pickle

with open("ev_battery_swap_random_dataset.pkl", "rb") as f:
    battery_swap_station_demo, ev_demo = pickle.load(f)

print(battery_swap_station_demo, ev_demo)


best_solution, best_score = simulated_annealing_strategy(
    battery_swap_station_demo,
    ev_demo,
    threshold=15,
    charging_rate=100/240,
    initial_temp=100.0,
    alpha=0.95,
    T_min=0.001,
    max_iter=200
)

print(best_solution)
print(best_score)
# Out:
# [[[5, 17], [25, 33]], [[3, 15], [27, 34]], [[2, 17], [25, 32]], [[2, 20], [25, 35]], [[4, 14], [25, 34]], [[7, 12], [27, 32]], [[10, 16], [23, 33]], [[9, 13], [23, 35]], [[8, 16], [24, 38]], [[5, 19], [27, 32]]] {0: {'battery_now': 80, 'battery_cycle': 30, 'energy_distance': [12, 28, 30, 14, 13, 31, 12, 20, 16, 34], 'travel_time': [27, 15, 13, 22, 36, 26, 16, 39, 36, 16], 'swap_schedule': {'assigned': True, 'battery_now': 80, 'battery_cycle': 30, 'battery_station': 3, 'slot': 0, 'energy_distance': 14, 'travel_time': 22, 'waiting_time': 8, 'exchanged_battery': 66, 'received_battery': 100, 'received_battery_cycle': 35}}, 1: {'battery_now': 91, 'battery_cycle': 60, 'energy_distance': [37, 21, 31, 28, 18, 17, 40, 23, 37, 13], 'travel_time': [38, 19, 12, 38, 37, 18, 11, 28, 13, 11], 'swap_schedule': {}}, 2: {'battery_now': 77, 'battery_cycle': 63, 'energy_distance': [39, 34, 23, 40, 17, 13, 30, 13, 40, 25], 'travel_time': [17, 36, 16, 40, 20, 35, 20, 24, 22, 27], 'swap_schedule': {}}, 3: {'battery_now': 62, 'battery_cycle': 68, 'energy_distance': [18, 10, 23, 37, 32, 32, 16, 19, 38, 25], 'travel_time': [12, 25, 10, 25, 28, 34, 21, 40, 25, 11], 'swap_schedule': {}}, 4: {'battery_now': 25, 'battery_cycle': 29, 'energy_distance': [14, 38, 23, 39, 10, 39, 33, 27, 27, 36], 'travel_time': [23, 21, 38, 15, 24, 29, 40, 17, 20, 32], 'swap_schedule': {}}, 5: {'battery_now': 28, 'battery_cycle': 82, 'energy_distance': [23, 24, 12, 40, 27, 19, 36, 13, 30, 25], 'travel_time': [29, 30, 31, 26, 40, 15, 16, 35, 21, 13], 'swap_schedule': {}}, 6: {'battery_now': 56, 'battery_cycle': 26, 'energy_distance': [30, 34, 19, 25, 32, 29, 40, 35, 36, 36], 'travel_time': [28, 19, 22, 31, 28, 20, 31, 18, 29, 37], 'swap_schedule': {}}, 7: {'battery_now': 77, 'battery_cycle': 64, 'energy_distance': [19, 28, 35, 12, 40, 20, 37, 18, 38, 32], 'travel_time': [17, 20, 20, 26, 28, 16, 11, 20, 10, 40], 'swap_schedule': {}}, 8: {'battery_now': 32, 'battery_cycle': 82, 'energy_distance': [21, 11, 18, 36, 31, 15, 11, 29, 15, 18], 'travel_time': [24, 35, 11, 35, 14, 18, 39, 37, 32, 39], 'swap_schedule': {}}, 9: {'battery_now': 33, 'battery_cycle': 28, 'energy_distance': [16, 16, 32, 31, 27, 10, 27, 24, 17, 20], 'travel_time': [13, 12, 26, 10, 12, 35, 34, 19, 13, 13], 'swap_schedule': {}}, 10: {'battery_now': 29, 'battery_cycle': 36, 'energy_distance': [25, 26, 23, 36, 23, 28, 30, 23, 22, 26], 'travel_time': [31, 26, 17, 32, 29, 12, 11, 32, 27, 11], 'swap_schedule': {}}, 11: {'battery_now': 57, 'battery_cycle': 73, 'energy_distance': [40, 28, 33, 22, 26, 24, 35, 29, 18, 16], 'travel_time': [33, 30, 16, 25, 21, 26, 24, 25, 25, 29], 'swap_schedule': {}}, 12: {'battery_now': 51, 'battery_cycle': 43, 'energy_distance': [27, 18, 14, 37, 27, 33, 38, 35, 29, 40], 'travel_time': [37, 31, 35, 12, 12, 27, 16, 11, 21, 28], 'swap_schedule': {}}, 13: {'battery_now': 48, 'battery_cycle': 34, 'energy_distance': [38, 14, 25, 15, 10, 23, 36, 15, 21, 11], 'travel_time': [23, 18, 36, 10, 29, 27, 29, 14, 16, 30], 'swap_schedule': {}}, 14: {'battery_now': 47, 'battery_cycle': 97, 'energy_distance': [16, 40, 26, 27, 36, 15, 25, 14, 22, 22], 'travel_time': [27, 37, 17, 28, 13, 30, 15, 35, 32, 38], 'swap_schedule': {}}, 15: {'battery_now': 90, 'battery_cycle': 53, 'energy_distance': [33, 39, 37, 32, 36, 10, 26, 22, 21, 37], 'travel_time': [17, 25, 25, 25, 23, 34, 28, 21, 26, 17], 'swap_schedule': {}}, 16: {'battery_now': 49, 'battery_cycle': 90, 'energy_distance': [28, 38, 18, 20, 30, 15, 29, 14, 21, 39], 'travel_time': [13, 39, 35, 33, 21, 21, 33, 30, 34, 23], 'swap_schedule': {}}, 17: {'battery_now': 81, 'battery_cycle': 81, 'energy_distance': [15, 21, 15, 19, 35, 25, 30, 27, 29, 19], 'travel_time': [35, 33, 37, 34, 38, 10, 13, 18, 26, 15], 'swap_schedule': {}}, 18: {'battery_now': 92, 'battery_cycle': 44, 'energy_distance': [25, 38, 14, 27, 29, 24, 35, 26, 24, 26], 'travel_time': [27, 20, 38, 13, 28, 13, 20, 26, 25, 20], 'swap_schedule': {}}, 19: {'battery_now': 64, 'battery_cycle': 75, 'energy ...
# Iter 1: Best Score = 178.2297
# Iter 2: Best Score = 178.2297
# Iter 3: Best Score = 178.2297
# Iter 4: Best Score = 178.2297
# Iter 5: Best Score = 178.2297
# Iter 6: Best Score = 178.2297
# Iter 7: Best Score = 178.2297
# Iter 8: Best Score = 178.2297
# Iter 9: Best Score = 178.2297
# Iter 10: Best Score = 178.2297
# Iter 11: Best Score = 178.2297
# Iter 12: Best Score = 178.2297
# Iter 13: Best Score = 178.2297
# Iter 14: Best Score = 178.2297
# Iter 15: Best Score = 178.2297
# Iter 16: Best Score = 178.2297
# Iter 17: Best Score = 178.2297
# Iter 18: Best Score = 178.2297
# Iter 19: Best Score = 178.2297
# Iter 20: Best Score = 178.2297
# Iter 21: Best Score = 178.2297
# Iter 22: Best Score = 178.2297
# Iter 23: Best Score = 178.2297
# Iter 24: Best Score = 178.2297
# Iter 25: Best Score = 178.2297
# Iter 26: Best Score = 178.2297
# Iter 27: Best Score = 178.2297
# Iter 28: Best Score = 178.2297
# Iter 29: Best Score = 178.2297
# Iter 30: Best Score = 178.2297
# Iter 31: Best Score = 178.4439
# Iter 32: Best Score = 179.2528
# Iter 33: Best Score = 180.7168
# Iter 34: Best Score = 181.2724
# Iter 35: Best Score = 181.5215
# Iter 36: Best Score = 183.2507
# Iter 37: Best Score = 183.2507
# Iter 38: Best Score = 183.2507
# Iter 39: Best Score = 183.2507
# Iter 40: Best Score = 183.2507
# Iter 41: Best Score = 183.2507
# Iter 42: Best Score = 183.2507
# Iter 43: Best Score = 183.2507
# Iter 44: Best Score = 183.2507
# Iter 45: Best Score = 183.2507
# Iter 46: Best Score = 183.2507
# Iter 47: Best Score = 183.2507
# Iter 48: Best Score = 183.2507
# Iter 49: Best Score = 183.2507
# Iter 50: Best Score = 183.2507
# Iter 51: Best Score = 183.2507
# Iter 52: Best Score = 183.2507
# Iter 53: Best Score = 183.2507
# Iter 54: Best Score = 183.2507
# Iter 55: Best Score = 183.2507
# Iter 56: Best Score = 183.2507
# Iter 57: Best Score = 183.2507
# Iter 58: Best Score = 183.2507
# Iter 59: Best Score = 183.2507
# Iter 60: Best Score = 183.2507
# Iter 61: Best Score = 183.2507
# Iter 62: Best Score = 183.2507
# Iter 63: Best Score = 183.2507
# Iter 64: Best Score = 183.2507
# Iter 65: Best Score = 183.2507
# Iter 66: Best Score = 183.2507
# Iter 67: Best Score = 183.2507
# Iter 68: Best Score = 183.2507
# Iter 69: Best Score = 183.2507
# Iter 70: Best Score = 183.2507
# Iter 71: Best Score = 183.2507
# Iter 72: Best Score = 183.2507
# Iter 73: Best Score = 183.2507
# Iter 74: Best Score = 183.2507
# Iter 75: Best Score = 183.2507
# Iter 76: Best Score = 183.2507
# Iter 77: Best Score = 183.2507
# Iter 78: Best Score = 183.2507
# Iter 79: Best Score = 183.2507
# Iter 80: Best Score = 183.2507
# Iter 81: Best Score = 183.2507
# Iter 82: Best Score = 183.2507
# Iter 83: Best Score = 183.2507
# Iter 84: Best Score = 183.2507
# Iter 85: Best Score = 183.2507
# Iter 86: Best Score = 183.2507
# Iter 87: Best Score = 183.2507
# Iter 88: Best Score = 183.2507
# Iter 89: Best Score = 183.2507
# Iter 90: Best Score = 183.2507
# Iter 91: Best Score = 183.2507
# Iter 92: Best Score = 183.2507
# Iter 93: Best Score = 183.2507
# Iter 94: Best Score = 183.2507
# Iter 95: Best Score = 183.2507
# Iter 96: Best Score = 183.2507
# Iter 97: Best Score = 183.2507
# Iter 98: Best Score = 183.2507
# Iter 99: Best Score = 183.2507
# Iter 100: Best Score = 183.2507
# Iter 101: Best Score = 183.2507
# Iter 102: Best Score = 183.2507
# Iter 103: Best Score = 183.2507
# Iter 104: Best Score = 183.2507
# Iter 105: Best Score = 183.2507
# Iter 106: Best Score = 183.2507
# Iter 107: Best Score = 184.5174
# Iter 108: Best Score = 184.5174
# Iter 109: Best Score = 184.5174
# Iter 110: Best Score = 187.3882
# Iter 111: Best Score = 187.3974
# Iter 112: Best Score = 187.3974
# Iter 113: Best Score = 187.3974
# Iter 114: Best Score = 187.3974
# Iter 115: Best Score = 187.3974
# Iter 116: Best Score = 187.3974
# Iter 117: Best Score = 187.3974
# Iter 118: Best Score = 187.3974
# Iter 119: Best Score = 187.3974
# Iter 120: Best Score = 187.3974
# Iter 121: Best Score = 187.3974
# Iter 122: Best Score = 187.3974
# Iter 123: Best Score = 187.3974
# Iter 124: Best Score = 187.3974
# Iter 125: Best Score = 187.3974
# Iter 126: Best Score = 188.2074
# Iter 127: Best Score = 188.2074
# Iter 128: Best Score = 188.2074
# Iter 129: Best Score = 188.2074
# Iter 130: Best Score = 188.3655
# Iter 131: Best Score = 188.3655
# Iter 132: Best Score = 188.3655
# Iter 133: Best Score = 188.3655
# Iter 134: Best Score = 188.3655
# Iter 135: Best Score = 188.3655
# Iter 136: Best Score = 188.3655
# Iter 137: Best Score = 188.3655
# Iter 138: Best Score = 188.3655
# Iter 139: Best Score = 188.8617
# Iter 140: Best Score = 189.1539
# Iter 141: Best Score = 189.1539
# Iter 142: Best Score = 189.1539
# Iter 143: Best Score = 189.1539
# Iter 144: Best Score = 189.1539
# Iter 145: Best Score = 189.1539
# Iter 146: Best Score = 189.1539
# Iter 147: Best Score = 190.0535
# Iter 148: Best Score = 191.7487
# Iter 149: Best Score = 193.0815
# Iter 150: Best Score = 193.0815
# Iter 151: Best Score = 193.7264
# Iter 152: Best Score = 193.7264
# Iter 153: Best Score = 194.8096
# Iter 154: Best Score = 195.4425
# Iter 155: Best Score = 196.7381
# Iter 156: Best Score = 196.7381
# Iter 157: Best Score = 196.7381
# Iter 158: Best Score = 196.9375
# Iter 159: Best Score = 196.9375
# Iter 160: Best Score = 196.9774
# Iter 161: Best Score = 196.9774
# Iter 162: Best Score = 196.9774
# Iter 163: Best Score = 197.5048
# Iter 164: Best Score = 197.5048
# Iter 165: Best Score = 197.5048
# Iter 166: Best Score = 197.5048
# Iter 167: Best Score = 197.5048
# Iter 168: Best Score = 197.5048
# Iter 169: Best Score = 197.5048
# Iter 170: Best Score = 197.5048
# Iter 171: Best Score = 197.5048
# Iter 172: Best Score = 197.7517
# Iter 173: Best Score = 197.7517
# Iter 174: Best Score = 197.7517
# Iter 175: Best Score = 197.7517
# Iter 176: Best Score = 198.0706
# Iter 177: Best Score = 198.0706
# Iter 178: Best Score = 198.0706
# Iter 179: Best Score = 198.0706
# Iter 180: Best Score = 198.0706
# Iter 181: Best Score = 198.0706
# Iter 182: Best Score = 198.0706
# Iter 183: Best Score = 198.0706
# Iter 184: Best Score = 198.0706
# Iter 185: Best Score = 198.0706
# Iter 186: Best Score = 198.0706
# Iter 187: Best Score = 198.0706
# Iter 188: Best Score = 198.0706
# Iter 189: Best Score = 198.0706
# Iter 190: Best Score = 198.0706
# Iter 191: Best Score = 198.0706
# Iter 192: Best Score = 198.0706
# Iter 193: Best Score = 198.0706
# Iter 194: Best Score = 198.0706
# Iter 195: Best Score = 198.0706
# Iter 196: Best Score = 198.0706
# Iter 197: Best Score = 198.0706
# Iter 198: Best Score = 198.0706
# Iter 199: Best Score = 198.0706
# Iter 200: Best Score = 198.0706
# {0: {'assigned': True, 'battery_now': 80, 'battery_cycle': 30, 'battery_station': 3, 'slot': 0, 'energy_distance': 14, 'travel_time': 22, 'waiting_time': 8, 'exchanged_battery': 66, 'received_battery': 100, 'received_battery_cycle': 35}, 50: {'assigned': True, 'battery_now': 33, 'battery_cycle': 52, 'battery_station': 6, 'slot': 0, 'energy_distance': 37, 'travel_time': 20, 'waiting_time': 6, 'exchanged_battery': 0, 'received_battery': 88, 'received_battery_cycle': 55}, 100: {'assigned': True, 'battery_now': 71, 'battery_cycle': 31, 'battery_station': 3, 'slot': 1, 'energy_distance': 30, 'travel_time': 13, 'waiting_time': 14, 'exchanged_battery': 41, 'received_battery': 89, 'received_battery_cycle': 41}, 150: {'assigned': True, 'battery_now': 57, 'battery_cycle': 87, 'battery_station': 1, 'slot': 1, 'energy_distance': 26, 'travel_time': 30, 'waiting_time': 10, 'exchanged_battery': 31, 'received_battery': 82, 'received_battery_cycle': 11}, 200: {'assigned': True, 'battery_now': 48, 'battery_cycle': 66, 'battery_station': 8, 'slot': 0, 'energy_distance': 21, 'travel_time': 25, 'waiting_time': 15, 'exchanged_battery': 27, 'received_battery': 100, 'received_battery_cycle': 29}, 250: {'assigned': True, 'battery_now': 43, 'battery_cycle': 65, 'battery_station': 7, 'slot': 1, 'energy_distance': 13, 'travel_time': 40, 'waiting_time': 11, 'exchanged_battery': 30, 'received_battery': 100, 'received_battery_cycle': 98}, 300: {'assigned': True, 'battery_now': 63, 'battery_cycle': 91, 'battery_station': 4, 'slot': 1, 'energy_distance': 30, 'travel_time': 29, 'waiting_time': 10, 'exchanged_battery': 33, 'received_battery': 96, 'received_battery_cycle': 48}, 350: {'assigned': True, 'battery_now': 84, 'battery_cycle': 75, 'battery_station': 9, 'slot': 1, 'energy_distance': 40, 'travel_time': 14, 'waiting_time': 11, 'exchanged_battery': 44, 'received_battery': 80, 'received_battery_cycle': 64}, 400: {'assigned': True, 'battery_now': 60, 'battery_cycle': 80, 'battery_station': 3, 'slot': 1, 'energy_distance': 17, 'travel_time': 37, 'waiting_time': 13, 'exchanged_battery': 43, 'received_battery': 81, 'received_battery_cycle': 45}, 450: {'assigned': True, 'battery_now': 23, 'battery_cycle': 81, 'battery_station': 4, 'slot': 1, 'energy_distance': 31, 'travel_time': 32, 'waiting_time': 11, 'exchanged_battery': 0, 'received_battery': 83, 'received_battery_cycle': 69}, 500: {'assigned': True, 'battery_now': 43, 'battery_cycle': 35, 'battery_station': 0, 'slot': 0, 'energy_distance': 38, 'travel_time': 34, 'waiting_time': 15, 'exchanged_battery': 5, 'received_battery': 87, 'received_battery_cycle': 44}, 550: {'assigned': True, 'battery_now': 80, 'battery_cycle': 48, 'battery_station': 1, 'slot': 1, 'energy_distance': 39, 'travel_time': 18, 'waiting_time': 8, 'exchanged_battery': 41, 'received_battery': 100, 'received_battery_cycle': 7}, 600: {'assigned': True, 'battery_now': 71, 'battery_cycle': 33, 'battery_station': 8, 'slot': 0, 'energy_distance': 18, 'travel_time': 31, 'waiting_time': 14, 'exchanged_battery': 53, 'received_battery': 97, 'received_battery_cycle': 74}, 650: {'assigned': True, 'battery_now': 96, 'battery_cycle': 44, 'battery_station': 1, 'slot': 1, 'energy_distance': 12, 'travel_time': 27, 'waiting_time': 13, 'exchanged_battery': 84, 'received_battery': 84, 'received_battery_cycle': 98}, 700: {'assigned': True, 'battery_now': 27, 'battery_cycle': 96, 'battery_station': 9, 'slot': 1, 'energy_distance': 10, 'travel_time': 17, 'waiting_time': 13, 'exchanged_battery': 17, 'received_battery': 100, 'received_battery_cycle': 82}, 750: {'assigned': True, 'battery_now': 81, 'battery_cycle': 41, 'battery_station': 4, 'slot': 0, 'energy_distance': 17, 'travel_time': 19, 'waiting_time': 6, 'exchanged_battery': 64, 'received_battery': 100, 'received_battery_cycle': 60}, 800: {'assigned': True, 'battery_now': 87, 'battery_cycle': 75, 'battery_station': 9, 'slot': 1, 'energy_distance': 36, 'travel_time': 16, 'waiting_time': 6, 'exchanged_battery': 5 ...
# 198.07063132872128

# %%
import time
import numpy as np
import matplotlib.pyplot as plt


def plot_distributions(initial_temp=100, num_of_cycle=100, runs=1000, max_attempts=1000):
    """
    Run the Simulated Annealing algorithm multiple times and plot distributions of 
    both fitness values and computation times.
    
    Parameters:
    - initial_temp: Initial temperature
    - num_of_cycle: Number of cycles after which temperature becomes 0
    - runs: Number of independent runs
    - max_attempts: Maximum number of attempts to find a valid solution
    
    Returns:
    - mean_fitness: Mean fitness across all valid runs
    - std_fitness: Standard deviation of fitness across all valid runs
    - mean_duration: Mean computation time across all runs (in seconds)
    - std_duration: Standard deviation of computation time across all runs (in seconds)
    """
    fitness_values = []
    duration_values = []
    valid_runs = 0
    
    print(f"Running {runs} trials of simulated annealing...")
    
    for i in range(runs):
        if i % 100 == 0 and i > 0:
            print(f"Completed {i} runs...")
            
        start_time = time.time()
        
        solution, fitness = simulated_annealing_strategy(
            battery_swap_station_demo,
            ev_demo,
            threshold=15,
            charging_rate=100/240,
            initial_temp=initial_temp,
            alpha=0.95,
            T_min=0.001,
            max_iter=200
        )
        
        end_time = time.time()
        duration = end_time - start_time
        duration_values.append(duration)
        
        if solution is not None and fitness is not None:
            fitness_values.append(fitness)
            valid_runs += 1
    
    # Print summary
    print(f"Valid solutions: {valid_runs}/{runs} ({valid_runs/runs*100:.2f}%)")
    
    # 1. PLOT FITNESS DISTRIBUTION
    if fitness_values:
        # Calculate fitness statistics
        mean_fitness = np.mean(fitness_values)
        std_fitness = np.std(fitness_values)
        
        # Plot fitness distribution
        plt.figure(figsize=(8, 6))
        plt.hist(fitness_values, bins=20, edgecolor='black')
        plt.axvline(mean_fitness, linestyle='--', label=f'Mean = {mean_fitness:.2f}')
        plt.axvline(mean_fitness + std_fitness, color='gray', linestyle=':', 
                    label=f'+1 Std = {std_fitness:.2f}')
        plt.axvline(mean_fitness - std_fitness, color='gray', linestyle=':', 
                    label=f'-1 Std = {std_fitness:.2f}')
        plt.title('Distribution of Best Fitness over {} Runs'.format(valid_runs))
        plt.xlabel('Fitness')
        plt.ylabel('Frequency')
        plt.legend()
        plt.tight_layout()
        plt.show()
        
        print(f"Mean fitness: {mean_fitness:.4f}")
        print(f"Std deviation of fitness: {std_fitness:.4f}")
    else:
        mean_fitness = None
        std_fitness = None
        print("No valid solutions found to plot fitness distribution")
    
    # 2. PLOT DURATION DISTRIBUTION
    if duration_values:
        # Calculate duration statistics
        mean_duration = np.mean(duration_values)
        std_duration = np.std(duration_values)
        
        # Plot duration distribution
        plt.figure(figsize=(8, 6))
        plt.hist(duration_values, bins=20, edgecolor='black')
        plt.axvline(mean_duration, linestyle='--', label=f'Mean = {mean_duration:.4f}s')
        plt.axvline(mean_duration + std_duration, color='gray', linestyle=':', 
                    label=f'+1 Std = {std_duration:.4f}s')
        plt.axvline(mean_duration - std_duration, color='gray', linestyle=':', 
                    label=f'-1 Std = {std_duration:.4f}s')
        plt.title('Distribution of Computation Time over {} Runs'.format(runs))
        plt.xlabel('Time (seconds)')
        plt.ylabel('Frequency')
        plt.legend()
        plt.tight_layout()
        plt.show()
        
        print(f"Mean computation time: {mean_duration:.4f} seconds")
        print(f"Std deviation of time: {std_duration:.4f} seconds")
    else:
        mean_duration = None
        std_duration = None
        print("No runs completed to plot duration distribution")
    
    return mean_fitness, std_fitness, mean_duration, std_duration

# %%
plot_distributions(initial_temp=100, num_of_cycle=300, runs=100, max_attempts=10)
# Out:
# Running 100 trials of simulated annealing...
# Iter 1: Best Score = 161.6107
# Iter 2: Best Score = 161.6107
# Iter 3: Best Score = 161.6107
# Iter 4: Best Score = 161.6107
# Iter 5: Best Score = 164.1776
# Iter 6: Best Score = 164.1776
# Iter 7: Best Score = 166.501
# Iter 8: Best Score = 166.501
# Iter 9: Best Score = 166.501
# Iter 10: Best Score = 166.501
# Iter 11: Best Score = 166.501
# Iter 12: Best Score = 166.501
# Iter 13: Best Score = 166.501
# Iter 14: Best Score = 166.501
# Iter 15: Best Score = 166.501
# Iter 16: Best Score = 166.501
# Iter 17: Best Score = 166.501
# Iter 18: Best Score = 166.501
# Iter 19: Best Score = 166.501
# Iter 20: Best Score = 166.501
# Iter 21: Best Score = 166.501
# Iter 22: Best Score = 166.501
# Iter 23: Best Score = 167.9866
# Iter 24: Best Score = 168.296
# Iter 25: Best Score = 168.296
# Iter 26: Best Score = 168.7313
# Iter 27: Best Score = 168.7313
# Iter 28: Best Score = 168.7313
# Iter 29: Best Score = 168.7313
# Iter 30: Best Score = 168.7313
# Iter 31: Best Score = 168.7313
# Iter 32: Best Score = 168.7313
# Iter 33: Best Score = 168.7313
# Iter 34: Best Score = 168.7568
# Iter 35: Best Score = 168.7568
# Iter 36: Best Score = 168.7568
# Iter 37: Best Score = 168.7568
# Iter 38: Best Score = 168.7568
# Iter 39: Best Score = 169.3171
# Iter 40: Best Score = 169.5195
# Iter 41: Best Score = 171.1049
# Iter 42: Best Score = 171.1049
# Iter 43: Best Score = 171.1049
# Iter 44: Best Score = 171.1049
# Iter 45: Best Score = 171.1049
# Iter 46: Best Score = 171.1049
# Iter 47: Best Score = 171.1049
# Iter 48: Best Score = 171.1049
# Iter 49: Best Score = 171.1049
# Iter 50: Best Score = 171.1049
# Iter 51: Best Score = 171.1049
# Iter 52: Best Score = 171.1049
# Iter 53: Best Score = 171.1049
# Iter 54: Best Score = 171.1049
# Iter 55: Best Score = 171.1049
# Iter 56: Best Score = 171.1049
# Iter 57: Best Score = 171.1049
# Iter 58: Best Score = 171.1049
# Iter 59: Best Score = 171.1049
# Iter 60: Best Score = 171.1049
# Iter 61: Best Score = 171.1049
# Iter 62: Best Score = 171.1049
# Iter 63: Best Score = 173.3514
# Iter 64: Best Score = 174.6123
# Iter 65: Best Score = 174.6123
# Iter 66: Best Score = 174.6123
# Iter 67: Best Score = 175.1281
# Iter 68: Best Score = 175.81
# Iter 69: Best Score = 176.8773
# Iter 70: Best Score = 176.8773
# Iter 71: Best Score = 176.8773
# Iter 72: Best Score = 176.8773
# Iter 73: Best Score = 180.5403
# Iter 74: Best Score = 180.5403
# Iter 75: Best Score = 181.0848
# Iter 76: Best Score = 183.2498
# Iter 77: Best Score = 183.8466
# Iter 78: Best Score = 183.8466
# Iter 79: Best Score = 183.8466
# Iter 80: Best Score = 183.8466
# Iter 81: Best Score = 183.8466
# Iter 82: Best Score = 183.8466
# Iter 83: Best Score = 183.8466
# Iter 84: Best Score = 183.8466
# Iter 85: Best Score = 183.8466
# Iter 86: Best Score = 183.8466
# Iter 87: Best Score = 183.8466
# Iter 88: Best Score = 183.8466
# Iter 89: Best Score = 183.8466
# Iter 90: Best Score = 183.8466
# Iter 91: Best Score = 183.8466
# Iter 92: Best Score = 183.8466
# Iter 93: Best Score = 183.8466
# Iter 94: Best Score = 183.8466
# Iter 95: Best Score = 184.7381
# Iter 96: Best Score = 184.7381
# Iter 97: Best Score = 184.7419
# Iter 98: Best Score = 184.7419
# Iter 99: Best Score = 186.0402
# Iter 100: Best Score = 186.0402
# Iter 101: Best Score = 186.0402
# Iter 102: Best Score = 186.0402
# Iter 103: Best Score = 187.7321
# Iter 104: Best Score = 188.1882
# Iter 105: Best Score = 189.5326
# Iter 106: Best Score = 191.2795
# Iter 107: Best Score = 191.2795
# Iter 108: Best Score = 191.2795
# Iter 109: Best Score = 191.7487
# Iter 110: Best Score = 191.7487
# Iter 111: Best Score = 191.9233
# Iter 112: Best Score = 192.0164
# Iter 113: Best Score = 192.0164
# Iter 114: Best Score = 194.0287
# Iter 115: Best Score = 194.0287
# Iter 116: Best Score = 194.0287
# Iter 117: Best Score = 195.0834
# Iter 118: Best Score = 195.0834
# Iter 119: Best Score = 195.0834
# Iter 120: Best Score = 195.0834
# Iter 121: Best Score = 195.5593
# Iter 122: Best Score = 195.5593
# Iter 123: Best Score = 195.5593
# Iter 124: Best Score = 197.1107
# Iter 125: Best Score = 197.1107
# Iter 126: Best Score = 197.1107
# Iter 127: Best Score = 197.1107
# Iter 128: Best Score = 197.1107
# Iter 129: Best Score = 197.1107
# Iter 130: Best Score = 197.1107
# Iter 131: Best Score = 197.7552
# Iter 132: Best Score = 197.7552
# Iter 133: Best Score = 197.7552
# Iter 134: Best Score = 197.7552
# Iter 135: Best Score = 197.7552
# Iter 136: Best Score = 197.7552
# Iter 137: Best Score = 197.7552
# Iter 138: Best Score = 197.7552
# Iter 139: Best Score = 197.7552
# Iter 140: Best Score = 197.7552
# Iter 141: Best Score = 197.7552
# Iter 142: Best Score = 197.7552
# Iter 143: Best Score = 197.7552
# Iter 144: Best Score = 197.7552
# Iter 145: Best Score = 197.7552
# Iter 146: Best Score = 197.9297
# Iter 147: Best Score = 197.9297
# Iter 148: Best Score = 197.9297
# Iter 149: Best Score = 197.9297
# Iter 150: Best Score = 197.9297
# Iter 151: Best Score = 197.9297
# Iter 152: Best Score = 197.9297
# Iter 153: Best Score = 197.9297
# Iter 154: Best Score = 197.9297
# Iter 155: Best Score = 197.9297
# Iter 156: Best Score = 198.6335
# Iter 157: Best Score = 198.6335
# Iter 158: Best Score = 198.6335
# Iter 159: Best Score = 198.6335
# Iter 160: Best Score = 198.6335
# Iter 161: Best Score = 198.6335
# Iter 162: Best Score = 198.6335
# Iter 163: Best Score = 198.6335
# Iter 164: Best Score = 198.6335
# Iter 165: Best Score = 198.6335
# Iter 166: Best Score = 198.6335
# Iter 167: Best Score = 198.6335
# Iter 168: Best Score = 198.6335
# Iter 169: Best Score = 198.6335
# Iter 170: Best Score = 198.6335
# Iter 171: Best Score = 198.6335
# Iter 172: Best Score = 198.6335
# Iter 173: Best Score = 198.6335
# Iter 174: Best Score = 198.6335
# Iter 175: Best Score = 198.6335
# Iter 176: Best Score = 198.8429
# Iter 177: Best Score = 198.8429
# Iter 178: Best Score = 198.8429
# Iter 179: Best Score = 198.9891
# Iter 180: Best Score = 198.9891
# Iter 181: Best Score = 198.9891
# Iter 182: Best Score = 198.9891
# Iter 183: Best Score = 198.9891
# Iter 184: Best Score = 199.2299
# Iter 185: Best Score = 199.2299
# Iter 186: Best Score = 199.2299
# Iter 187: Best Score = 199.2299
# Iter 188: Best Score = 199.2299
# Iter 189: Best Score = 199.2299
# Iter 190: Best Score = 199.2299
# Iter 191: Best Score = 199.2299
# Iter 192: Best Score = 199.2299
# Iter 193: Best Score = 199.2299
# Iter 194: Best Score = 199.2299
# Iter 195: Best Score = 199.2299
# Iter 196: Best Score = 199.2299
# Iter 197: Best Score = 199.2299
# Iter 198: Best Score = 199.2299
# Iter 199: Best Score = 199.2299
# Iter 200: Best Score = 199.5072
# Iter 1: Best Score = 167.3404
# Iter 2: Best Score = 167.3404
# Iter 3: Best Score = 167.3404
# Iter 4: Best Score = 167.3404
# Iter 5: Best Score = 167.3404
# Iter 6: Best Score = 167.3404
# Iter 7: Best Score = 167.3404
# Iter 8: Best Score = 167.3404
# Iter 9: Best Score = 167.3404
# Iter 10: Best Score = 167.3404
# Iter 11: Best Score = 168.0479
# Iter 12: Best Score = 168.0479
# Iter 13: Best Score = 168.0479
# Iter 14: Best Score = 168.0479
# Iter 15: Best Score = 168.0479
# Iter 16: Best Score = 168.0479
# Iter 17: Best Score = 168.0479
# Iter 18: Best Score = 168.0479
# Iter 19: Best Score = 168.0479
# Iter 20: Best Score = 168.0479
# Iter 21: Best Score = 168.0479
# Iter 22: Best Score = 168.0479
# Iter 23: Best Score = 168.0479
# Iter 24: Best Score = 168.0479
# Iter 25: Best Score = 168.0479
# Iter 26: Best Score = 168.0479
# Iter 27: Best Score = 168.0479
# Iter 28: Best Score = 168.0479
# Iter 29: Best Score = 168.0479
# Iter 30: Best Score = 168.0479
# Iter 31: Best Score = 168.0479
# Iter 32: Best Score = 168.0479
# Iter 33: Best Score = 168.0479
# Iter 34: Best Score = 168.0479
# Iter 35: Best Score = 168.0479
# Iter 36: Best Score = 168.0479
# Iter 37: Best Score = 168.0479
# Iter 38: Best Score = 168.0479
# Iter 39: Best Score = 168.0479
# Iter 40: Best Score = 168.0479
# Iter 41: Best Score = 168.0479
# Iter 42: Best Score = 168.0479
# Iter 43: Best Score = 168.0479
# Iter 44: Best Score = 168.0479
# Iter 45: Best Score = 168.0479
# Iter 46: Best Score = 168.0479
# Iter 47: Best Score = 168.0479
# Iter 48: Best Score = 168.0479
# Iter 49: Best Score = 168.0479
# Iter 50: Best Score = 168.0479
# Iter 51: Best Score = 168.0479
# Iter 52: Best Score = 168.0479
# Iter 53: Best Score = 168.0479
# Iter 54: Best Score = 169.672
# Iter 55: Best Score = 171.8467
# Iter 56: Best Score = 173.9646
# Iter 57: Best Score = 173.9646
# Iter 58: Best Score = 174.0999
# Iter 59: Best Score = 175.5575
# Iter 60: Best Score = 175.5575
# Iter 61: Best Score = 175.5575
# Iter 62: Best Score = 175.5575
# Iter 63: Best Score = 175.5575
# Iter 64: Best Score = 175.5575
# Iter 65: Best Score = 175.5575
# Iter 66: Best Score = 175.9848
# Iter 67: Best Score = 176.6551
# Iter 68: Best Score = 176.6551
# Iter 69: Best Score = 178.9453
# Iter 70: Best Score = 178.9453
# Iter 71: Best Score = 181.055
# Iter 72: Best Score = 182.6273
# Iter 73: Best Score = 182.6273
# Iter 74: Best Score = 182.6273
# Iter 75: Best Score = 182.6273
# Iter 76: Best Score = 182.6273
# Iter 77: Best Score = 182.6273
# Iter 78: Best Score = 182.6273
# Iter 79: Best Score = 182.6273
# Iter 80: Best Score = 182.6273
# Iter 81: Best Score = 182.9136
# Iter 82: Best Score = 183.8645
# Iter 83: Best Score = 184.4067
# Iter 84: Best Score = 184.9407
# Iter 85: Best Score = 184.9407
# Iter 86: Best Score = 184.9407
# Iter 87: Best Score = 185.6712
# Iter 88: Best Score = 185.6712
# Iter 89: Best Score = 186.018
# Iter 90: Best Score = 186.5869
# Iter 91: Best Score = 186.5869
# Iter 92: Best Score = 187.6039
# Iter 93: Best Score = 187.6039
# Iter 94: Best Score = 187.6039
# Iter 95: Best Score = 187.6039
# Iter 96: Best Score = 187.6039
# Iter 97: Best Score = 187.6039
# Iter 98: Best Score = 187.6039
# Iter 99: Best Score = 188.2863
# Iter 100: Best Score = 188.2863
# Iter 101: Best Score = 188.2863
# Iter 102: Best Score = 188.2863
# Iter 103: Best Score = 188.2863
# Iter 104: Best Score = 188.2863
# Iter 105: Best Score = 188.2863
# Iter 106: Best Score = 188.2863
# Iter 107: Best Score = 188.2863
# Iter 108: Best Score = 188.2863
# Iter 109: Best Score = 188.2863
# Iter 110: Best Score = 188.2863
# Iter 111: Best Score = 188.2863
# Iter 112: Best Score = 188.2863
# Iter 113: Best Score = 188.2863
# Iter 114: Best Score = 188.2863
# Iter 115: Best Score = 188.2863
# Iter 116: Best Score = 188.2863
# Iter 117: Best Score = 188.2863
# Iter 118: Best Score = 188.2863
# Iter 119: Best Score = 188.2863
# Iter 120: Best Score = 188.2863
# Iter 121: Best Score = 188.2863
# Iter 122: Best Score = 189.0736
# Iter 123: Best Score = 189.1364
# Iter 124: Best Score = 189.1364
# Iter 125: Best Score = 189.1364
# Iter 126: Best Score = 192.0045
# Iter 127: Best Score = 192.0045
# Iter 128: Best Score = 192.0045
# Iter 129: Best Score = 193.0676
# Iter 130: Best Score = 193.5067
# Iter 131: Best Score = 193.5067
# Iter 132: Best Score = 193.5067
# Iter 133: Best Score = 193.5067
# Iter 134: Best Score = 193.5067
# Iter 135: Best Score = 193.5067
# Iter 136: Best Score = 193.5067
# Iter 137: Best Score = 193.5067
# Iter 138: Best Score = 193.5067
# Iter 139: Best Score = 193.5067
# Iter 140: Best Score = 193.5067
# Iter 141: Best Score = 193.5067
# Iter 142: Best Score = 193.5067
# Iter 143: Best Score = 193.5067
# Iter 144: Best Score = 194.4011
# Iter 145: Best Score = 194.4477
# Iter 146: Best Score = 194.9672
# Iter 147: Best Score = 195.4059
# Iter 148: Best Score = 195.478
# Iter 149: Best Score = 195.6958
# Iter 150: Best Score = 195.6958
# Iter 151: Best Score = 195.6958
# Iter 152: Best Score = 195.6958
# Iter 153: Best Score = 195.7372
# Iter 154: Best Score = 195.7512
# Iter 155: Best Score = 195.7512
# Iter 156: Best Score = 195.7512
# Iter 157: Best Score = 195.7512
# Iter 158: Best Score = 196.6208
# Iter 159: Best Score = 197.2234
# Iter 160: Best Score = 197.2234
# Iter 161: Best Score = 197.7999
# Iter 162: Best Score = 197.8272
# Iter 163: Best Score = 198.1154
# Iter 164: Best Score = 198.1154
# Iter 165: Best Score = 198.1154
# Iter 166: Best Score = 198.1154
# Iter 167: Best Score = 198.1154
# Iter 168: Best Score = 198.1154
# Iter 169: Best Score = 198.1154
# Iter 170: Best Score = 198.1154
# Iter 171: Best Score = 198.1154
# Iter 172: Best Score = 198.2137
# Iter 173: Best Score = 198.2137
# Iter 174: Best Score = 198.7974
# Iter 175: Best Score = 198.7974
# Iter 176: Best Score = 198.7974
# Iter 177: Best Score = 198.7974
# Iter 178: Best Score = 198.8747
# Iter 179: Best Score = 198.8747
# Iter 180: Best Score = 198.8747
# Iter 181: Best Score = 198.8747
# Iter 182: Best Score = 198.8747
# Iter 183: Best Score = 198.8747
# Iter 184: Best Score = 198.8747
# Iter 185: Best Score = 198.8747
# Iter 186: Best Score = 198.8747
# Iter 187: Best Score = 198.8747
# Iter 188: Best Score = 198.8747
# Iter 189: Best Score = 198.8747
# Iter 190: Best Score = 198.8747
# Iter 191: Best Score = 198.8747
# Iter 192: Best Score = 198.8747
# Iter 193: Best Score = 198.8747
# Iter 194: Best Score = 198.8747
# Iter 195: Best Score = 198.8747
# Iter 196: Best Score = 198.8747
# Iter 197: Best Score = 198.8747
# Iter 198: Best Score = 198.8747
# Iter 199: Best Score = 198.8747
# Iter 200: Best Score = 198.8747
# Iter 1: Best Score = 173.8941
# Iter 2: Best Score = 173.98
# Iter 3: Best Score = 175.1594
# Iter 4: Best Score = 176.5177
# Iter 5: Best Score = 176.5177
# Iter 6: Best Score = 176.5177
# Iter 7: Best Score = 176.5177
# Iter 8: Best Score = 176.5177
# Iter 9: Best Score = 176.5177
# Iter 10: Best Score = 176.5177
# Iter 11: Best Score = 176.5177
# Iter 12: Best Score = 176.5177
# Iter 13: Best Score = 176.5177
# Iter 14: Best Score = 176.5177
# Iter 15: Best Score = 176.5177
# Iter 16: Best Score = 176.5177
# Iter 17: Best Score = 176.5177
# Iter 18: Best Score = 176.5177
# Iter 19: Best Score = 176.5177
# Iter 20: Best Score = 176.5177
# Iter 21: Best Score = 176.5177
# Iter 22: Best Score = 176.5177
# Iter 23: Best Score = 176.5177
# Iter 24: Best Score = 176.5177
# Iter 25: Best Score = 176.5177
# Iter 26: Best Score = 176.5177
# Iter 27: Best Score = 176.5177
# Iter 28: Best Score = 176.5177
# Iter 29: Best Score = 176.5177
# Iter 30: Best Score = 176.5177
# Iter 31: Best Score = 176.5177
# Iter 32: Best Score = 176.5177
# Iter 33: Best Score = 176.5177
# Iter 34: Best Score = 176.5177
# Iter 35: Best Score = 176.5177
# Iter 36: Best Score = 176.5177
# Iter 37: Best Score = 176.5177
# Iter 38: Best Score = 176.5177
# Iter 39: Best Score = 176.5177
# Iter 40: Best Score = 176.5177
# Iter 41: Best Score = 176.5177
# Iter 42: Best Score = 176.5177
# Iter 43: Best Score = 176.5177
# Iter 44: Best Score = 176.5177
# Iter 45: Best Score = 176.5177
# Iter 46: Best Score = 176.5177
# Iter 47: Best Score = 176.5177
# Iter 48: Best Score = 176.5177
# Iter 49: Best Score = 176.5177
# Iter 50: Best Score = 176.5177
# Iter 51: Best Score = 176.5177
# Iter 52: Best Score = 176.5177
# Iter 53: Best Score = 176.5177
# Iter 54: Best Score = 176.5177
# Iter 55: Best Score = 176.5177
# Iter 56: Best Score = 176.5177
# Iter 57: Best Score = 176.5177
# Iter 58: Best Score = 176.5177
# Iter 59: Best Score = 176.5177
# Iter 60: Best Score = 176.5177
# Iter 61: Best Score = 176.5177
# Iter 62: Best Score = 176.5177
# Iter 63: Best Score = 176.5177
# Iter 64: Best Score = 176.5177
# Iter 65: Best Score = 176.5177
# Iter 66: Best Score = 177.1937
# Iter 67: Best Score = 177.1937
# Iter 68: Best Score = 177.1937
# Iter 69: Best Score = 179.7158
# Iter 70: Best Score = 179.7158
# Iter 71: Best Score = 179.7158
# Iter 72: Best Score = 179.7158
# Iter 73: Best Score = 179.7158
# Iter 74: Best Score = 180.2087
# Iter 75: Best Score = 180.5035
# Iter 76: Best Score = 182.5582
# Iter 77: Best Score = 182.5582
# Iter 78: Best Score = 182.5582
# Iter 79: Best Score = 182.5582
# Iter 80: Best Score = 182.5582
# Iter 81: Best Score = 182.5582
# Iter 82: Best Score = 182.5582
# Iter 83: Best Score = 184.619
# Iter 84: Best Score = 184.619
# Iter 85: Best Score = 184.619
# Iter 86: Best Score = 184.619
# Iter 87: Best Score = 185.0432
# Iter 88: Best Score = 185.6807
# Iter 89: Best Score = 185.8173
# Iter 90: Best Score = 185.8173
# Iter 91: Best Score = 186.4124
# Iter 92: Best Score = 186.4124
# Iter 93: Best Score = 186.4124
# Iter 94: Best Score = 186.4124
# Iter 95: Best Score = 186.4124
# Iter 96: Best Score = 186.4124
# Iter 97: Best Score = 186.4124
# Iter 98: Best Score = 186.4124
# Iter 99: Best Score = 186.4124
# Iter 100: Best Score = 186.4124
# Iter 101: Best Score = 186.4124
# Iter 102: Best Score = 186.4124
# Iter 103: Best Score = 186.4124
# Iter 104: Best Score = 186.4124
# Iter 105: Best Score = 186.4124
# Iter 106: Best Score = 186.434
# Iter 107: Best Score = 186.434
# Iter 108: Best Score = 187.5636
# Iter 109: Best Score = 187.7419
# Iter 110: Best Score = 187.7419
# Iter 111: Best Score = 187.7419
# Iter 112: Best Score = 187.7419
# Iter 113: Best Score = 188.0467
# Iter 114: Best Score = 188.0467
# Iter 115: Best Score = 190.0967
# Iter 116: Best Score = 190.5788
# Iter 117: Best Score = 190.5788
# Iter 118: Best Score = 192.5486
# Iter 119: Best Score = 192.912
# Iter 120: Best Score = 193.2154
# Iter 121: Best Score = 193.2154
# Iter 122: Best Score = 193.2154
# Iter 123: Best Score = 193.2154
# Iter 124: Best Score = 193.2154
# Iter 125: Best Score = 193.2154
# Iter 126: Best Score = 193.2154
# Iter 127: Best Score = 193.2154
# Iter 128: Best Score = 193.6617
# Iter 129: Best Score = 193.6617
# Iter 130: Best Score = 193.6617
# Iter 131: Best Score = 193.6617
# Iter 132: Best Score = 193.8358
# Iter 133: Best Score = 193.8358
# Iter 134: Best Score = 194.5553
# Iter 135: Best Score = 194.5553
# Iter 136: Best Score = 194.8057
# Iter 137: Best Score = 194.8057
# Iter 138: Best Score = 194.8057
# Iter 139: Best Score = 194.8057
# Iter 140: Best Score = 196.0263
# Iter 141: Best Score = 196.0263
# Iter 142: Best Score = 196.0263
# Iter 143: Best Score = 196.0263
# Iter 144: Best Score = 197.0142
# Iter 145: Best Score = 197.5162
# Iter 146: Best Score = 197.5162
# Iter 147: Best Score = 197.5162
# Iter 148: Best Score = 198.0491
# Iter 149: Best Score = 198.0538
# Iter 150: Best Score = 198.0538
# Iter 151: Best Score = 198.5723
# Iter 152: Best Score = 198.5723
# Iter 153: Best Score = 198.5723
# Iter 154: Best Score = 198.5723
# Iter 155: Best Score = 198.8982
# Iter 156: Best Score = 198.8982
# Iter 157: Best Score = 198.8982
# Iter 158: Best Score = 198.8982
# Iter 159: Best Score = 198.8982
# Iter 160: Best Score = 199.3128
# Iter 161: Best Score = 199.3128
# Iter 162: Best Score = 199.3128
# Iter 163: Best Score = 199.5983
# Iter 164: Best Score = 199.5983
# Iter 165: Best Score = 199.5983
# Iter 166: Best Score = 199.5983
# Iter 167: Best Score = 199.5983
# Iter 168: Best Score = 199.5983
# Iter 169: Best Score = 199.5983
# Iter 170: Best Score = 199.5983
# Iter 171: Best Score = 199.5983
# Iter 172: Best Score = 199.5983
# Iter 173: Best Score = 199.5983
# Iter 174: Best Score = 199.5983
# Iter 175: Best Score = 199.5983
# Iter 176: Best Score = 199.5983
# Iter 177: Best Score = 199.5983
# Iter 178: Best Score = 199.5983
# Iter 179: Best Score = 199.5983
# Iter 180: Best Score = 199.5983
# Iter 181: Best Score = 199.5983
# Iter 182: Best Score = 199.5983
# Iter 183: Best Score = 199.5983
# Iter 184: Best Score = 199.5983
# Iter 185: Best Score = 199.5983
# Iter 186: Best Score = 199.5983
# Iter 187: Best Score = 199.5983
# Iter 188: Best Score = 199.5983
# Iter 189: Best Score = 199.5983
# Iter 190: Best Score = 199.5983
# Iter 191: Best Score = 199.5983
# Iter 192: Best Score = 199.5983
# Iter 193: Best Score = 199.5983
# Iter 194: Best Score = 199.5983
# Iter 195: Best Score = 199.5983
# Iter 196: Best Score = 199.5983
# Iter 197: Best Score = 199.5983
# Iter 198: Best Score = 199.5983
# Iter 199: Best Score = 199.5983
# Iter 200: Best Score = 199.5983
# Iter 1: Best Score = 165.6283
# Iter 2: Best Score = 165.6283
# Iter 3: Best Score = 165.6283
# Iter 4: Best Score = 167.0421
# Iter 5: Best Score = 168.5397
# Iter 6: Best Score = 169.1793
# Iter 7: Best Score = 169.1793
# Iter 8: Best Score = 169.1793
# Iter 9: Best Score = 169.1793
# Iter 10: Best Score = 169.1793
# Iter 11: Best Score = 169.1793
# Iter 12: Best Score = 169.1793
# Iter 13: Best Score = 169.1793
# Iter 14: Best Score = 169.1793
# Iter 15: Best Score = 169.1793
# Iter 16: Best Score = 169.1793
# Iter 17: Best Score = 169.1793
# Iter 18: Best Score = 169.4005
# Iter 19: Best Score = 169.4005
# Iter 20: Best Score = 169.4005
# Iter 21: Best Score = 169.4005
# Iter 22: Best Score = 169.4005
# Iter 23: Best Score = 169.4005
# Iter 24: Best Score = 169.4005
# Iter 25: Best Score = 169.4005
# Iter 26: Best Score = 169.4005
# Iter 27: Best Score = 170.5991
# Iter 28: Best Score = 170.6018
# Iter 29: Best Score = 170.6018
# Iter 30: Best Score = 172.7903
# Iter 31: Best Score = 172.7903
# Iter 32: Best Score = 173.7687
# Iter 33: Best Score = 173.7687
# Iter 34: Best Score = 173.7687
# Iter 35: Best Score = 174.0909
# Iter 36: Best Score = 175.0782
# Iter 37: Best Score = 175.0782
# Iter 38: Best Score = 175.0782
# Iter 39: Best Score = 175.0782
# Iter 40: Best Score = 175.0782
# Iter 41: Best Score = 175.0782
# Iter 42: Best Score = 175.0782
# Iter 43: Best Score = 175.6648
# Iter 44: Best Score = 175.6648
# Iter 45: Best Score = 175.6648
# Iter 46: Best Score = 175.6648
# Iter 47: Best Score = 175.6648
# Iter 48: Best Score = 175.6648
# Iter 49: Best Score = 176.3602
# Iter 50: Best Score = 176.6914
# Iter 51: Best Score = 177.0456
# Iter 52: Best Score = 177.0456
# Iter 53: Best Score = 177.5161
# Iter 54: Best Score = 177.5161
# Iter 55: Best Score = 177.5161
# Iter 56: Best Score = 177.5161
# Iter 57: Best Score = 177.5161
# Iter 58: Best Score = 177.5161
# Iter 59: Best Score = 177.5161
# Iter 60: Best Score = 177.5161
# Iter 61: Best Score = 177.5161
# Iter 62: Best Score = 177.5161
# Iter 63: Best Score = 177.5161
# Iter 64: Best Score = 177.5161
# Iter 65: Best Score = 177.5161
# Iter 66: Best Score = 177.5161
# Iter 67: Best Score = 177.5161
# Iter 68: Best Score = 177.5161
# Iter 69: Best Score = 177.5161
# Iter 70: Best Score = 177.5161
# Iter 71: Best Score = 177.5161
# Iter 72: Best Score = 177.5161
# Iter 73: Best Score = 177.5161
# Iter 74: Best Score = 177.5161
# Iter 75: Best Score = 177.5161
# Iter 76: Best Score = 177.5161
# Iter 77: Best Score = 177.5161
# Iter 78: Best Score = 177.5161
# Iter 79: Best Score = 177.5161
# Iter 80: Best Score = 177.5161
# Iter 81: Best Score = 177.5161
# Iter 82: Best Score = 177.5161
# Iter 83: Best Score = 177.5161
# Iter 84: Best Score = 177.5161
# Iter 85: Best Score = 177.5161
# Iter 86: Best Score = 177.5161
# Iter 87: Best Score = 177.5161
# Iter 88: Best Score = 177.5161
# Iter 89: Best Score = 177.5161
# Iter 90: Best Score = 177.5161
# Iter 91: Best Score = 177.5161
# Iter 92: Best Score = 177.5161
# Iter 93: Best Score = 177.5161
# Iter 94: Best Score = 177.5161
# Iter 95: Best Score = 177.5161
# Iter 96: Best Score = 177.5161
# Iter 97: Best Score = 177.5161
# Iter 98: Best Score = 177.5161
# Iter 99: Best Score = 177.5161
# Iter 100: Best Score = 177.5161
# Iter 101: Best Score = 177.5161
# Iter 102: Best Score = 177.8465
# Iter 103: Best Score = 177.8465
# Iter 104: Best Score = 178.3111
# Iter 105: Best Score = 179.1797
# Iter 106: Best Score = 179.1797
# Iter 107: Best Score = 180.6283
# Iter 108: Best Score = 180.6283
# Iter 109: Best Score = 180.6283
# Iter 110: Best Score = 180.6283
# Iter 111: Best Score = 180.725
# Iter 112: Best Score = 181.2328
# Iter 113: Best Score = 181.8816
# Iter 114: Best Score = 181.8816
# Iter 115: Best Score = 181.8816
# Iter 116: Best Score = 181.8816
# Iter 117: Best Score = 182.3976
# Iter 118: Best Score = 183.7023
# Iter 119: Best Score = 184.3476
# Iter 120: Best Score = 184.3476
# Iter 121: Best Score = 184.3476
# Iter 122: Best Score = 184.3476
# Iter 123: Best Score = 184.3476
# Iter 124: Best Score = 184.3476
# Iter 125: Best Score = 184.3476
# Iter 126: Best Score = 184.3476
# Iter 127: Best Score = 184.3476
# Iter 128: Best Score = 184.3476
# Iter 129: Best Score = 184.3476
# Iter 130: Best Score = 185.0329
# Iter 131: Best Score = 185.0329
# Iter 132: Best Score = 185.0329
# Iter 133: Best Score = 185.0329
# Iter 134: Best Score = 185.1481
# Iter 135: Best Score = 185.1481
# Iter 136: Best Score = 185.1481
# Iter 137: Best Score = 185.1481
# Iter 138: Best Score = 185.1481
# Iter 139: Best Score = 185.1481
# Iter 140: Best Score = 186.2975
# Iter 141: Best Score = 186.2975
# Iter 142: Best Score = 186.2975
# Iter 143: Best Score = 186.2975
# Iter 144: Best Score = 186.2975
# Iter 145: Best Score = 188.649
# Iter 146: Best Score = 188.649
# Iter 147: Best Score = 190.7085
# Iter 148: Best Score = 191.5448
# Iter 149: Best Score = 191.5448
# Iter 150: Best Score = 192.0001
# Iter 151: Best Score = 192.0001
# Iter 152: Best Score = 192.0001
# Iter 153: Best Score = 192.5592
# Iter 154: Best Score = 192.5592
# Iter 155: Best Score = 192.5592
# Iter 156: Best Score = 192.5592
# Iter 157: Best Score = 192.5592
# Iter 158: Best Score = 192.5592
# Iter 159: Best Score = 192.5592
# Iter 160: Best Score = 192.5592
# Iter 161: Best Score = 192.5592
# Iter 162: Best Score = 192.5592
# Iter 163: Best Score = 192.5592
# Iter 164: Best Score = 192.9394
# Iter 165: Best Score = 192.9394
# Iter 166: Best Score = 192.9394
# Iter 167: Best Score = 192.9394
# Iter 168: Best Score = 192.9394
# Iter 169: Best Score = 192.9394
# Iter 170: Best Score = 192.9394
# Iter 171: Best Score = 192.9394
# Iter 172: Best Score = 193.4743
# Iter 173: Best Score = 193.4743
# Iter 174: Best Score = 193.4743
# Iter 175: Best Score = 193.4743
# Iter 176: Best Score = 193.4743
# Iter 177: Best Score = 193.4743
# Iter 178: Best Score = 193.7885
# Iter 179: Best Score = 193.9052
# Iter 180: Best Score = 193.9052
# Iter 181: Best Score = 193.9052
# Iter 182: Best Score = 193.9052
# Iter 183: Best Score = 193.9052
# Iter 184: Best Score = 193.9052
# Iter 185: Best Score = 193.9052
# Iter 186: Best Score = 193.9052
# Iter 187: Best Score = 193.9052
# Iter 188: Best Score = 193.9052
# Iter 189: Best Score = 194.0996
# Iter 190: Best Score = 195.2012
# Iter 191: Best Score = 195.7922
# Iter 192: Best Score = 196.1655
# Iter 193: Best Score = 196.1655
# Iter 194: Best Score = 196.1655
# Iter 195: Best Score = 196.1655
# Iter 196: Best Score = 196.6151
# Iter 197: Best Score = 196.6151
# Iter 198: Best Score = 198.0512
# Iter 199: Best Score = 198.2253
# Iter 200: Best Score = 198.2253
# Iter 1: Best Score = 176.4689
# Iter 2: Best Score = 177.8241
# Iter 3: Best Score = 177.8241
# Iter 4: Best Score = 177.8241
# Iter 5: Best Score = 178.153
# Iter 6: Best Score = 178.153
# Iter 7: Best Score = 178.153
# Iter 8: Best Score = 178.5105
# Iter 9: Best Score = 179.6123
# Iter 10: Best Score = 182.4989
# Iter 11: Best Score = 182.4989
# Iter 12: Best Score = 182.4989
# Iter 13: Best Score = 182.4989
# Iter 14: Best Score = 182.4989
# Iter 15: Best Score = 182.4989
# Iter 16: Best Score = 182.4989
# Iter 17: Best Score = 182.4989
# Iter 18: Best Score = 182.4989
# Iter 19: Best Score = 182.4989
# Iter 20: Best Score = 182.4989
# Iter 21: Best Score = 182.4989
# Iter 22: Best Score = 182.4989
# Iter 23: Best Score = 182.4989
# Iter 24: Best Score = 182.4989
# Iter 25: Best Score = 182.4989
# Iter 26: Best Score = 182.4989
# Iter 27: Best Score = 182.4989
# Iter 28: Best Score = 182.4989
# Iter 29: Best Score = 182.4989
# Iter 30: Best Score = 182.4989
# Iter 31: Best Score = 182.4989
# Iter 32: Best Score = 182.4989
# Iter 33: Best Score = 182.4989
# Iter 34: Best Score = 182.4989
# Iter 35: Best Score = 182.4989
# Iter 36: Best Score = 182.4989
# Iter 37: Best Score = 182.4989
# Iter 38: Best Score = 182.4989
# Iter 39: Best Score = 182.4989
# Iter 40: Best Score = 182.4989
# Iter 41: Best Score = 182.4989
# Iter 42: Best Score = 182.4989
# Iter 43: Best Score = 182.4989
# Iter 44: Best Score = 182.4989
# Iter 45: Best Score = 182.4989
# Iter 46: Best Score = 182.4989
# Iter 47: Best Score = 182.4989
# Iter 48: Best Score = 182.4989
# Iter 49: Best Score = 182.4989
# Iter 50: Best Score = 182.4989
# Iter 51: Best Score = 182.4989
# Iter 52: Best Score = 182.4989
# Iter 53: Best Score = 182.4989
# Iter 54: Best Score = 182.4989
# Iter 55: Best Score = 182.4989
# Iter 56: Best Score = 182.4989
# Iter 57: Best Score = 182.4989
# Iter 58: Best Score = 182.4989
# Iter 59: Best Score = 182.4989
# Iter 60: Best Score = 182.4989
# Iter 61: Best Score = 182.4989
# Iter 62: Best Score = 182.4989
# Iter 63: Best Score = 182.4989
# Iter 64: Best Score = 182.4989
# Iter 65: Best Score = 182.4989
# Iter 66: Best Score = 182.4989
# Iter 67: Best Score = 182.4989
# Iter 68: Best Score = 182.4989
# Iter 69: Best Score = 182.4989
# Iter 70: Best Score = 182.4989
# Iter 71: Best Score = 182.4989
# Iter 72: Best Score = 182.4989
# Iter 73: Best Score = 182.4989
# Iter 74: Best Score = 182.4989
# Iter 75: Best Score = 182.4989
# Iter 76: Best Score = 182.4989
# Iter 77: Best Score = 182.4989
# Iter 78: Best Score = 182.4989
# Iter 79: Best Score = 182.4989
# Iter 80: Best Score = 182.4989
# Iter 81: Best Score = 182.4989
# Iter 82: Best Score = 182.4989
# Iter 83: Best Score = 182.4989
# Iter 84: Best Score = 182.4989
# Iter 85: Best Score = 182.4989
# Iter 86: Best Score = 182.4989
# Iter 87: Best Score = 182.4989
# Iter 88: Best Score = 182.4989
# Iter 89: Best Score = 182.4989
# Iter 90: Best Score = 182.4989
# Iter 91: Best Score = 182.4989
# Iter 92: Best Score = 182.4989
# Iter 93: Best Score = 182.4989
# Iter 94: Best Score = 182.4989
# Iter 95: Best Score = 182.4989
# Iter 96: Best Score = 182.4989
# Iter 97: Best Score = 182.4989
# Iter 98: Best Score = 182.4989
# Iter 99: Best Score = 182.4989
# Iter 100: Best Score = 182.4989
# Iter 101: Best Score = 182.4989
# Iter 102: Best Score = 182.4989
# Iter 103: Best Score = 182.4989
# Iter 104: Best Score = 182.4989
# Iter 105: Best Score = 182.4989
# Iter 106: Best Score = 182.4989
# Iter 107: Best Score = 182.4989
# Iter 108: Best Score = 182.4989
# Iter 109: Best Score = 182.4989
# Iter 110: Best Score = 182.4989
# Iter 111: Best Score = 182.4989
# Iter 112: Best Score = 182.4989
# Iter 113: Best Score = 182.4989
# Iter 114: Best Score = 182.4989
# Iter 115: Best Score = 182.4989
# Iter 116: Best Score = 182.4989
# Iter 117: Best Score = 182.4989
# Iter 118: Best Score = 182.4989
# Iter 119: Best Score = 182.4989
# Iter 120: Best Score = 182.4989
# Iter 121: Best Score = 182.4989
# Iter 122: Best Score = 182.4989
# Iter 123: Best Score = 182.4989
# Iter 124: Best Score = 182.4989
# Iter 125: Best Score = 182.4989
# Iter 126: Best Score = 182.4989
# Iter 127: Best Score = 182.4989
# Iter 128: Best Score = 182.4989
# Iter 129: Best Score = 182.4989
# Iter 130: Best Score = 182.4989
# Iter 131: Best Score = 182.4989
# Iter 132: Best Score = 182.4989
# Iter 133: Best Score = 182.4989
# Iter 134: Best Score = 182.4989
# Iter 135: Best Score = 182.4989
# Iter 136: Best Score = 183.8193
# Iter 137: Best Score = 183.8193
# Iter 138: Best Score = 183.8193
# Iter 139: Best Score = 183.8193
# Iter 140: Best Score = 183.8193
# Iter 141: Best Score = 183.8193
# Iter 142: Best Score = 184.4558
# Iter 143: Best Score = 184.4558
# Iter 144: Best Score = 184.7966
# Iter 145: Best Score = 185.5377
# Iter 146: Best Score = 185.5377
# Iter 147: Best Score = 185.5377
# Iter 148: Best Score = 185.5377
# Iter 149: Best Score = 185.5377
# Iter 150: Best Score = 185.5377
# Iter 151: Best Score = 185.5377
# Iter 152: Best Score = 185.5377
# Iter 153: Best Score = 185.5377
# Iter 154: Best Score = 185.5377
# Iter 155: Best Score = 186.9575
# Iter 156: Best Score = 186.9575
# Iter 157: Best Score = 186.9575
# Iter 158: Best Score = 186.9575
# Iter 159: Best Score = 188.2132
# Iter 160: Best Score = 188.2132
# Iter 161: Best Score = 188.2132
# Iter 162: Best Score = 188.2132
# Iter 163: Best Score = 188.2132
# Iter 164: Best Score = 188.2132
# Iter 165: Best Score = 189.2216
# Iter 166: Best Score = 190.4363
# Iter 167: Best Score = 190.4363
# Iter 168: Best Score = 190.4363
# Iter 169: Best Score = 190.4363
# Iter 170: Best Score = 190.4363
# Iter 171: Best Score = 190.4363
# Iter 172: Best Score = 190.4363
# Iter 173: Best Score = 190.4363
# Iter 174: Best Score = 191.1531
# Iter 175: Best Score = 191.1531
# Iter 176: Best Score = 192.5463
# Iter 177: Best Score = 192.5463
# Iter 178: Best Score = 192.5463
# Iter 179: Best Score = 192.5463
# Iter 180: Best Score = 192.6948
# Iter 181: Best Score = 193.774
# Iter 182: Best Score = 193.774
# Iter 183: Best Score = 193.774
# Iter 184: Best Score = 193.774
# Iter 185: Best Score = 193.774
# Iter 186: Best Score = 193.774
# Iter 187: Best Score = 193.774
# Iter 188: Best Score = 193.774
# Iter 189: Best Score = 194.4187
# Iter 190: Best Score = 194.4187
# Iter 191: Best Score = 194.4187
# Iter 192: Best Score = 194.4187
# Iter 193: Best Score = 194.4187
# Iter 194: Best Score = 194.4187
# Iter 195: Best Score = 194.4187
# Iter 196: Best Score = 194.4187
# Iter 197: Best Score = 194.4187
# Iter 198: Best Score = 194.4187
# Iter 199: Best Score = 194.4187
# Iter 200: Best Score = 196.6422
# Iter 1: Best Score = 171.3076
# Iter 2: Best Score = 172.8986
# Iter 3: Best Score = 172.8986
# Iter 4: Best Score = 172.8986
# Iter 5: Best Score = 172.8986
# Iter 6: Best Score = 172.8986
# Iter 7: Best Score = 172.8986
# Iter 8: Best Score = 172.8986
# Iter 9: Best Score = 173.0864
# Iter 10: Best Score = 173.0864
# Iter 11: Best Score = 175.6495
# Iter 12: Best Score = 176.8154
# Iter 13: Best Score = 178.2859
# Iter 14: Best Score = 178.2859
# Iter 15: Best Score = 178.2859
# Iter 16: Best Score = 178.9912
# Iter 17: Best Score = 178.9912
# Iter 18: Best Score = 179.4459
# Iter 19: Best Score = 179.7819
# Iter 20: Best Score = 179.7819
# Iter 21: Best Score = 179.7819
# Iter 22: Best Score = 179.7819
# Iter 23: Best Score = 179.7819
# Iter 24: Best Score = 179.7819
# Iter 25: Best Score = 179.7819
# Iter 26: Best Score = 179.7819
# Iter 27: Best Score = 179.7819
# Iter 28: Best Score = 179.7819
# Iter 29: Best Score = 179.7819
# Iter 30: Best Score = 179.7819
# Iter 31: Best Score = 179.7819
# Iter 32: Best Score = 179.7819
# Iter 33: Best Score = 179.7819
# Iter 34: Best Score = 179.7819
# Iter 35: Best Score = 179.7819
# Iter 36: Best Score = 179.7819
# Iter 37: Best Score = 179.7819
# Iter 38: Best Score = 179.7819
# Iter 39: Best Score = 179.7819
# Iter 40: Best Score = 179.7819
# Iter 41: Best Score = 179.7819
# Iter 42: Best Score = 179.7819
# Iter 43: Best Score = 179.7819
# Iter 44: Best Score = 179.7819
# Iter 45: Best Score = 179.7819
# Iter 46: Best Score = 179.7819
# Iter 47: Best Score = 179.7819
# Iter 48: Best Score = 179.7819
# Iter 49: Best Score = 179.7819
# Iter 50: Best Score = 179.7819
# Iter 51: Best Score = 179.7819
# Iter 52: Best Score = 179.7819
# Iter 53: Best Score = 179.7819
# Iter 54: Best Score = 179.7819
# Iter 55: Best Score = 179.7819
# Iter 56: Best Score = 179.7819
# Iter 57: Best Score = 179.7819
# Iter 58: Best Score = 179.7819
# Iter 59: Best Score = 179.7819
# Iter 60: Best Score = 179.7819
# Iter 61: Best Score = 179.7819
# Iter 62: Best Score = 179.7819
# Iter 63: Best Score = 179.7819
# Iter 64: Best Score = 179.7819
# Iter 65: Best Score = 179.7819
# Iter 66: Best Score = 179.7819
# Iter 67: Best Score = 179.7819
# Iter 68: Best Score = 179.7819
# Iter 69: Best Score = 179.7819
# Iter 70: Best Score = 179.7819
# Iter 71: Best Score = 179.7819
# Iter 72: Best Score = 179.7819
# Iter 73: Best Score = 179.7819
# Iter 74: Best Score = 179.7819
# Iter 75: Best Score = 179.7819
# Iter 76: Best Score = 179.7819
# Iter 77: Best Score = 179.7819
# Iter 78: Best Score = 179.7819
# Iter 79: Best Score = 179.7819
# Iter 80: Best Score = 179.7819
# Iter 81: Best Score = 179.7819
# Iter 82: Best Score = 179.7819
# Iter 83: Best Score = 179.7819
# Iter 84: Best Score = 179.7819
# Iter 85: Best Score = 179.7819
# Iter 86: Best Score = 179.7819
# Iter 87: Best Score = 179.7819
# Iter 88: Best Score = 179.8947
# Iter 89: Best Score = 179.8947
# Iter 90: Best Score = 179.8947
# Iter 91: Best Score = 179.8947
# Iter 92: Best Score = 179.8947
# Iter 93: Best Score = 179.8947
# Iter 94: Best Score = 179.8947
# Iter 95: Best Score = 179.8947
# Iter 96: Best Score = 179.8947
# Iter 97: Best Score = 179.8947
# Iter 98: Best Score = 179.8947
# Iter 99: Best Score = 179.8947
# Iter 100: Best Score = 180.9897
# Iter 101: Best Score = 181.9363
# Iter 102: Best Score = 181.9363
# Iter 103: Best Score = 182.5628
# Iter 104: Best Score = 182.5628
# Iter 105: Best Score = 182.5628
# Iter 106: Best Score = 182.5628
# Iter 107: Best Score = 182.5628
# Iter 108: Best Score = 182.5628
# Iter 109: Best Score = 182.5628
# Iter 110: Best Score = 182.7184
# Iter 111: Best Score = 183.2157
# Iter 112: Best Score = 183.2157
# Iter 113: Best Score = 183.2157
# Iter 114: Best Score = 183.2157
# Iter 115: Best Score = 183.2157
# Iter 116: Best Score = 184.7854
# Iter 117: Best Score = 185.3761
# Iter 118: Best Score = 185.3761
# Iter 119: Best Score = 186.0284
# Iter 120: Best Score = 186.0284
# Iter 121: Best Score = 186.0284
# Iter 122: Best Score = 187.5045
# Iter 123: Best Score = 187.5045
# Iter 124: Best Score = 188.1598
# Iter 125: Best Score = 188.1598
# Iter 126: Best Score = 188.1598
# Iter 127: Best Score = 188.1598
# Iter 128: Best Score = 188.1598
# Iter 129: Best Score = 189.1362
# Iter 130: Best Score = 189.1362
# Iter 131: Best Score = 189.1362
# Iter 132: Best Score = 189.8259
# Iter 133: Best Score = 189.8259
# Iter 134: Best Score = 189.8259
# Iter 135: Best Score = 190.1689
# Iter 136: Best Score = 190.1689
# Iter 137: Best Score = 190.1689
# Iter 138: Best Score = 190.1689
# Iter 139: Best Score = 190.1689
# Iter 140: Best Score = 190.2622
# Iter 141: Best Score = 190.2622
# Iter 142: Best Score = 190.2622
# Iter 143: Best Score = 192.2383
# Iter 144: Best Score = 192.2383
# Iter 145: Best Score = 192.2383
# Iter 146: Best Score = 192.4305
# Iter 147: Best Score = 192.608
# Iter 148: Best Score = 192.608
# Iter 149: Best Score = 192.608
# Iter 150: Best Score = 192.608
# Iter 151: Best Score = 192.6541
# Iter 152: Best Score = 192.6541
# Iter 153: Best Score = 194.5587
# Iter 154: Best Score = 194.5587
# Iter 155: Best Score = 194.5587
# Iter 156: Best Score = 194.5587
# Iter 157: Best Score = 194.7742
# Iter 158: Best Score = 194.7742
# Iter 159: Best Score = 194.7742
# Iter 160: Best Score = 194.7742
# Iter 161: Best Score = 194.7742
# Iter 162: Best Score = 194.7742
# Iter 163: Best Score = 194.7742
# Iter 164: Best Score = 194.7742
# Iter 165: Best Score = 194.7742
# Iter 166: Best Score = 194.9784
# Iter 167: Best Score = 196.3674
# Iter 168: Best Score = 196.3674
# Iter 169: Best Score = 196.3674
# Iter 170: Best Score = 196.3674
# Iter 171: Best Score = 196.3674
# Iter 172: Best Score = 196.3674
# Iter 173: Best Score = 196.3674
# Iter 174: Best Score = 196.3674
# Iter 175: Best Score = 196.3674
# Iter 176: Best Score = 196.3674
# Iter 177: Best Score = 196.3674
# Iter 178: Best Score = 196.3674
# Iter 179: Best Score = 196.3674
# Iter 180: Best Score = 197.0602
# Iter 181: Best Score = 197.3385
# Iter 182: Best Score = 197.3385
# Iter 183: Best Score = 197.3385
# Iter 184: Best Score = 197.3385
# Iter 185: Best Score = 197.3385
# Iter 186: Best Score = 197.7509
# Iter 187: Best Score = 198.552
# Iter 188: Best Score = 198.552
# Iter 189: Best Score = 198.552
# Iter 190: Best Score = 199.0688
# Iter 191: Best Score = 199.0688
# Iter 192: Best Score = 199.0688
# Iter 193: Best Score = 199.0688
# Iter 194: Best Score = 199.0688
# Iter 195: Best Score = 199.0688
# Iter 196: Best Score = 199.404
# Iter 197: Best Score = 199.404
# Iter 198: Best Score = 199.404
# Iter 199: Best Score = 199.404
# Iter 200: Best Score = 199.404
# Iter 1: Best Score = 177.7461
# Iter 2: Best Score = 177.7461
# Iter 3: Best Score = 177.7461
# Iter 4: Best Score = 177.7461
# Iter 5: Best Score = 177.7461
# Iter 6: Best Score = 177.7461
# Iter 7: Best Score = 177.7461
# Iter 8: Best Score = 177.7461
# Iter 9: Best Score = 177.7461
# Iter 10: Best Score = 178.0154
# Iter 11: Best Score = 178.2128
# Iter 12: Best Score = 178.8409
# Iter 13: Best Score = 178.8409
# Iter 14: Best Score = 178.9582
# Iter 15: Best Score = 178.9582
# Iter 16: Best Score = 178.9582
# Iter 17: Best Score = 178.9582
# Iter 18: Best Score = 178.9582
# Iter 19: Best Score = 178.9582
# Iter 20: Best Score = 179.7623
# Iter 21: Best Score = 179.7623
# Iter 22: Best Score = 179.7623
# Iter 23: Best Score = 179.7623
# Iter 24: Best Score = 179.7623
# Iter 25: Best Score = 179.7623
# Iter 26: Best Score = 179.7623
# Iter 27: Best Score = 179.7623
# Iter 28: Best Score = 179.7623
# Iter 29: Best Score = 179.7623
# Iter 30: Best Score = 179.7623
# Iter 31: Best Score = 180.9053
# Iter 32: Best Score = 182.9713
# Iter 33: Best Score = 182.9713
# Iter 34: Best Score = 182.9713
# Iter 35: Best Score = 182.9713
# Iter 36: Best Score = 182.9713
# Iter 37: Best Score = 182.9713
# Iter 38: Best Score = 182.9713
# Iter 39: Best Score = 182.9713
# Iter 40: Best Score = 182.9713
# Iter 41: Best Score = 184.0649
# Iter 42: Best Score = 184.0811
# Iter 43: Best Score = 184.0811
# Iter 44: Best Score = 184.0811
# Iter 45: Best Score = 184.0811
# Iter 46: Best Score = 184.0811
# Iter 47: Best Score = 184.0811
# Iter 48: Best Score = 184.0811
# Iter 49: Best Score = 184.0811
# Iter 50: Best Score = 184.0811
# Iter 51: Best Score = 184.0811
# Iter 52: Best Score = 184.0811
# Iter 53: Best Score = 184.0811
# Iter 54: Best Score = 184.0811
# Iter 55: Best Score = 184.0811
# Iter 56: Best Score = 184.0811
# Iter 57: Best Score = 184.0811
# Iter 58: Best Score = 184.0811
# Iter 59: Best Score = 184.0811
# Iter 60: Best Score = 184.0811
# Iter 61: Best Score = 184.0811
# Iter 62: Best Score = 184.0811
# Iter 63: Best Score = 184.0811
# Iter 64: Best Score = 184.0811
# Iter 65: Best Score = 184.0811
# Iter 66: Best Score = 184.0811
# Iter 67: Best Score = 184.0811
# Iter 68: Best Score = 184.0811
# Iter 69: Best Score = 184.0811
# Iter 70: Best Score = 184.0811
# Iter 71: Best Score = 184.0811
# Iter 72: Best Score = 184.0811
# Iter 73: Best Score = 184.0811
# Iter 74: Best Score = 184.0811
# Iter 75: Best Score = 184.0811
# Iter 76: Best Score = 184.0811
# Iter 77: Best Score = 184.0811
# Iter 78: Best Score = 184.0811
# Iter 79: Best Score = 184.0811
# Iter 80: Best Score = 184.0811
# Iter 81: Best Score = 184.0811
# Iter 82: Best Score = 184.0811
# Iter 83: Best Score = 184.0811
# Iter 84: Best Score = 184.0811
# Iter 85: Best Score = 184.0811
# Iter 86: Best Score = 184.0811
# Iter 87: Best Score = 184.0811
# Iter 88: Best Score = 184.0811
# Iter 89: Best Score = 184.0811
# Iter 90: Best Score = 184.0811
# Iter 91: Best Score = 184.0811
# Iter 92: Best Score = 184.7372
# Iter 93: Best Score = 185.5278
# Iter 94: Best Score = 185.5278
# Iter 95: Best Score = 186.0584
# Iter 96: Best Score = 186.8388
# Iter 97: Best Score = 187.9368
# Iter 98: Best Score = 189.2648
# Iter 99: Best Score = 189.2648
# Iter 100: Best Score = 189.2648
# Iter 101: Best Score = 189.2648
# Iter 102: Best Score = 189.5732
# Iter 103: Best Score = 190.4379
# Iter 104: Best Score = 190.4379
# Iter 105: Best Score = 190.4379
# Iter 106: Best Score = 190.4379
# Iter 107: Best Score = 190.4379
# Iter 108: Best Score = 190.4379
# Iter 109: Best Score = 190.4379
# Iter 110: Best Score = 190.4379
# Iter 111: Best Score = 190.4379
# Iter 112: Best Score = 190.4379
# Iter 113: Best Score = 190.4379
# Iter 114: Best Score = 190.4379
# Iter 115: Best Score = 191.9196
# Iter 116: Best Score = 191.9196
# Iter 117: Best Score = 191.9196
# Iter 118: Best Score = 192.0121
# Iter 119: Best Score = 192.0121
# Iter 120: Best Score = 192.0121
# Iter 121: Best Score = 192.0121
# Iter 122: Best Score = 192.092
# Iter 123: Best Score = 192.092
# Iter 124: Best Score = 192.092
# Iter 125: Best Score = 192.092
# Iter 126: Best Score = 192.092
# Iter 127: Best Score = 192.092
# Iter 128: Best Score = 192.092
# Iter 129: Best Score = 192.661
# Iter 130: Best Score = 192.8709
# Iter 131: Best Score = 192.8709
# Iter 132: Best Score = 192.8709
# Iter 133: Best Score = 192.8709
# Iter 134: Best Score = 192.8709
# Iter 135: Best Score = 192.8709
# Iter 136: Best Score = 192.8841
# Iter 137: Best Score = 192.8841
# Iter 138: Best Score = 192.8841
# Iter 139: Best Score = 194.6514
# Iter 140: Best Score = 194.6514
# Iter 141: Best Score = 194.6514
# Iter 142: Best Score = 194.8604
# Iter 143: Best Score = 194.9764
# Iter 144: Best Score = 195.6319
# Iter 145: Best Score = 195.6319
# Iter 146: Best Score = 196.4554
# Iter 147: Best Score = 196.4554
# Iter 148: Best Score = 196.4554
# Iter 149: Best Score = 196.4554
# Iter 150: Best Score = 196.4554
# Iter 151: Best Score = 196.4554
# Iter 152: Best Score = 196.4554
# Iter 153: Best Score = 196.4554
# Iter 154: Best Score = 196.4554
# Iter 155: Best Score = 196.4554
# Iter 156: Best Score = 196.4554
# Iter 157: Best Score = 196.4554
# Iter 158: Best Score = 196.4554
# Iter 159: Best Score = 196.6153
# Iter 160: Best Score = 196.6153
# Iter 161: Best Score = 196.6153
# Iter 162: Best Score = 196.6153
# Iter 163: Best Score = 196.7396
# Iter 164: Best Score = 196.7396
# Iter 165: Best Score = 196.7396
# Iter 166: Best Score = 196.7396
# Iter 167: Best Score = 196.7396
# Iter 168: Best Score = 196.7396
# Iter 169: Best Score = 196.7396
# Iter 170: Best Score = 196.7396
# Iter 171: Best Score = 196.7396
# Iter 172: Best Score = 196.7396
# Iter 173: Best Score = 196.7396
# Iter 174: Best Score = 196.9151
# Iter 175: Best Score = 196.9151
# Iter 176: Best Score = 196.9151
# Iter 177: Best Score = 196.9151
# Iter 178: Best Score = 196.9151
# Iter 179: Best Score = 196.9151
# Iter 180: Best Score = 198.266
# Iter 181: Best Score = 198.266
# Iter 182: Best Score = 198.4385
# Iter 183: Best Score = 198.4385
# Iter 184: Best Score = 198.4385
# Iter 185: Best Score = 198.4385
# Iter 186: Best Score = 198.4385
# Iter 187: Best Score = 198.4385
# Iter 188: Best Score = 198.4385
# Iter 189: Best Score = 198.4385
# Iter 190: Best Score = 198.4385
# Iter 191: Best Score = 198.4385
# Iter 192: Best Score = 198.4385
# Iter 193: Best Score = 198.5027
# Iter 194: Best Score = 198.5027
# Iter 195: Best Score = 198.5027
# Iter 196: Best Score = 198.5027
# Iter 197: Best Score = 198.5027
# Iter 198: Best Score = 198.5027
# Iter 199: Best Score = 198.5027
# Iter 200: Best Score = 198.5027
# Iter 1: Best Score = 166.165
# Iter 2: Best Score = 166.165
# Iter 3: Best Score = 167.163
# Iter 4: Best Score = 169.2777
# Iter 5: Best Score = 169.2777
# Iter 6: Best Score = 169.2777
# Iter 7: Best Score = 169.2777
# Iter 8: Best Score = 169.2777
# Iter 9: Best Score = 169.2777
# Iter 10: Best Score = 169.2777
# Iter 11: Best Score = 169.8384
# Iter 12: Best Score = 169.8384
# Iter 13: Best Score = 169.8384
# Iter 14: Best Score = 169.8384
# Iter 15: Best Score = 169.8384
# Iter 16: Best Score = 169.8384
# Iter 17: Best Score = 169.8384
# Iter 18: Best Score = 169.8384
# Iter 19: Best Score = 169.8384
# Iter 20: Best Score = 169.8384
# Iter 21: Best Score = 169.8384
# Iter 22: Best Score = 169.8384
# Iter 23: Best Score = 169.8384
# Iter 24: Best Score = 169.8384
# Iter 25: Best Score = 169.8384
# Iter 26: Best Score = 169.8384
# Iter 27: Best Score = 169.8384
# Iter 28: Best Score = 169.8384
# Iter 29: Best Score = 169.8384
# Iter 30: Best Score = 169.8384
# Iter 31: Best Score = 169.8384
# Iter 32: Best Score = 169.8384
# Iter 33: Best Score = 169.8384
# Iter 34: Best Score = 169.8384
# Iter 35: Best Score = 169.8384
# Iter 36: Best Score = 169.8384
# Iter 37: Best Score = 169.8384
# Iter 38: Best Score = 169.8384
# Iter 39: Best Score = 169.8384
# Iter 40: Best Score = 169.8384
# Iter 41: Best Score = 169.8384
# Iter 42: Best Score = 169.8384
# Iter 43: Best Score = 169.8384
# Iter 44: Best Score = 169.8384
# Iter 45: Best Score = 170.2979
# Iter 46: Best Score = 172.5499
# Iter 47: Best Score = 172.5499
# Iter 48: Best Score = 172.5499
# Iter 49: Best Score = 172.5499
# Iter 50: Best Score = 172.5499
# Iter 51: Best Score = 172.5499
# Iter 52: Best Score = 172.5499
# Iter 53: Best Score = 172.5499
# Iter 54: Best Score = 172.5499
# Iter 55: Best Score = 172.5499
# Iter 56: Best Score = 172.5499
# Iter 57: Best Score = 172.5499
# Iter 58: Best Score = 172.8495
# Iter 59: Best Score = 172.8495
# Iter 60: Best Score = 172.8495
# Iter 61: Best Score = 172.8495
# Iter 62: Best Score = 172.8495
# Iter 63: Best Score = 172.8495
# Iter 64: Best Score = 172.8495
# Iter 65: Best Score = 172.8495
# Iter 66: Best Score = 172.8495
# Iter 67: Best Score = 172.8495
# Iter 68: Best Score = 172.8495
# Iter 69: Best Score = 172.8495
# Iter 70: Best Score = 172.8495
# Iter 71: Best Score = 172.8495
# Iter 72: Best Score = 172.8495
# Iter 73: Best Score = 172.8495
# Iter 74: Best Score = 172.8495
# Iter 75: Best Score = 174.8064
# Iter 76: Best Score = 176.3989
# Iter 77: Best Score = 176.3989
# Iter 78: Best Score = 176.3989
# Iter 79: Best Score = 176.3989
# Iter 80: Best Score = 178.699
# Iter 81: Best Score = 178.699
# Iter 82: Best Score = 180.2882
# Iter 83: Best Score = 181.5947
# Iter 84: Best Score = 181.8307
# Iter 85: Best Score = 183.4306
# Iter 86: Best Score = 183.4306
# Iter 87: Best Score = 183.4306
# Iter 88: Best Score = 183.4306
# Iter 89: Best Score = 183.4306
# Iter 90: Best Score = 183.4306
# Iter 91: Best Score = 183.4306
# Iter 92: Best Score = 183.4306
# Iter 93: Best Score = 183.4306
# Iter 94: Best Score = 183.4306
# Iter 95: Best Score = 183.4306
# Iter 96: Best Score = 183.4306
# Iter 97: Best Score = 183.4306
# Iter 98: Best Score = 183.4306
# Iter 99: Best Score = 183.4306
# Iter 100: Best Score = 183.4306
# Iter 101: Best Score = 183.4306
# Iter 102: Best Score = 183.4306
# Iter 103: Best Score = 183.4306
# Iter 104: Best Score = 183.4306
# Iter 105: Best Score = 183.4306
# Iter 106: Best Score = 183.4306
# Iter 107: Best Score = 183.4306
# Iter 108: Best Score = 183.4306
# Iter 109: Best Score = 183.4306
# Iter 110: Best Score = 183.4306
# Iter 111: Best Score = 183.4306
# Iter 112: Best Score = 183.568
# Iter 113: Best Score = 183.568
# Iter 114: Best Score = 183.568
# Iter 115: Best Score = 184.5668
# Iter 116: Best Score = 184.5668
# Iter 117: Best Score = 184.9947
# Iter 118: Best Score = 184.9947
# Iter 119: Best Score = 184.9947
# Iter 120: Best Score = 185.5921
# Iter 121: Best Score = 185.5921
# Iter 122: Best Score = 185.5921
# Iter 123: Best Score = 185.5921
# Iter 124: Best Score = 186.8536
# Iter 125: Best Score = 186.8536
# Iter 126: Best Score = 186.8536
# Iter 127: Best Score = 187.3034
# Iter 128: Best Score = 187.8448
# ...
# Iter 103: Best Score = 192.2806
# Iter 104: Best Score = 192.2806
# Iter 105: Best Score = 192.2806
# Iter 106: Best Score = 192.2806
# Iter 107: Best Score = 192.2806
# Iter 108: Best Score = 192.8976
# Iter 109: Best Score = 192.8976
# Iter 110: Best Score = 192.8976
# Iter 111: Best Score = 192.8976
# Iter 112: Best Score = 193.1511
# Iter 113: Best Score = 193.1511
# Iter 114: Best Score = 193.1511
# Iter 115: Best Score = 193.1511
# Iter 116: Best Score = 193.1511
# Iter 117: Best Score = 193.8959
# Iter 118: Best Score = 193.8959
# Iter 119: Best Score = 193.8959
# Iter 120: Best Score = 193.8959
# Iter 121: Best Score = 193.8959
# Iter 122: Best Score = 194.343
# Iter 123: Best Score = 194.343
# Iter 124: Best Score = 194.343
# Iter 125: Best Score = 194.343
# Iter 126: Best Score = 194.343
# Iter 127: Best Score = 194.3804
# Iter 128: Best Score = 194.3804
# Iter 129: Best Score = 194.3804
# Iter 130: Best Score = 194.3804
# Iter 131: Best Score = 194.5468
# Iter 132: Best Score = 195.2042
# Iter 133: Best Score = 195.2042
# Iter 134: Best Score = 195.2042
# Iter 135: Best Score = 195.2042
# Iter 136: Best Score = 195.2042
# Iter 137: Best Score = 195.2042
# Iter 138: Best Score = 195.2042
# Iter 139: Best Score = 195.2042
# Iter 140: Best Score = 195.2042
# Iter 141: Best Score = 195.2042
# Iter 142: Best Score = 195.2042
# Iter 143: Best Score = 195.8364
# Iter 144: Best Score = 195.8364
# Iter 145: Best Score = 195.8364
# Iter 146: Best Score = 196.5199
# Iter 147: Best Score = 196.6815
# Iter 148: Best Score = 196.6815
# Iter 149: Best Score = 196.6815
# Iter 150: Best Score = 196.6815
# Iter 151: Best Score = 196.6815
# Iter 152: Best Score = 196.6815
# Iter 153: Best Score = 196.6815
# Iter 154: Best Score = 196.6815
# Iter 155: Best Score = 196.6815
# Iter 156: Best Score = 196.6815
# Iter 157: Best Score = 196.6815
# Iter 158: Best Score = 196.6815
# Iter 159: Best Score = 196.6815
# Iter 160: Best Score = 196.6815
# Iter 161: Best Score = 196.6815
# Iter 162: Best Score = 196.6815
# Iter 163: Best Score = 196.6815
# Iter 164: Best Score = 196.6815
# Iter 165: Best Score = 196.6815
# Iter 166: Best Score = 196.6815
# Iter 167: Best Score = 196.6815
# Iter 168: Best Score = 196.6815
# Iter 169: Best Score = 196.6815
# Iter 170: Best Score = 196.6815
# Iter 171: Best Score = 196.6815
# Iter 172: Best Score = 196.6815
# Iter 173: Best Score = 196.6815
# Iter 174: Best Score = 196.6815
# Iter 175: Best Score = 196.6815
# Iter 176: Best Score = 196.6815
# Iter 177: Best Score = 196.6815
# Iter 178: Best Score = 196.6815
# Iter 179: Best Score = 196.6815
# Iter 180: Best Score = 196.6815
# Iter 181: Best Score = 196.6815
# Iter 182: Best Score = 196.6815
# Iter 183: Best Score = 196.6815
# Iter 184: Best Score = 196.6815
# Iter 185: Best Score = 196.6815
# Iter 186: Best Score = 196.6815
# Iter 187: Best Score = 197.8836
# Iter 188: Best Score = 197.8836
# Iter 189: Best Score = 197.8836
# Iter 190: Best Score = 197.8836
# Iter 191: Best Score = 197.8836
# Iter 192: Best Score = 197.8836
# Iter 193: Best Score = 197.8836
# Iter 194: Best Score = 197.8836
# Iter 195: Best Score = 197.8836
# Iter 196: Best Score = 197.8836
# Iter 197: Best Score = 197.8836
# Iter 198: Best Score = 197.8836
# Iter 199: Best Score = 197.8836
# Iter 200: Best Score = 197.8836
# Iter 1: Best Score = 174.9032
# Iter 2: Best Score = 177.8198
# Iter 3: Best Score = 177.8198
# Iter 4: Best Score = 179.0335
# Iter 5: Best Score = 179.0335
# Iter 6: Best Score = 179.636
# Iter 7: Best Score = 180.3332
# Iter 8: Best Score = 180.3332
# Iter 9: Best Score = 180.3332
# Iter 10: Best Score = 180.3332
# Iter 11: Best Score = 180.3332
# Iter 12: Best Score = 180.3332
# Iter 13: Best Score = 180.3332
# Iter 14: Best Score = 180.3332
# Iter 15: Best Score = 180.3332
# Iter 16: Best Score = 180.3332
# Iter 17: Best Score = 180.3332
# Iter 18: Best Score = 180.3332
# Iter 19: Best Score = 180.3332
# Iter 20: Best Score = 180.3332
# Iter 21: Best Score = 180.3332
# Iter 22: Best Score = 180.3332
# Iter 23: Best Score = 180.3332
# Iter 24: Best Score = 180.3332
# Iter 25: Best Score = 180.3332
# Iter 26: Best Score = 180.3332
# Iter 27: Best Score = 180.3332
# Iter 28: Best Score = 180.3332
# Iter 29: Best Score = 180.3332
# Iter 30: Best Score = 180.3332
# Iter 31: Best Score = 180.3332
# Iter 32: Best Score = 180.3332
# Iter 33: Best Score = 180.3332
# Iter 34: Best Score = 180.3332
# Iter 35: Best Score = 180.3332
# Iter 36: Best Score = 180.3332
# Iter 37: Best Score = 180.3332
# Iter 38: Best Score = 180.3332
# Iter 39: Best Score = 180.3332
# Iter 40: Best Score = 180.3332
# Iter 41: Best Score = 180.3332
# Iter 42: Best Score = 180.3332
# Iter 43: Best Score = 180.3332
# Iter 44: Best Score = 180.3332
# Iter 45: Best Score = 180.3332
# Iter 46: Best Score = 180.3332
# Iter 47: Best Score = 180.3332
# Iter 48: Best Score = 180.3332
# Iter 49: Best Score = 180.3332
# Iter 50: Best Score = 180.3332
# Iter 51: Best Score = 180.3332
# Iter 52: Best Score = 180.3332
# Iter 53: Best Score = 180.3332
# Iter 54: Best Score = 180.3332
# Iter 55: Best Score = 180.3332
# Iter 56: Best Score = 180.3332
# Iter 57: Best Score = 180.3332
# Iter 58: Best Score = 180.3332
# Iter 59: Best Score = 180.3332
# Iter 60: Best Score = 180.3332
# Iter 61: Best Score = 180.3332
# Iter 62: Best Score = 180.3332
# Iter 63: Best Score = 180.3332
# Iter 64: Best Score = 180.3332
# Iter 65: Best Score = 180.3332
# Iter 66: Best Score = 180.3332
# Iter 67: Best Score = 180.3332
# Iter 68: Best Score = 180.3332
# Iter 69: Best Score = 180.3332
# Iter 70: Best Score = 180.3332
# Iter 71: Best Score = 181.1533
# Iter 72: Best Score = 183.0924
# Iter 73: Best Score = 183.0924
# Iter 74: Best Score = 184.3843
# Iter 75: Best Score = 184.3843
# Iter 76: Best Score = 184.3843
# Iter 77: Best Score = 184.3843
# Iter 78: Best Score = 184.3843
# Iter 79: Best Score = 184.3843
# Iter 80: Best Score = 185.2025
# Iter 81: Best Score = 187.8456
# Iter 82: Best Score = 188.839
# Iter 83: Best Score = 188.839
# Iter 84: Best Score = 188.9171
# Iter 85: Best Score = 188.9171
# Iter 86: Best Score = 188.9171
# Iter 87: Best Score = 188.9171
# Iter 88: Best Score = 188.9171
# Iter 89: Best Score = 188.9171
# Iter 90: Best Score = 190.0362
# Iter 91: Best Score = 190.0362
# Iter 92: Best Score = 190.0362
# Iter 93: Best Score = 190.0362
# Iter 94: Best Score = 190.0362
# Iter 95: Best Score = 190.0362
# Iter 96: Best Score = 190.0362
# Iter 97: Best Score = 190.0362
# Iter 98: Best Score = 190.4155
# Iter 99: Best Score = 190.4155
# Iter 100: Best Score = 190.9568
# Iter 101: Best Score = 190.9568
# Iter 102: Best Score = 191.2713
# Iter 103: Best Score = 191.2713
# Iter 104: Best Score = 191.2713
# Iter 105: Best Score = 191.2713
# Iter 106: Best Score = 191.2713
# Iter 107: Best Score = 191.2713
# Iter 108: Best Score = 191.2713
# Iter 109: Best Score = 191.2713
# Iter 110: Best Score = 191.2713
# Iter 111: Best Score = 191.2713
# Iter 112: Best Score = 191.2713
# Iter 113: Best Score = 191.2713
# Iter 114: Best Score = 191.2713
# Iter 115: Best Score = 191.2713
# Iter 116: Best Score = 191.2713
# Iter 117: Best Score = 191.2713
# Iter 118: Best Score = 191.2713
# Iter 119: Best Score = 191.2713
# Iter 120: Best Score = 191.2713
# Iter 121: Best Score = 191.2713
# Iter 122: Best Score = 191.2713
# Iter 123: Best Score = 191.5562
# Iter 124: Best Score = 191.5636
# Iter 125: Best Score = 191.5636
# Iter 126: Best Score = 191.9509
# Iter 127: Best Score = 191.9509
# Iter 128: Best Score = 191.9509
# Iter 129: Best Score = 191.9509
# Iter 130: Best Score = 191.9509
# Iter 131: Best Score = 191.9509
# Iter 132: Best Score = 191.9509
# Iter 133: Best Score = 191.9509
# Iter 134: Best Score = 191.9509
# Iter 135: Best Score = 191.9509
# Iter 136: Best Score = 192.6576
# Iter 137: Best Score = 192.6576
# Iter 138: Best Score = 192.6576
# Iter 139: Best Score = 192.6576
# Iter 140: Best Score = 193.7123
# Iter 141: Best Score = 193.7123
# Iter 142: Best Score = 193.7123
# Iter 143: Best Score = 193.838
# Iter 144: Best Score = 193.838
# Iter 145: Best Score = 193.838
# Iter 146: Best Score = 193.838
# Iter 147: Best Score = 193.838
# Iter 148: Best Score = 195.0777
# Iter 149: Best Score = 195.0777
# Iter 150: Best Score = 195.8177
# Iter 151: Best Score = 195.8177
# Iter 152: Best Score = 195.8177
# Iter 153: Best Score = 195.8177
# Iter 154: Best Score = 195.8177
# Iter 155: Best Score = 196.0434
# Iter 156: Best Score = 196.0434
# Iter 157: Best Score = 196.0434
# Iter 158: Best Score = 196.0434
# Iter 159: Best Score = 196.0434
# Iter 160: Best Score = 196.0434
# Iter 161: Best Score = 196.0434
# Iter 162: Best Score = 196.0434
# Iter 163: Best Score = 196.0434
# Iter 164: Best Score = 196.0434
# Iter 165: Best Score = 196.0434
# Iter 166: Best Score = 196.2214
# Iter 167: Best Score = 196.2214
# Iter 168: Best Score = 196.2214
# Iter 169: Best Score = 196.2214
# Iter 170: Best Score = 196.2214
# Iter 171: Best Score = 196.2214
# Iter 172: Best Score = 196.2214
# Iter 173: Best Score = 196.2214
# Iter 174: Best Score = 196.2214
# Iter 175: Best Score = 196.2214
# Iter 176: Best Score = 196.2214
# Iter 177: Best Score = 196.8197
# Iter 178: Best Score = 196.8197
# Iter 179: Best Score = 196.8197
# Iter 180: Best Score = 196.8197
# Iter 181: Best Score = 197.2724
# Iter 182: Best Score = 197.2724
# Iter 183: Best Score = 197.2724
# Iter 184: Best Score = 197.2724
# Iter 185: Best Score = 197.2724
# Iter 186: Best Score = 197.2724
# Iter 187: Best Score = 197.2724
# Iter 188: Best Score = 197.2724
# Iter 189: Best Score = 197.2724
# Iter 190: Best Score = 197.2724
# Iter 191: Best Score = 197.2724
# Iter 192: Best Score = 197.2724
# Iter 193: Best Score = 197.2724
# Iter 194: Best Score = 197.2724
# Iter 195: Best Score = 197.2724
# Iter 196: Best Score = 197.2724
# Iter 197: Best Score = 197.2724
# Iter 198: Best Score = 197.2724
# Iter 199: Best Score = 197.2724
# Iter 200: Best Score = 197.2724
# Iter 1: Best Score = 158.4187
# Iter 2: Best Score = 159.6157
# Iter 3: Best Score = 160.6878
# Iter 4: Best Score = 161.898
# Iter 5: Best Score = 161.898
# Iter 6: Best Score = 161.898
# Iter 7: Best Score = 161.898
# Iter 8: Best Score = 161.898
# Iter 9: Best Score = 163.9266
# Iter 10: Best Score = 163.9266
# Iter 11: Best Score = 163.9266
# Iter 12: Best Score = 163.9266
# Iter 13: Best Score = 163.9266
# Iter 14: Best Score = 164.0452
# Iter 15: Best Score = 164.0452
# Iter 16: Best Score = 164.0452
# Iter 17: Best Score = 164.0452
# Iter 18: Best Score = 164.0452
# Iter 19: Best Score = 164.0452
# Iter 20: Best Score = 164.0452
# Iter 21: Best Score = 164.0452
# Iter 22: Best Score = 164.0452
# Iter 23: Best Score = 164.0452
# Iter 24: Best Score = 164.0452
# Iter 25: Best Score = 164.0452
# Iter 26: Best Score = 164.0452
# Iter 27: Best Score = 164.0452
# Iter 28: Best Score = 164.0452
# Iter 29: Best Score = 164.0452
# Iter 30: Best Score = 164.0452
# Iter 31: Best Score = 164.0452
# Iter 32: Best Score = 164.0452
# Iter 33: Best Score = 164.0452
# Iter 34: Best Score = 166.3989
# Iter 35: Best Score = 166.3989
# Iter 36: Best Score = 166.3989
# Iter 37: Best Score = 166.3989
# Iter 38: Best Score = 166.7804
# Iter 39: Best Score = 167.0037
# Iter 40: Best Score = 167.0037
# Iter 41: Best Score = 167.9792
# Iter 42: Best Score = 167.9792
# Iter 43: Best Score = 168.7137
# Iter 44: Best Score = 169.6164
# Iter 45: Best Score = 169.847
# Iter 46: Best Score = 169.847
# Iter 47: Best Score = 172.4492
# Iter 48: Best Score = 174.7111
# Iter 49: Best Score = 174.7111
# Iter 50: Best Score = 174.7111
# Iter 51: Best Score = 174.7111
# Iter 52: Best Score = 174.7111
# Iter 53: Best Score = 174.7111
# Iter 54: Best Score = 174.7111
# Iter 55: Best Score = 174.7111
# Iter 56: Best Score = 174.7111
# Iter 57: Best Score = 174.7111
# Iter 58: Best Score = 174.7111
# Iter 59: Best Score = 174.7111
# Iter 60: Best Score = 174.7111
# Iter 61: Best Score = 174.9499
# Iter 62: Best Score = 174.9499
# Iter 63: Best Score = 174.9499
# Iter 64: Best Score = 175.3801
# Iter 65: Best Score = 176.4429
# Iter 66: Best Score = 176.4429
# Iter 67: Best Score = 176.4429
# Iter 68: Best Score = 176.4429
# Iter 69: Best Score = 176.4429
# Iter 70: Best Score = 176.4429
# Iter 71: Best Score = 177.7431
# Iter 72: Best Score = 177.7431
# Iter 73: Best Score = 179.2657
# Iter 74: Best Score = 179.2657
# Iter 75: Best Score = 179.2657
# Iter 76: Best Score = 179.2657
# Iter 77: Best Score = 181.0569
# Iter 78: Best Score = 181.0569
# Iter 79: Best Score = 181.0569
# Iter 80: Best Score = 181.0569
# Iter 81: Best Score = 181.0569
# Iter 82: Best Score = 181.0569
# Iter 83: Best Score = 181.0569
# Iter 84: Best Score = 181.0569
# Iter 85: Best Score = 181.0569
# Iter 86: Best Score = 181.0569
# Iter 87: Best Score = 181.5711
# Iter 88: Best Score = 181.5711
# Iter 89: Best Score = 181.5711
# Iter 90: Best Score = 181.5711
# Iter 91: Best Score = 182.0101
# Iter 92: Best Score = 182.2952
# Iter 93: Best Score = 182.2952
# Iter 94: Best Score = 183.6122
# Iter 95: Best Score = 183.6122
# Iter 96: Best Score = 183.6122
# Iter 97: Best Score = 183.9223
# Iter 98: Best Score = 183.9223
# Iter 99: Best Score = 183.9223
# Iter 100: Best Score = 185.7971
# Iter 101: Best Score = 185.7971
# Iter 102: Best Score = 185.7971
# Iter 103: Best Score = 187.2416
# Iter 104: Best Score = 188.7594
# Iter 105: Best Score = 188.7594
# Iter 106: Best Score = 188.7594
# Iter 107: Best Score = 188.7594
# Iter 108: Best Score = 188.7594
# Iter 109: Best Score = 189.1988
# Iter 110: Best Score = 189.1988
# Iter 111: Best Score = 189.1988
# Iter 112: Best Score = 189.1988
# Iter 113: Best Score = 189.1988
# Iter 114: Best Score = 189.1988
# Iter 115: Best Score = 189.1988
# Iter 116: Best Score = 189.1988
# Iter 117: Best Score = 189.1988
# Iter 118: Best Score = 189.1988
# Iter 119: Best Score = 189.4967
# Iter 120: Best Score = 189.4967
# Iter 121: Best Score = 189.9056
# Iter 122: Best Score = 190.6057
# Iter 123: Best Score = 190.6057
# Iter 124: Best Score = 190.6057
# Iter 125: Best Score = 190.6057
# Iter 126: Best Score = 190.6057
# Iter 127: Best Score = 190.6057
# Iter 128: Best Score = 190.6057
# Iter 129: Best Score = 190.6057
# Iter 130: Best Score = 190.9245
# Iter 131: Best Score = 191.0398
# Iter 132: Best Score = 191.0398
# Iter 133: Best Score = 191.0398
# Iter 134: Best Score = 191.0398
# Iter 135: Best Score = 191.0398
# Iter 136: Best Score = 191.0398
# Iter 137: Best Score = 192.3251
# Iter 138: Best Score = 192.3251
# Iter 139: Best Score = 192.3251
# Iter 140: Best Score = 192.3251
# Iter 141: Best Score = 192.4786
# Iter 142: Best Score = 192.4786
# Iter 143: Best Score = 192.4786
# Iter 144: Best Score = 192.4786
# Iter 145: Best Score = 192.4786
# Iter 146: Best Score = 192.4786
# Iter 147: Best Score = 192.4786
# Iter 148: Best Score = 192.4786
# Iter 149: Best Score = 192.4786
# Iter 150: Best Score = 192.4786
# Iter 151: Best Score = 192.4786
# Iter 152: Best Score = 192.4786
# Iter 153: Best Score = 192.4786
# Iter 154: Best Score = 192.4786
# Iter 155: Best Score = 192.4786
# Iter 156: Best Score = 192.4786
# Iter 157: Best Score = 192.6946
# Iter 158: Best Score = 192.6946
# Iter 159: Best Score = 192.6946
# Iter 160: Best Score = 192.9755
# Iter 161: Best Score = 192.9755
# Iter 162: Best Score = 192.9755
# Iter 163: Best Score = 193.812
# Iter 164: Best Score = 193.812
# Iter 165: Best Score = 193.812
# Iter 166: Best Score = 193.812
# Iter 167: Best Score = 193.812
# Iter 168: Best Score = 193.812
# Iter 169: Best Score = 193.8787
# Iter 170: Best Score = 193.8787
# Iter 171: Best Score = 193.9914
# Iter 172: Best Score = 193.9914
# Iter 173: Best Score = 195.7308
# Iter 174: Best Score = 195.7308
# Iter 175: Best Score = 195.7308
# Iter 176: Best Score = 195.7308
# Iter 177: Best Score = 195.7308
# Iter 178: Best Score = 195.7308
# Iter 179: Best Score = 196.5314
# Iter 180: Best Score = 197.0451
# Iter 181: Best Score = 197.0451
# Iter 182: Best Score = 197.0451
# Iter 183: Best Score = 197.0451
# Iter 184: Best Score = 197.0451
# Iter 185: Best Score = 197.0451
# Iter 186: Best Score = 197.0451
# Iter 187: Best Score = 197.0451
# Iter 188: Best Score = 197.0451
# Iter 189: Best Score = 197.0451
# Iter 190: Best Score = 197.0451
# Iter 191: Best Score = 197.0451
# Iter 192: Best Score = 197.7316
# Iter 193: Best Score = 197.7316
# Iter 194: Best Score = 197.7316
# Iter 195: Best Score = 197.7316
# Iter 196: Best Score = 198.1218
# Iter 197: Best Score = 198.1218
# Iter 198: Best Score = 198.1218
# Iter 199: Best Score = 198.3429
# Iter 200: Best Score = 198.3429
# Valid solutions: 100/100 (100.00%)
# Mean fitness: 197.9080
# Std deviation of fitness: 1.4998
# Mean computation time: 0.4916 seconds
# Std deviation of time: 0.0407 seconds
# (np.float64(197.9080402850491),
#  np.float64(1.4997627149285324),
#  np.float64(0.49157292127609253),
#  np.float64(0.04069058603556129))
