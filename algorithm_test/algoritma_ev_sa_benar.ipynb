# %%
battery_swap_station = [[85,60], [90,50]]

ev = {
    0: {'battery_now': 87, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'idle', 'energy_distance': [18, 10], 'travel_time': [18, 10], 'order_schedule': {}, 'swap_schedule': {}},
    1: {'battery_now': 100, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'active order', 'energy_distance': [12, 13], 'travel_time': [12, 13], 'order_schedule': {'latitude': -6, 'longitude': 106, 'duration': 10, 'energy_needed': 10}, 'swap_schedule': {'assigned': True, 'battery_now': 15, 'battery_station': 1, 'slot': 0, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 20, 'exchanged_battery': 10, 'received_battery': 20}},
    2: {'battery_now': 90, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'heading to BSS', 'energy_distance': [14, 20], 'travel_time': [14, 20], 'order_schedule': {}, 'swap_schedule': {'assigned': True, 'battery_now': 15, 'battery_station': 1, 'slot': 0, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 20, 'exchanged_battery': 10, 'received_battery': 20}},
    3: {'battery_now': 85, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'active order', 'energy_distance': [20, 24], 'travel_time': [20, 24], 'order_schedule': {'latitude': -6, 'longitude': 106, 'duration': 10, 'energy_needed': 10}, 'swap_schedule': {}},
    4: {'battery_now': 78, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'idle', 'energy_distance': [30, 27], 'travel_time': [30, 27], 'order_schedule': {}, 'swap_schedule': {}},
    5: {'battery_now': 60, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'idle', 'energy_distance': [33, 12], 'travel_time': [33, 12], 'order_schedule': {}, 'swap_schedule': {}},
    6: {'battery_now': 20, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'idle', 'energy_distance': [21, 30], 'travel_time': [21, 30], 'order_schedule': {}, 'swap_schedule': {}},
    7: {'battery_now': 24, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'idle', 'energy_distance': [14, 20], 'travel_time': [14, 20], 'order_schedule': {}, 'swap_schedule': {}},
    8: {'battery_now': 91, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'idle', 'energy_distance': [10, 30], 'travel_time': [10, 30], 'order_schedule': {}, 'swap_schedule': {}},
    9: {'battery_now': 35, 'latitude': -6.2009307, 'longitude': 106.8398833, 'status': 'idle', 'energy_distance': [11, 17], 'travel_time': [11, 17], 'order_schedule': {}, 'swap_schedule': {}},
}


# [87, 100, 90, 85, 78, 60, 20, 24, 91, 35]

# energy_distance = [
#     [18, 10],
#     [12, 13],
#     [14, 20],
#     [20, 24],
#     [30, 27],
#     [33, 12],
#     [21, 30],
#     [14, 20],
#     [10, 30],
#     [11, 17]
# ]

# travel_time = [
#     [18, 10],
#     [12, 13],
#     [14, 20],
#     [20, 24],
#     [30, 27],
#     [33, 12],
#     [21, 30],
#     [14, 20],
#     [10, 30],
#     [11, 17]
# ]

threshold = 15

# Stasiun, Slot, Durasi, Waiting Time
battery_swap_schedule = {
    0: {'assigned': True, 'battery_now': 15, 'battery_station': 1, 'slot': 0, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 20, 'exchanged_battery': 10, 'received_battery': 20},
    1: {'assigned': True, 'battery_now': 14, 'battery_station': 1, 'slot': 0, 'energy_distance': 20, 'travel_time': 12, 'waiting_time': 0, 'exchanged_battery': 10, 'received_battery': 20},
    2: {'assigned': False, 'battery_now': 80, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None},
    3: {'assigned': False, 'battery_now': 60, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None},
    4: {'assigned': False, 'battery_now': 55, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None},
    5: {'assigned': False, 'battery_now': 99, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None},
    6: {'assigned': True, 'battery_now': 12, 'battery_station': 0, 'slot': 1, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 0, 'exchanged_battery': 10, 'received_battery': 20},
    7: {'assigned': True, 'battery_now': 13, 'battery_station': 0, 'slot': 0, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 0, 'exchanged_battery': 10, 'received_battery': 20},
    8: {'assigned': False, 'battery_now': 87, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None},
    9: {'assigned': False, 'battery_now': 87, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None},
}

print(battery_swap_schedule)
# Out:
# {0: {'assigned': True, 'battery_now': 15, 'battery_station': 1, 'slot': 0, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 20, 'exchanged_battery': 10, 'received_battery': 20}, 1: {'assigned': True, 'battery_now': 14, 'battery_station': 1, 'slot': 0, 'energy_distance': 20, 'travel_time': 12, 'waiting_time': 0, 'exchanged_battery': 10, 'received_battery': 20}, 2: {'assigned': False, 'battery_now': 80, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None}, 3: {'assigned': False, 'battery_now': 60, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None}, 4: {'assigned': False, 'battery_now': 55, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None}, 5: {'assigned': False, 'battery_now': 99, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None}, 6: {'assigned': True, 'battery_now': 12, 'battery_station': 0, 'slot': 1, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 0, 'exchanged_battery': 10, 'received_battery': 20}, 7: {'assigned': True, 'battery_now': 13, 'battery_station': 0, 'slot': 0, 'energy_distance': 18, 'travel_time': 18, 'waiting_time': 0, 'exchanged_battery': 10, 'received_battery': 20}, 8: {'assigned': False, 'battery_now': 87, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None}, 9: {'assigned': False, 'battery_now': 87, 'battery_station': None, 'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None, 'exchanged_battery': None, 'received_battery': None}}

# %%
def evaluate(battery_swap_schedule):
    total_travel_time = 0
    total_waiting_time = 0
    battery_urgency_score = 0
    active_fleet_batery_score = 0
    total_battery_cycle = 0
    # for i in range(len(battery_swap_schedule)):
    #     if battery_swap_schedule[i]["assigned"]:
    #         total_travel_time += battery_swap_schedule[i]["travel_time"]
    #         total_waiting_time += battery_swap_schedule[i]["waiting_time"]
    #         battery_urgency_score += ((100 - battery_swap_schedule[i]["exchanged_battery"]) ** 2)
    #         active_fleet_batery_score += (battery_swap_schedule[i]["received_battery"] ** 2)
    #     else:
    #         active_fleet_batery_score += battery_swap_schedule[i]["battery_now"]
    for ev_id, sched in battery_swap_schedule.items():
        if sched and sched.get("assigned"):
            total_travel_time += sched["travel_time"]
            total_waiting_time += sched["waiting_time"]
            battery_urgency_score += ((100 - sched["exchanged_battery"]) ** 2)
            active_fleet_batery_score += (sched["received_battery"] ** 2)
            total_battery_cycle += sched["received_battery_cycle"]
        elif sched:
            active_fleet_batery_score += sched["battery_now"]
    if total_travel_time or total_waiting_time:
        total_score = (battery_urgency_score + active_fleet_batery_score) / ((total_travel_time + (10 * total_waiting_time))/60 + total_battery_cycle/8)
    else:
        total_score = battery_urgency_score + active_fleet_batery_score

    return total_score

# %%
# score = evaluate(battery_swap_schedule)
# print(score)

# %%
import copy
import random

# SOKIN: Setiap algo mau jalan, itung dulu semua travel time, waiting time, baterai sekarang, dll ulang (sesuai jam yang udah dilewatin, dan schedule nya juga)

def random_initialization(battery_swap_station, ev, threshold, charging_rate, required_battery_threshold=80):
    solution = {}
    station_batteries = copy.deepcopy(battery_swap_station)
    slot_timeline = {}

    # Kumpulkan semua swap_schedule yang ada ke dalam list dulu
    scheduled_swaps = []

    for i, data in ev.items():
        if data['swap_schedule']:
            swap = copy.deepcopy(data['swap_schedule'])
            ready_time = swap['travel_time'] + swap['waiting_time']
            scheduled_swaps.append((i, swap, ready_time))

    # Urutkan berdasarkan arrival_time (yang datang lebih cepat duluan)
    scheduled_swaps.sort(key=lambda x: x[2])

    # Masukkan ke slot_timeline secara terurut
    for i, swap, ready_time in scheduled_swaps:
        solution[i] = swap
        key = (swap['battery_station'], swap['slot'])
        exchanged_battery = swap['exchanged_battery']
        if key not in slot_timeline:
            slot_timeline[key] = [(ready_time, exchanged_battery)]
        else:
            slot_timeline[key].append((ready_time, exchanged_battery))


    for i, data in ev.items():
        if data['swap_schedule']:
            # Nanti setiap algo jalan lagi itung dulu semua travel time dan waiting time, tar dikurangin
            continue

        energy_to_nearest = min(data['energy_distance'])
        if data['battery_now'] - energy_to_nearest > threshold:
            solution[i] = {'assigned': False, 'battery_now': data['battery_now'], 'battery_station': None,
                           'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None,
                           'exchanged_battery': None, 'received_battery': None}
            continue

        valid_slots = []
        for station_idx, (ed, tt) in enumerate(zip(data['energy_distance'], data['travel_time'])):
            if data['battery_now'] - ed < 0:
                continue
            for slot_idx, initial_battery in enumerate(battery_swap_station[station_idx]):
                key = (station_idx, slot_idx)
                if key not in slot_timeline:
                    time_to_80 = max(0, (required_battery_threshold - initial_battery) / charging_rate)
                    ready_time = time_to_80
                else:
                    last_ready_time, last_insert = slot_timeline[key][-1]
                    time_to_80 = max(0, (required_battery_threshold - last_insert) / charging_rate)
                    ready_time = last_ready_time + time_to_80
                valid_slots.append((ready_time, station_idx, slot_idx, ed, tt))

        if not valid_slots:
            solution[i] = {'assigned': False, 'battery_now': data['battery_now'], 'battery_station': None,
                           'slot': None, 'energy_distance': None, 'travel_time': None, 'waiting_time': None,
                           'exchanged_battery': None, 'received_battery': None}
            continue

        ready_time, station_idx, slot_idx, energy_dist, travel_time = random.choice(valid_slots)
        key = (station_idx, slot_idx)
        exchanged_battery = data['battery_now'] - energy_dist

        if key not in slot_timeline:
            waiting_time = max(0, ready_time - travel_time)
            slot_timeline[key] = [(travel_time + waiting_time, exchanged_battery)]
            current_slot_battery = station_batteries[station_idx][slot_idx]
            received_battery = min(100, current_slot_battery + (travel_time + waiting_time) * charging_rate)
        else:
            waiting_time = max(0, ready_time - travel_time)
            last_ready_time, last_insert = copy.deepcopy(slot_timeline[key][-1])
            slot_timeline[key].append((travel_time + waiting_time, exchanged_battery))
            if ready_time < travel_time:
                 received_battery = min(100, 80 + (travel_time - ready_time) * charging_rate)
            else:
                received_battery = 80

        solution[i] = {
            'assigned': True,
            'battery_now': data['battery_now'],
            'battery_station': station_idx,
            'slot': slot_idx,
            'energy_distance': energy_dist,
            'travel_time': travel_time,
            'waiting_time': round(waiting_time, 2),
            'exchanged_battery': exchanged_battery,
            'received_battery': round(received_battery, 2)
        }

    return solution

# %%
import copy
import random

def queue_update(solution, ev, battery_swap_station, charging_rate, required_battery_threshold=80):
    slot_timeline = {}
    station_batteries = copy.deepcopy(battery_swap_station)

    swaps = []

    # 1. Masukkan jadwal tetap (dari ev['swap_schedule']) dulu ke slot_timeline
    # Kumpulkan semua jadwal tetap dari ev['swap_schedule']
    temp_queue = {}

    for ev_id, data in ev.items():
        sched = copy.deepcopy(data.get('swap_schedule'))
        if sched and sched.get('assigned'):
            key = (sched['battery_station'], sched['slot'])
            ready_time = sched['travel_time'] + sched['waiting_time']
            exchanged_battery = sched['exchanged_battery']
            exchanged_battery_cycle = sched['battery_cycle']

            if key not in temp_queue:
                temp_queue[key] = [(ready_time, exchanged_battery, exchanged_battery_cycle)]
            else:
                temp_queue[key].append((ready_time, exchanged_battery, exchanged_battery_cycle))

    # Urutkan setiap antrian berdasarkan arrival_time
    slot_timeline = {
        key: sorted(entries, key=lambda x: x[0])
        for key, entries in temp_queue.items()
    }

    # 2. Kumpulkan EV dari solusi yang assigned, tapi hanya yang tidak punya jadwal tetap
    for ev_id, sched in solution.items():
        if sched['assigned'] and not ev[ev_id]['swap_schedule']:
            arrival_time = sched['travel_time']
            key = (sched['battery_station'], sched['slot'])
            swaps.append((arrival_time, ev_id, key))

    # 3. Urutkan berdasarkan arrival_time (yang datang duluan diproses lebih dulu)
    swaps.sort()

    # 4. Proses masing-masing EV, hitung ulang waiting_time dan received_battery
    for _, ev_id, key in swaps:
        sched = solution[ev_id]
        station_idx, slot_idx = key

        if key not in slot_timeline:
            last_ready_time = 0
            last_insert = battery_swap_station[station_idx][slot_idx][0]
            last_insert_cycle = battery_swap_station[station_idx][slot_idx][1]
        else:
            last_ready_time, last_insert, last_insert_cycle = slot_timeline[key][-1]

        arrival_time = sched['travel_time']
        time_to_80 = max(0, (required_battery_threshold - last_insert) / charging_rate)
        ready_time = last_ready_time + time_to_80
        waiting_time = max(0, ready_time - arrival_time)

        exchanged_battery = sched['exchanged_battery']
        received_battery = min(100, last_insert + (arrival_time + waiting_time - last_ready_time) * charging_rate)
        exchanged_battery_cycle = sched['battery_cycle']
        received_battery_cycle = last_insert_cycle + (received_battery - last_insert) / 100

        # Update ke dalam solution
        solution[ev_id]['waiting_time'] = round(waiting_time, 2)
        solution[ev_id]['received_battery'] = round(received_battery, 2)
        solution[ev_id]['received_battery_cycle'] = round(received_battery_cycle, 2)

        # Tambahkan ke slot_timeline untuk update antrian selanjutnya
        if key not in slot_timeline:
            slot_timeline[key] = [(arrival_time + waiting_time, exchanged_battery, exchanged_battery_cycle)]
        else:
            slot_timeline[key].append((arrival_time + waiting_time, exchanged_battery, exchanged_battery_cycle))

    return solution



def random_initialization(battery_swap_station, ev, threshold, charging_rate, required_battery_threshold=80):
    solution = {}
    station_batteries = copy.deepcopy(battery_swap_station)

    # Inisialisasi semua EV yang punya schedule tetap
    for i, data in ev.items():
        if data['swap_schedule']:
            solution[i] = copy.deepcopy(data['swap_schedule'])

    # Ambil EV yang layak dijadwalkan
    candidates = []
    for i, data in ev.items():
        if data['swap_schedule']:
            continue
        energy_to_nearest = min(data['energy_distance'])
        if data['battery_now'] - energy_to_nearest < threshold:
            candidates.append(i)

    # Acak urutan EV
    random.shuffle(candidates)

    # Jadwalkan secara acak ke slot kosong
    slot_keys = [(i, j) for i in range(len(battery_swap_station)) for j in range(len(battery_swap_station[i]))]
    slot_usage = {k: [] for k in slot_keys}

    for i in candidates:
        data = ev[i]
        valid_options = []

        for station_idx, (ed, tt) in enumerate(zip(data['energy_distance'], data['travel_time'])):
            if data['battery_now'] - ed < 0:
                continue
            for slot_idx in range(len(battery_swap_station[station_idx])):
                valid_options.append((station_idx, slot_idx, ed, tt))

        if not valid_options:
            solution[i] = {
                'assigned': False,
                'battery_now': data['battery_now'],
                'battery_cycle': data['battery_cycle'],
                'battery_station': None,
                'slot': None,
                'energy_distance': None,
                'travel_time': None,
                'waiting_time': None,
                'exchanged_battery': None,
                'received_battery': None,
                'received_battery_cycle': None
            }
            continue

        # Pilih slot acak dari opsi valid
        station_idx, slot_idx, energy_dist, travel_time = random.choice(valid_options)
        key = (station_idx, slot_idx)
        exchanged_battery = data['battery_now'] - energy_dist

        solution[i] = {
            'assigned': True,
            'battery_now': data['battery_now'],
            'battery_cycle': data['battery_cycle'],
            'battery_station': station_idx,
            'slot': slot_idx,
            'energy_distance': energy_dist,
            'travel_time': travel_time,
            'waiting_time': 0,  # akan diupdate
            'exchanged_battery': exchanged_battery,
            'received_battery': 0,  # akan diupdate
            'received_battery_cycle': 0 # akan diupdate
        }

    # Update ulang waiting_time dan received_battery
    solution = queue_update(solution, ev, battery_swap_station, charging_rate, required_battery_threshold)
    return solution

# %%
battery_swap_station_demo = [
    [[60, 200], [50,100]],  # Station 0: Slot 0, Slot 1
    [[45,100], [55,150]]   # Station 1: Slot 0, Slot 1
]

ev_demo = {
    0: {'battery_now': 20, 'battery_cycle': 100, 'energy_distance': [10, 14], 'travel_time': [10, 14], 'swap_schedule': {}},
    1: {'battery_now': 25, 'battery_cycle': 100,'energy_distance': [12, 17], 'travel_time': [11, 16], 'swap_schedule': {}},
    2: {'battery_now': 87, 'battery_cycle': 100,'energy_distance': [35, 40], 'travel_time': [30, 35], 'swap_schedule': {}},
    3: {'battery_now': 38, 'battery_cycle': 100,'energy_distance': [15, 18], 'travel_time': [13, 17], 'swap_schedule': {}},
    4: {'battery_now': 35, 'battery_cycle': 100,'energy_distance': [14, 17], 'travel_time': [12, 17], 'swap_schedule': {
        'assigned': True, 'battery_now': 35, 'battery_cycle': 100, 'battery_station': 0, 'slot': 1,
        'energy_distance': 12, 'travel_time': 12, 'waiting_time': 5,
        'exchanged_battery': 23, 'received_battery': 85, 'received_battery_cycle': 100
    }},
    5: {'battery_now': 90, 'battery_cycle': 100, 'energy_distance': [40, 36], 'travel_time': [35, 31], 'swap_schedule': {}},
    6: {'battery_now': 33, 'battery_cycle': 100,'energy_distance': [13, 12], 'travel_time': [13, 12], 'swap_schedule': {}},
    7: {'battery_now': 19, 'battery_cycle': 100,'energy_distance': [15, 13], 'travel_time': [15, 13], 'swap_schedule': {
        'assigned': True, 'battery_now': 19, 'battery_cycle': 100,'battery_station': 1, 'slot': 1,
        'energy_distance': 13, 'travel_time': 13, 'waiting_time': 7,
        'exchanged_battery': 6, 'received_battery': 83, 'received_battery_cycle': 100
    }},
    8: {'battery_now': 60, 'battery_cycle': 100,'energy_distance': [16, 14], 'travel_time': [16, 14], 'swap_schedule': {}},
    9: {'battery_now': 50, 'battery_cycle': 100,'energy_distance': [11, 19], 'travel_time': [11, 19], 'swap_schedule': {}},
    10: {'battery_now': 28, 'battery_cycle': 100,'energy_distance': [13, 15], 'travel_time': [11, 14], 'swap_schedule': {}},
    11: {'battery_now': 24, 'battery_cycle': 100,'energy_distance': [12, 18], 'travel_time': [10, 16], 'swap_schedule': {}},
    12: {'battery_now': 45, 'battery_cycle': 100,'energy_distance': [20, 25], 'travel_time': [18, 22], 'swap_schedule': {}},
    13: {'battery_now': 42, 'battery_cycle': 100,'energy_distance': [19, 17], 'travel_time': [17, 15], 'swap_schedule': {}},
    14: {'battery_now': 31, 'battery_cycle': 100,'energy_distance': [12, 13], 'travel_time': [11, 12], 'swap_schedule': {}},
    15: {'battery_now': 36, 'battery_cycle': 100,'energy_distance': [15, 18], 'travel_time': [14, 17], 'swap_schedule': {}},
    16: {'battery_now': 65, 'battery_cycle': 100,'energy_distance': [25, 30], 'travel_time': [22, 27], 'swap_schedule': {}},
    17: {'battery_now': 58, 'battery_cycle': 100,'energy_distance': [20, 22], 'travel_time': [20, 22], 'swap_schedule': {}},
    18: {'battery_now': 49, 'battery_cycle': 100,'energy_distance': [16, 19], 'travel_time': [15, 18], 'swap_schedule': {}},
    19: {'battery_now': 22, 'battery_cycle': 100,'energy_distance': [11, 14], 'travel_time': [10, 13], 'swap_schedule': {}},
}




solution = random_initialization(battery_swap_station_demo, ev_demo, 15, 100 / 240)
print(solution)
print(evaluate(solution))
# Out:
# {4: {'assigned': True, 'battery_now': 35, 'battery_cycle': 100, 'battery_station': 0, 'slot': 1, 'energy_distance': 12, 'travel_time': 12, 'waiting_time': 5, 'exchanged_battery': 23, 'received_battery': 85, 'received_battery_cycle': 100}, 7: {'assigned': True, 'battery_now': 19, 'battery_cycle': 100, 'battery_station': 1, 'slot': 1, 'energy_distance': 13, 'travel_time': 13, 'waiting_time': 7, 'exchanged_battery': 6, 'received_battery': 83, 'received_battery_cycle': 100}, 19: {'assigned': True, 'battery_now': 22, 'battery_cycle': 100, 'battery_station': 0, 'slot': 0, 'energy_distance': 11, 'travel_time': 10, 'waiting_time': 38.0, 'exchanged_battery': 11, 'received_battery': 80.0, 'received_battery_cycle': 200.2}, 1: {'assigned': True, 'battery_now': 25, 'battery_cycle': 100, 'battery_station': 0, 'slot': 0, 'energy_distance': 12, 'travel_time': 11, 'waiting_time': 202.6, 'exchanged_battery': 13, 'received_battery': 80.0, 'received_battery_cycle': 100.69}, 11: {'assigned': True, 'battery_now': 24, 'battery_cycle': 100, 'battery_station': 1, 'slot': 0, 'energy_distance': 18, 'travel_time': 16, 'waiting_time': 245.6, 'exchanged_battery': 6, 'received_battery': 80.0, 'received_battery_cycle': 100.74}, 0: {'assigned': True, 'battery_now': 20, 'battery_cycle': 100, 'battery_station': 1, 'slot': 0, 'energy_distance': 14, 'travel_time': 14, 'waiting_time': 70.0, 'exchanged_battery': 6, 'received_battery': 80.0, 'received_battery_cycle': 100.35}}
# 477.0508534544151

# %%
import copy
import random
import math

def get_neighbor(solution, ev, battery_swap_station, charging_rate, threshold=15, required_battery_threshold=80):
    neighbor = copy.deepcopy(solution)

    # Ambil daftar EV yang assigned di solution tetapi tidak punya swap_schedule tetap di ev
    movable_ev_ids = [
        ev_id for ev_id in neighbor
        if neighbor[ev_id] and neighbor[ev_id].get("assigned") and not ev[ev_id].get("swap_schedule")
    ]

    if not movable_ev_ids:
        return neighbor  # Tidak ada yang bisa diubah

    # Pilih satu EV secara acak dari yang bisa diubah
    ev_id = random.choice(movable_ev_ids)
    data = ev[ev_id]

    # Cari opsi stasiun-slot valid untuk EV ini
    valid_options = []
    for station_idx, (ed, tt) in enumerate(zip(data['energy_distance'], data['travel_time'])):
        if data['battery_now'] - ed < 0:
            continue
        for slot_idx in range(len(battery_swap_station[station_idx])):
            valid_options.append((station_idx, slot_idx, ed, tt))

    if not valid_options:
        # Jika tidak ada opsi valid, set jadi unassigned
        neighbor[ev_id] = {
            'assigned': False,
            'battery_now': data['battery_now'],
            'battery_cycle': data['battery_cycle'],
            'battery_station': None,
            'slot': None,
            'energy_distance': None,
            'travel_time': None,
            'waiting_time': None,
            'exchanged_battery': None,
            'received_battery': None,
            'received_battery_cycle': None
        }
    else:
        # Acak salah satu pilihan valid
        station_idx, slot_idx, energy_dist, travel_time = random.choice(valid_options)
        exchanged_battery = data['battery_now'] - energy_dist
        neighbor[ev_id] = {
            'assigned': True,
            'battery_now': data['battery_now'],
            'battery_cycle': data['battery_cycle'],
            'battery_station': station_idx,
            'slot': slot_idx,
            'energy_distance': energy_dist,
            'travel_time': travel_time,
            'waiting_time': 0,  # akan diupdate
            'exchanged_battery': exchanged_battery,
            'received_battery': 0,  # akan diupdate
            'received_battery_cycle': 0 # akan diupdate
        }

    # Update ulang nilai waiting_time dan received_battery setelah perubahan
    neighbor = queue_update(neighbor, ev, battery_swap_station, charging_rate, required_battery_threshold)
    return neighbor


# def temperature_schedule(t, initial_temp, num_of_cycle):
#     """
#     Temperature schedule function that returns 0 when t reaches num_of_cycle.
    
#     Parameters:
#     - t: Current cycle/iteration
#     - initial_temp: Initial temperature
#     - num_of_cycle: Number of cycles after which temperature becomes 0
    
#     Returns:
#     - Temperature value
#     """
#     if t >= num_of_cycle:
#         return 0
    
#     # Linear cooling schedule that reaches 0 at num_of_cycle
#     return initial_temp * (1 - t / num_of_cycle)

def simulated_annealing_strategy(
    battery_swap_station,
    ev,
    threshold,
    charging_rate,
    initial_temp=100.0,
    alpha=0.95,
    T_min=0.001,
    max_iter=200
):
    current_ev = copy.deepcopy(ev)
    current_solution = random_initialization(battery_swap_station, current_ev, threshold, charging_rate)
    current_score = evaluate(current_solution)

    best_solution = copy.deepcopy(current_solution)
    best_score = current_score

    T = initial_temp
    for iteration in range(max_iter):
        if T < T_min:
            break

        new_solution = get_neighbor(current_solution, ev, battery_swap_station, charging_rate, threshold=15, required_battery_threshold=80)
        new_score = evaluate(new_solution)
        delta = new_score - current_score

        if delta > 0 or random.random() < math.exp(delta / T):
            current_solution = new_solution
            current_score = new_score
            if new_score > best_score:
                best_solution = new_solution
                best_score = new_score

        print(f"Iter {iteration+1}: Best Score = {round(best_score, 4)}")
        T *= alpha

    return best_solution, best_score

# %%
import random

import pickle

with open("ev_battery_swap_random_dataset.pkl", "rb") as f:
    battery_swap_station_demo, ev_demo = pickle.load(f)

print(battery_swap_station_demo, ev_demo)


best_solution, best_score = simulated_annealing_strategy(
    battery_swap_station_demo,
    ev_demo,
    threshold=15,
    charging_rate=100/240,
    initial_temp=100.0,
    alpha=0.95,
    T_min=0.001,
    max_iter=200
)

print(best_solution)
print(best_score)
# Out:
# [[[5, 17], [25, 33]], [[3, 15], [27, 34]], [[2, 17], [25, 32]], [[2, 20], [25, 35]], [[4, 14], [25, 34]], [[7, 12], [27, 32]], [[10, 16], [23, 33]], [[9, 13], [23, 35]], [[8, 16], [24, 38]], [[5, 19], [27, 32]]] {0: {'battery_now': 80, 'battery_cycle': 30, 'energy_distance': [12, 28, 30, 14, 13, 31, 12, 20, 16, 34], 'travel_time': [27, 15, 13, 22, 36, 26, 16, 39, 36, 16], 'swap_schedule': {'assigned': True, 'battery_now': 80, 'battery_cycle': 30, 'battery_station': 3, 'slot': 0, 'energy_distance': 14, 'travel_time': 22, 'waiting_time': 8, 'exchanged_battery': 66, 'received_battery': 100, 'received_battery_cycle': 35}}, 1: {'battery_now': 91, 'battery_cycle': 60, 'energy_distance': [37, 21, 31, 28, 18, 17, 40, 23, 37, 13], 'travel_time': [38, 19, 12, 38, 37, 18, 11, 28, 13, 11], 'swap_schedule': {}}, 2: {'battery_now': 77, 'battery_cycle': 63, 'energy_distance': [39, 34, 23, 40, 17, 13, 30, 13, 40, 25], 'travel_time': [17, 36, 16, 40, 20, 35, 20, 24, 22, 27], 'swap_schedule': {}}, 3: {'battery_now': 62, 'battery_cycle': 68, 'energy_distance': [18, 10, 23, 37, 32, 32, 16, 19, 38, 25], 'travel_time': [12, 25, 10, 25, 28, 34, 21, 40, 25, 11], 'swap_schedule': {}}, 4: {'battery_now': 25, 'battery_cycle': 29, 'energy_distance': [14, 38, 23, 39, 10, 39, 33, 27, 27, 36], 'travel_time': [23, 21, 38, 15, 24, 29, 40, 17, 20, 32], 'swap_schedule': {}}, 5: {'battery_now': 28, 'battery_cycle': 82, 'energy_distance': [23, 24, 12, 40, 27, 19, 36, 13, 30, 25], 'travel_time': [29, 30, 31, 26, 40, 15, 16, 35, 21, 13], 'swap_schedule': {}}, 6: {'battery_now': 56, 'battery_cycle': 26, 'energy_distance': [30, 34, 19, 25, 32, 29, 40, 35, 36, 36], 'travel_time': [28, 19, 22, 31, 28, 20, 31, 18, 29, 37], 'swap_schedule': {}}, 7: {'battery_now': 77, 'battery_cycle': 64, 'energy_distance': [19, 28, 35, 12, 40, 20, 37, 18, 38, 32], 'travel_time': [17, 20, 20, 26, 28, 16, 11, 20, 10, 40], 'swap_schedule': {}}, 8: {'battery_now': 32, 'battery_cycle': 82, 'energy_distance': [21, 11, 18, 36, 31, 15, 11, 29, 15, 18], 'travel_time': [24, 35, 11, 35, 14, 18, 39, 37, 32, 39], 'swap_schedule': {}}, 9: {'battery_now': 33, 'battery_cycle': 28, 'energy_distance': [16, 16, 32, 31, 27, 10, 27, 24, 17, 20], 'travel_time': [13, 12, 26, 10, 12, 35, 34, 19, 13, 13], 'swap_schedule': {}}, 10: {'battery_now': 29, 'battery_cycle': 36, 'energy_distance': [25, 26, 23, 36, 23, 28, 30, 23, 22, 26], 'travel_time': [31, 26, 17, 32, 29, 12, 11, 32, 27, 11], 'swap_schedule': {}}, 11: {'battery_now': 57, 'battery_cycle': 73, 'energy_distance': [40, 28, 33, 22, 26, 24, 35, 29, 18, 16], 'travel_time': [33, 30, 16, 25, 21, 26, 24, 25, 25, 29], 'swap_schedule': {}}, 12: {'battery_now': 51, 'battery_cycle': 43, 'energy_distance': [27, 18, 14, 37, 27, 33, 38, 35, 29, 40], 'travel_time': [37, 31, 35, 12, 12, 27, 16, 11, 21, 28], 'swap_schedule': {}}, 13: {'battery_now': 48, 'battery_cycle': 34, 'energy_distance': [38, 14, 25, 15, 10, 23, 36, 15, 21, 11], 'travel_time': [23, 18, 36, 10, 29, 27, 29, 14, 16, 30], 'swap_schedule': {}}, 14: {'battery_now': 47, 'battery_cycle': 97, 'energy_distance': [16, 40, 26, 27, 36, 15, 25, 14, 22, 22], 'travel_time': [27, 37, 17, 28, 13, 30, 15, 35, 32, 38], 'swap_schedule': {}}, 15: {'battery_now': 90, 'battery_cycle': 53, 'energy_distance': [33, 39, 37, 32, 36, 10, 26, 22, 21, 37], 'travel_time': [17, 25, 25, 25, 23, 34, 28, 21, 26, 17], 'swap_schedule': {}}, 16: {'battery_now': 49, 'battery_cycle': 90, 'energy_distance': [28, 38, 18, 20, 30, 15, 29, 14, 21, 39], 'travel_time': [13, 39, 35, 33, 21, 21, 33, 30, 34, 23], 'swap_schedule': {}}, 17: {'battery_now': 81, 'battery_cycle': 81, 'energy_distance': [15, 21, 15, 19, 35, 25, 30, 27, 29, 19], 'travel_time': [35, 33, 37, 34, 38, 10, 13, 18, 26, 15], 'swap_schedule': {}}, 18: {'battery_now': 92, 'battery_cycle': 44, 'energy_distance': [25, 38, 14, 27, 29, 24, 35, 26, 24, 26], 'travel_time': [27, 20, 38, 13, 28, 13, 20, 26, 25, 20], 'swap_schedule': {}}, 19: {'battery_now': 64, 'battery_cycle': 75, 'energy ...
# Iter 1: Best Score = 181.3278
# Iter 2: Best Score = 184.6035
# Iter 3: Best Score = 184.6035
# Iter 4: Best Score = 184.6035
# Iter 5: Best Score = 184.6035
# Iter 6: Best Score = 185.7288
# Iter 7: Best Score = 187.2237
# Iter 8: Best Score = 187.2237
# Iter 9: Best Score = 187.2237
# Iter 10: Best Score = 187.2237
# Iter 11: Best Score = 187.2237
# Iter 12: Best Score = 187.2237
# Iter 13: Best Score = 187.2237
# Iter 14: Best Score = 187.2237
# Iter 15: Best Score = 187.2237
# Iter 16: Best Score = 187.2237
# Iter 17: Best Score = 187.2237
# Iter 18: Best Score = 187.2237
# Iter 19: Best Score = 187.2237
# Iter 20: Best Score = 187.2237
# Iter 21: Best Score = 187.2237
# Iter 22: Best Score = 187.2237
# Iter 23: Best Score = 187.2237
# Iter 24: Best Score = 187.2237
# Iter 25: Best Score = 187.2237
# Iter 26: Best Score = 187.2237
# Iter 27: Best Score = 187.2237
# Iter 28: Best Score = 187.258
# Iter 29: Best Score = 187.258
# Iter 30: Best Score = 187.258
# Iter 31: Best Score = 187.258
# Iter 32: Best Score = 187.258
# Iter 33: Best Score = 187.5799
# Iter 34: Best Score = 187.5799
# Iter 35: Best Score = 188.6786
# Iter 36: Best Score = 188.6786
# Iter 37: Best Score = 188.6786
# Iter 38: Best Score = 188.6786
# Iter 39: Best Score = 188.6786
# Iter 40: Best Score = 188.6786
# Iter 41: Best Score = 188.6786
# Iter 42: Best Score = 188.6786
# Iter 43: Best Score = 188.6786
# Iter 44: Best Score = 188.6786
# Iter 45: Best Score = 188.6786
# Iter 46: Best Score = 188.6786
# Iter 47: Best Score = 188.6786
# Iter 48: Best Score = 188.6786
# Iter 49: Best Score = 188.6786
# Iter 50: Best Score = 188.6786
# Iter 51: Best Score = 188.6786
# Iter 52: Best Score = 188.6786
# Iter 53: Best Score = 188.6786
# Iter 54: Best Score = 188.6786
# Iter 55: Best Score = 188.6786
# Iter 56: Best Score = 188.6786
# Iter 57: Best Score = 188.6786
# Iter 58: Best Score = 188.6786
# Iter 59: Best Score = 188.6786
# Iter 60: Best Score = 188.6786
# Iter 61: Best Score = 188.6786
# Iter 62: Best Score = 188.6786
# Iter 63: Best Score = 188.6786
# Iter 64: Best Score = 188.6786
# Iter 65: Best Score = 188.6786
# Iter 66: Best Score = 188.6786
# Iter 67: Best Score = 188.6786
# Iter 68: Best Score = 188.6786
# Iter 69: Best Score = 188.6786
# Iter 70: Best Score = 188.6786
# Iter 71: Best Score = 188.6786
# Iter 72: Best Score = 188.6786
# Iter 73: Best Score = 188.6786
# Iter 74: Best Score = 188.6786
# Iter 75: Best Score = 188.6786
# Iter 76: Best Score = 188.6786
# Iter 77: Best Score = 188.6786
# Iter 78: Best Score = 188.6786
# Iter 79: Best Score = 188.6786
# Iter 80: Best Score = 188.6786
# Iter 81: Best Score = 188.6786
# Iter 82: Best Score = 188.6786
# Iter 83: Best Score = 188.6786
# Iter 84: Best Score = 188.6786
# Iter 85: Best Score = 188.6786
# Iter 86: Best Score = 188.6786
# Iter 87: Best Score = 188.6786
# Iter 88: Best Score = 188.6786
# Iter 89: Best Score = 188.6786
# Iter 90: Best Score = 188.6786
# Iter 91: Best Score = 188.6786
# Iter 92: Best Score = 188.6786
# Iter 93: Best Score = 188.6786
# Iter 94: Best Score = 188.6786
# Iter 95: Best Score = 188.6786
# Iter 96: Best Score = 188.6786
# Iter 97: Best Score = 188.6786
# Iter 98: Best Score = 188.6786
# Iter 99: Best Score = 188.6786
# Iter 100: Best Score = 188.6786
# Iter 101: Best Score = 188.6786
# Iter 102: Best Score = 188.6786
# Iter 103: Best Score = 188.6786
# Iter 104: Best Score = 188.6786
# Iter 105: Best Score = 188.6786
# Iter 106: Best Score = 188.6786
# Iter 107: Best Score = 188.6786
# Iter 108: Best Score = 188.6786
# Iter 109: Best Score = 188.6786
# Iter 110: Best Score = 188.6786
# Iter 111: Best Score = 188.6786
# Iter 112: Best Score = 188.6786
# Iter 113: Best Score = 188.6786
# Iter 114: Best Score = 188.6786
# Iter 115: Best Score = 188.6786
# Iter 116: Best Score = 188.6786
# Iter 117: Best Score = 188.6786
# Iter 118: Best Score = 188.6786
# Iter 119: Best Score = 188.6786
# Iter 120: Best Score = 188.6786
# Iter 121: Best Score = 188.6786
# Iter 122: Best Score = 188.6786
# Iter 123: Best Score = 188.6786
# Iter 124: Best Score = 188.6786
# Iter 125: Best Score = 188.6786
# Iter 126: Best Score = 188.6786
# Iter 127: Best Score = 188.6786
# Iter 128: Best Score = 188.6786
# Iter 129: Best Score = 189.6579
# Iter 130: Best Score = 189.6579
# Iter 131: Best Score = 189.6579
# Iter 132: Best Score = 189.6579
# Iter 133: Best Score = 189.6579
# Iter 134: Best Score = 189.6579
# Iter 135: Best Score = 189.6579
# Iter 136: Best Score = 191.4755
# Iter 137: Best Score = 191.4755
# Iter 138: Best Score = 191.4755
# Iter 139: Best Score = 191.4755
# Iter 140: Best Score = 191.4755
# Iter 141: Best Score = 192.5203
# Iter 142: Best Score = 192.5203
# Iter 143: Best Score = 192.5203
# Iter 144: Best Score = 192.5203
# Iter 145: Best Score = 192.5203
# Iter 146: Best Score = 192.5203
# Iter 147: Best Score = 192.8188
# Iter 148: Best Score = 193.2213
# Iter 149: Best Score = 193.2213
# Iter 150: Best Score = 194.8724
# Iter 151: Best Score = 194.8724
# Iter 152: Best Score = 194.8724
# Iter 153: Best Score = 194.8724
# Iter 154: Best Score = 194.8724
# Iter 155: Best Score = 195.789
# Iter 156: Best Score = 195.789
# Iter 157: Best Score = 195.789
# Iter 158: Best Score = 195.789
# Iter 159: Best Score = 195.789
# Iter 160: Best Score = 195.789
# Iter 161: Best Score = 195.789
# Iter 162: Best Score = 195.789
# Iter 163: Best Score = 195.789
# Iter 164: Best Score = 195.8477
# Iter 165: Best Score = 195.8477
# Iter 166: Best Score = 196.253
# Iter 167: Best Score = 196.253
# Iter 168: Best Score = 196.253
# Iter 169: Best Score = 196.7407
# Iter 170: Best Score = 196.7407
# Iter 171: Best Score = 196.7407
# Iter 172: Best Score = 196.7407
# Iter 173: Best Score = 196.7407
# Iter 174: Best Score = 196.7407
# Iter 175: Best Score = 197.1714
# Iter 176: Best Score = 197.1714
# Iter 177: Best Score = 197.1714
# Iter 178: Best Score = 197.1714
# Iter 179: Best Score = 197.1714
# Iter 180: Best Score = 197.1714
# Iter 181: Best Score = 197.1714
# Iter 182: Best Score = 197.1714
# Iter 183: Best Score = 197.1714
# Iter 184: Best Score = 197.1714
# Iter 185: Best Score = 197.1714
# Iter 186: Best Score = 197.2105
# Iter 187: Best Score = 197.2105
# Iter 188: Best Score = 197.2105
# Iter 189: Best Score = 197.3174
# Iter 190: Best Score = 197.3174
# Iter 191: Best Score = 197.3174
# Iter 192: Best Score = 197.3174
# Iter 193: Best Score = 197.3174
# Iter 194: Best Score = 197.3174
# Iter 195: Best Score = 197.785
# Iter 196: Best Score = 197.785
# Iter 197: Best Score = 197.785
# Iter 198: Best Score = 197.785
# Iter 199: Best Score = 197.785
# Iter 200: Best Score = 197.785
# {0: {'assigned': True, 'battery_now': 80, 'battery_cycle': 30, 'battery_station': 3, 'slot': 0, 'energy_distance': 14, 'travel_time': 22, 'waiting_time': 8, 'exchanged_battery': 66, 'received_battery': 100, 'received_battery_cycle': 35}, 50: {'assigned': True, 'battery_now': 33, 'battery_cycle': 52, 'battery_station': 6, 'slot': 0, 'energy_distance': 37, 'travel_time': 20, 'waiting_time': 6, 'exchanged_battery': 0, 'received_battery': 88, 'received_battery_cycle': 55}, 100: {'assigned': True, 'battery_now': 71, 'battery_cycle': 31, 'battery_station': 3, 'slot': 1, 'energy_distance': 30, 'travel_time': 13, 'waiting_time': 14, 'exchanged_battery': 41, 'received_battery': 89, 'received_battery_cycle': 41}, 150: {'assigned': True, 'battery_now': 57, 'battery_cycle': 87, 'battery_station': 1, 'slot': 1, 'energy_distance': 26, 'travel_time': 30, 'waiting_time': 10, 'exchanged_battery': 31, 'received_battery': 82, 'received_battery_cycle': 11}, 200: {'assigned': True, 'battery_now': 48, 'battery_cycle': 66, 'battery_station': 8, 'slot': 0, 'energy_distance': 21, 'travel_time': 25, 'waiting_time': 15, 'exchanged_battery': 27, 'received_battery': 100, 'received_battery_cycle': 29}, 250: {'assigned': True, 'battery_now': 43, 'battery_cycle': 65, 'battery_station': 7, 'slot': 1, 'energy_distance': 13, 'travel_time': 40, 'waiting_time': 11, 'exchanged_battery': 30, 'received_battery': 100, 'received_battery_cycle': 98}, 300: {'assigned': True, 'battery_now': 63, 'battery_cycle': 91, 'battery_station': 4, 'slot': 1, 'energy_distance': 30, 'travel_time': 29, 'waiting_time': 10, 'exchanged_battery': 33, 'received_battery': 96, 'received_battery_cycle': 48}, 350: {'assigned': True, 'battery_now': 84, 'battery_cycle': 75, 'battery_station': 9, 'slot': 1, 'energy_distance': 40, 'travel_time': 14, 'waiting_time': 11, 'exchanged_battery': 44, 'received_battery': 80, 'received_battery_cycle': 64}, 400: {'assigned': True, 'battery_now': 60, 'battery_cycle': 80, 'battery_station': 3, 'slot': 1, 'energy_distance': 17, 'travel_time': 37, 'waiting_time': 13, 'exchanged_battery': 43, 'received_battery': 81, 'received_battery_cycle': 45}, 450: {'assigned': True, 'battery_now': 23, 'battery_cycle': 81, 'battery_station': 4, 'slot': 1, 'energy_distance': 31, 'travel_time': 32, 'waiting_time': 11, 'exchanged_battery': 0, 'received_battery': 83, 'received_battery_cycle': 69}, 500: {'assigned': True, 'battery_now': 43, 'battery_cycle': 35, 'battery_station': 0, 'slot': 0, 'energy_distance': 38, 'travel_time': 34, 'waiting_time': 15, 'exchanged_battery': 5, 'received_battery': 87, 'received_battery_cycle': 44}, 550: {'assigned': True, 'battery_now': 80, 'battery_cycle': 48, 'battery_station': 1, 'slot': 1, 'energy_distance': 39, 'travel_time': 18, 'waiting_time': 8, 'exchanged_battery': 41, 'received_battery': 100, 'received_battery_cycle': 7}, 600: {'assigned': True, 'battery_now': 71, 'battery_cycle': 33, 'battery_station': 8, 'slot': 0, 'energy_distance': 18, 'travel_time': 31, 'waiting_time': 14, 'exchanged_battery': 53, 'received_battery': 97, 'received_battery_cycle': 74}, 650: {'assigned': True, 'battery_now': 96, 'battery_cycle': 44, 'battery_station': 1, 'slot': 1, 'energy_distance': 12, 'travel_time': 27, 'waiting_time': 13, 'exchanged_battery': 84, 'received_battery': 84, 'received_battery_cycle': 98}, 700: {'assigned': True, 'battery_now': 27, 'battery_cycle': 96, 'battery_station': 9, 'slot': 1, 'energy_distance': 10, 'travel_time': 17, 'waiting_time': 13, 'exchanged_battery': 17, 'received_battery': 100, 'received_battery_cycle': 82}, 750: {'assigned': True, 'battery_now': 81, 'battery_cycle': 41, 'battery_station': 4, 'slot': 0, 'energy_distance': 17, 'travel_time': 19, 'waiting_time': 6, 'exchanged_battery': 64, 'received_battery': 100, 'received_battery_cycle': 60}, 800: {'assigned': True, 'battery_now': 87, 'battery_cycle': 75, 'battery_station': 9, 'slot': 1, 'energy_distance': 36, 'travel_time': 16, 'waiting_time': 6, 'exchanged_battery': 5 ...
# 197.78501571213133

# %%
import time
import numpy as np
import matplotlib.pyplot as plt


def plot_distributions(initial_temp=100, num_of_cycle=100, runs=1000, max_attempts=1000):
    """
    Run the Simulated Annealing algorithm multiple times and plot distributions of 
    both fitness values and computation times.
    
    Parameters:
    - initial_temp: Initial temperature
    - num_of_cycle: Number of cycles after which temperature becomes 0
    - runs: Number of independent runs
    - max_attempts: Maximum number of attempts to find a valid solution
    
    Returns:
    - mean_fitness: Mean fitness across all valid runs
    - std_fitness: Standard deviation of fitness across all valid runs
    - mean_duration: Mean computation time across all runs (in seconds)
    - std_duration: Standard deviation of computation time across all runs (in seconds)
    """
    fitness_values = []
    duration_values = []
    valid_runs = 0
    
    print(f"Running {runs} trials of simulated annealing...")
    
    for i in range(runs):
        if i % 100 == 0 and i > 0:
            print(f"Completed {i} runs...")
            
        start_time = time.time()
        
        solution, fitness = simulated_annealing_strategy(
            battery_swap_station_demo,
            ev_demo,
            threshold=15,
            charging_rate=100/240,
            initial_temp=initial_temp,
            alpha=0.95,
            T_min=0.001,
            max_iter=200
        )
        
        end_time = time.time()
        duration = end_time - start_time
        duration_values.append(duration)
        
        if solution is not None and fitness is not None:
            fitness_values.append(fitness)
            valid_runs += 1
    
    # Print summary
    print(f"Valid solutions: {valid_runs}/{runs} ({valid_runs/runs*100:.2f}%)")
    
    # 1. PLOT FITNESS DISTRIBUTION
    if fitness_values:
        # Calculate fitness statistics
        mean_fitness = np.mean(fitness_values)
        std_fitness = np.std(fitness_values)
        
        # Plot fitness distribution
        plt.figure(figsize=(8, 6))
        plt.hist(fitness_values, bins=20, edgecolor='black')
        plt.axvline(mean_fitness, linestyle='--', label=f'Mean = {mean_fitness:.2f}')
        plt.axvline(mean_fitness + std_fitness, color='gray', linestyle=':', 
                    label=f'+1 Std = {std_fitness:.2f}')
        plt.axvline(mean_fitness - std_fitness, color='gray', linestyle=':', 
                    label=f'-1 Std = {std_fitness:.2f}')
        plt.title('Distribution of Best Fitness over {} Runs'.format(valid_runs))
        plt.xlabel('Fitness')
        plt.ylabel('Frequency')
        plt.legend()
        plt.tight_layout()
        plt.show()
        
        print(f"Mean fitness: {mean_fitness:.4f}")
        print(f"Std deviation of fitness: {std_fitness:.4f}")
    else:
        mean_fitness = None
        std_fitness = None
        print("No valid solutions found to plot fitness distribution")
    
    # 2. PLOT DURATION DISTRIBUTION
    if duration_values:
        # Calculate duration statistics
        mean_duration = np.mean(duration_values)
        std_duration = np.std(duration_values)
        
        # Plot duration distribution
        plt.figure(figsize=(8, 6))
        plt.hist(duration_values, bins=20, edgecolor='black')
        plt.axvline(mean_duration, linestyle='--', label=f'Mean = {mean_duration:.4f}s')
        plt.axvline(mean_duration + std_duration, color='gray', linestyle=':', 
                    label=f'+1 Std = {std_duration:.4f}s')
        plt.axvline(mean_duration - std_duration, color='gray', linestyle=':', 
                    label=f'-1 Std = {std_duration:.4f}s')
        plt.title('Distribution of Computation Time over {} Runs'.format(runs))
        plt.xlabel('Time (seconds)')
        plt.ylabel('Frequency')
        plt.legend()
        plt.tight_layout()
        plt.show()
        
        print(f"Mean computation time: {mean_duration:.4f} seconds")
        print(f"Std deviation of time: {std_duration:.4f} seconds")
    else:
        mean_duration = None
        std_duration = None
        print("No runs completed to plot duration distribution")
    
    return mean_fitness, std_fitness, mean_duration, std_duration

# %%
plot_distributions(initial_temp=100, num_of_cycle=300, runs=100, max_attempts=10)
# Out:
# Running 100 trials of simulated annealing...
# Iter 1: Best Score = 177.7315
# Iter 2: Best Score = 177.7315
# Iter 3: Best Score = 177.7315
# Iter 4: Best Score = 177.7315
# Iter 5: Best Score = 177.7315
# Iter 6: Best Score = 177.7315
# Iter 7: Best Score = 177.7315
# Iter 8: Best Score = 177.7315
# Iter 9: Best Score = 177.7315
# Iter 10: Best Score = 177.7315
# Iter 11: Best Score = 177.7315
# Iter 12: Best Score = 177.7315
# Iter 13: Best Score = 177.7315
# Iter 14: Best Score = 177.7315
# Iter 15: Best Score = 177.7315
# Iter 16: Best Score = 177.7315
# Iter 17: Best Score = 177.7315
# Iter 18: Best Score = 177.7315
# Iter 19: Best Score = 177.7315
# Iter 20: Best Score = 177.7315
# Iter 21: Best Score = 177.7315
# Iter 22: Best Score = 177.7315
# Iter 23: Best Score = 177.7315
# Iter 24: Best Score = 177.7315
# Iter 25: Best Score = 177.7315
# Iter 26: Best Score = 177.7315
# Iter 27: Best Score = 177.7315
# Iter 28: Best Score = 178.8194
# Iter 29: Best Score = 178.8194
# Iter 30: Best Score = 178.8194
# Iter 31: Best Score = 178.8194
# Iter 32: Best Score = 178.8194
# Iter 33: Best Score = 178.8194
# Iter 34: Best Score = 178.8194
# Iter 35: Best Score = 178.8194
# Iter 36: Best Score = 178.8194
# Iter 37: Best Score = 178.8194
# Iter 38: Best Score = 178.8194
# Iter 39: Best Score = 178.8194
# Iter 40: Best Score = 178.8194
# Iter 41: Best Score = 178.8194
# Iter 42: Best Score = 178.8194
# Iter 43: Best Score = 178.8194
# Iter 44: Best Score = 178.8194
# Iter 45: Best Score = 178.8194
# Iter 46: Best Score = 178.8194
# Iter 47: Best Score = 178.8194
# Iter 48: Best Score = 178.8194
# Iter 49: Best Score = 178.8194
# Iter 50: Best Score = 178.8194
# Iter 51: Best Score = 178.8194
# Iter 52: Best Score = 178.8194
# Iter 53: Best Score = 178.8194
# Iter 54: Best Score = 178.8194
# Iter 55: Best Score = 178.8194
# Iter 56: Best Score = 178.8194
# Iter 57: Best Score = 178.8194
# Iter 58: Best Score = 178.8194
# Iter 59: Best Score = 178.8194
# Iter 60: Best Score = 178.8194
# Iter 61: Best Score = 178.8194
# Iter 62: Best Score = 178.8194
# Iter 63: Best Score = 178.8194
# Iter 64: Best Score = 178.8194
# Iter 65: Best Score = 178.8194
# Iter 66: Best Score = 178.8194
# Iter 67: Best Score = 178.8194
# Iter 68: Best Score = 178.8194
# Iter 69: Best Score = 178.8194
# Iter 70: Best Score = 178.8194
# Iter 71: Best Score = 178.8194
# Iter 72: Best Score = 179.0643
# Iter 73: Best Score = 179.0643
# Iter 74: Best Score = 180.6992
# Iter 75: Best Score = 180.6992
# Iter 76: Best Score = 180.6992
# Iter 77: Best Score = 180.6992
# Iter 78: Best Score = 180.6992
# Iter 79: Best Score = 180.6992
# Iter 80: Best Score = 180.6992
# Iter 81: Best Score = 180.6992
# Iter 82: Best Score = 180.6992
# Iter 83: Best Score = 180.6992
# Iter 84: Best Score = 181.1232
# Iter 85: Best Score = 181.1232
# Iter 86: Best Score = 181.1232
# Iter 87: Best Score = 181.1232
# Iter 88: Best Score = 181.1232
# Iter 89: Best Score = 181.1232
# Iter 90: Best Score = 181.1232
# Iter 91: Best Score = 181.1232
# Iter 92: Best Score = 181.1232
# Iter 93: Best Score = 181.1232
# Iter 94: Best Score = 181.1232
# Iter 95: Best Score = 181.1232
# Iter 96: Best Score = 182.471
# Iter 97: Best Score = 182.5132
# Iter 98: Best Score = 182.5132
# Iter 99: Best Score = 182.5132
# Iter 100: Best Score = 182.5132
# Iter 101: Best Score = 182.5132
# Iter 102: Best Score = 183.6025
# Iter 103: Best Score = 183.6025
# Iter 104: Best Score = 184.7843
# Iter 105: Best Score = 184.7843
# Iter 106: Best Score = 186.3329
# Iter 107: Best Score = 186.3329
# Iter 108: Best Score = 186.3329
# Iter 109: Best Score = 186.5828
# Iter 110: Best Score = 186.5828
# Iter 111: Best Score = 186.5828
# Iter 112: Best Score = 188.26
# Iter 113: Best Score = 188.26
# Iter 114: Best Score = 188.26
# Iter 115: Best Score = 188.26
# Iter 116: Best Score = 189.3329
# Iter 117: Best Score = 189.3329
# Iter 118: Best Score = 189.3329
# Iter 119: Best Score = 189.3329
# Iter 120: Best Score = 189.3329
# Iter 121: Best Score = 189.3329
# Iter 122: Best Score = 189.3329
# Iter 123: Best Score = 189.6312
# Iter 124: Best Score = 190.0403
# Iter 125: Best Score = 190.6069
# Iter 126: Best Score = 190.8524
# Iter 127: Best Score = 190.8524
# Iter 128: Best Score = 190.8524
# Iter 129: Best Score = 191.9963
# Iter 130: Best Score = 191.9963
# Iter 131: Best Score = 191.9963
# Iter 132: Best Score = 191.9963
# Iter 133: Best Score = 191.9963
# Iter 134: Best Score = 191.9963
# Iter 135: Best Score = 191.9963
# Iter 136: Best Score = 191.9963
# Iter 137: Best Score = 191.9963
# Iter 138: Best Score = 191.9963
# Iter 139: Best Score = 191.9963
# Iter 140: Best Score = 191.9963
# Iter 141: Best Score = 191.9963
# Iter 142: Best Score = 191.9963
# Iter 143: Best Score = 191.9963
# Iter 144: Best Score = 191.9963
# Iter 145: Best Score = 191.9963
# Iter 146: Best Score = 191.9963
# Iter 147: Best Score = 192.525
# Iter 148: Best Score = 192.525
# Iter 149: Best Score = 192.525
# Iter 150: Best Score = 192.525
# Iter 151: Best Score = 192.5742
# Iter 152: Best Score = 192.5742
# Iter 153: Best Score = 192.5742
# Iter 154: Best Score = 192.5742
# Iter 155: Best Score = 193.4341
# Iter 156: Best Score = 193.7446
# Iter 157: Best Score = 193.7446
# Iter 158: Best Score = 193.7446
# Iter 159: Best Score = 195.3292
# Iter 160: Best Score = 195.3292
# Iter 161: Best Score = 195.3292
# Iter 162: Best Score = 195.3292
# Iter 163: Best Score = 195.3292
# Iter 164: Best Score = 195.6064
# Iter 165: Best Score = 195.6064
# Iter 166: Best Score = 195.6064
# Iter 167: Best Score = 195.6814
# Iter 168: Best Score = 195.6835
# Iter 169: Best Score = 196.5684
# Iter 170: Best Score = 196.5684
# Iter 171: Best Score = 196.5684
# Iter 172: Best Score = 196.5684
# Iter 173: Best Score = 196.5684
# Iter 174: Best Score = 196.5684
# Iter 175: Best Score = 196.5684
# Iter 176: Best Score = 196.5684
# Iter 177: Best Score = 196.5684
# Iter 178: Best Score = 196.5684
# Iter 179: Best Score = 196.5684
# Iter 180: Best Score = 196.6403
# Iter 181: Best Score = 196.6871
# Iter 182: Best Score = 196.6871
# Iter 183: Best Score = 197.036
# Iter 184: Best Score = 197.036
# Iter 185: Best Score = 197.036
# Iter 186: Best Score = 197.036
# Iter 187: Best Score = 197.036
# Iter 188: Best Score = 197.036
# Iter 189: Best Score = 197.036
# Iter 190: Best Score = 197.1406
# Iter 191: Best Score = 197.1406
# Iter 192: Best Score = 197.1406
# Iter 193: Best Score = 197.1406
# Iter 194: Best Score = 197.1406
# Iter 195: Best Score = 197.5913
# Iter 196: Best Score = 197.5913
# Iter 197: Best Score = 197.5913
# Iter 198: Best Score = 197.7444
# Iter 199: Best Score = 197.7444
# Iter 200: Best Score = 197.7444
# Iter 1: Best Score = 175.0005
# Iter 2: Best Score = 175.0005
# Iter 3: Best Score = 175.0005
# Iter 4: Best Score = 175.8037
# Iter 5: Best Score = 180.3785
# Iter 6: Best Score = 180.3785
# Iter 7: Best Score = 181.0245
# Iter 8: Best Score = 181.0245
# Iter 9: Best Score = 181.0245
# Iter 10: Best Score = 181.0245
# Iter 11: Best Score = 181.0245
# Iter 12: Best Score = 181.0245
# Iter 13: Best Score = 181.0245
# Iter 14: Best Score = 181.0245
# Iter 15: Best Score = 181.0245
# Iter 16: Best Score = 181.0245
# Iter 17: Best Score = 181.0245
# Iter 18: Best Score = 181.0245
# Iter 19: Best Score = 181.0245
# Iter 20: Best Score = 181.0245
# Iter 21: Best Score = 181.0245
# Iter 22: Best Score = 181.0245
# Iter 23: Best Score = 181.0245
# Iter 24: Best Score = 181.0245
# Iter 25: Best Score = 181.0245
# Iter 26: Best Score = 181.0245
# Iter 27: Best Score = 181.0245
# Iter 28: Best Score = 181.0245
# Iter 29: Best Score = 181.0245
# Iter 30: Best Score = 181.0245
# Iter 31: Best Score = 181.0245
# Iter 32: Best Score = 181.0245
# Iter 33: Best Score = 181.0245
# Iter 34: Best Score = 181.0245
# Iter 35: Best Score = 181.0245
# Iter 36: Best Score = 181.0245
# Iter 37: Best Score = 181.0245
# Iter 38: Best Score = 181.0245
# Iter 39: Best Score = 181.0245
# Iter 40: Best Score = 181.0245
# Iter 41: Best Score = 181.0245
# Iter 42: Best Score = 181.0245
# Iter 43: Best Score = 181.0245
# Iter 44: Best Score = 181.0245
# Iter 45: Best Score = 181.0245
# Iter 46: Best Score = 181.0245
# Iter 47: Best Score = 181.0245
# Iter 48: Best Score = 181.0245
# Iter 49: Best Score = 181.0245
# Iter 50: Best Score = 181.0245
# Iter 51: Best Score = 181.0245
# Iter 52: Best Score = 181.0245
# Iter 53: Best Score = 181.0245
# Iter 54: Best Score = 181.0245
# Iter 55: Best Score = 181.0245
# Iter 56: Best Score = 181.0245
# Iter 57: Best Score = 181.0245
# Iter 58: Best Score = 181.0245
# Iter 59: Best Score = 181.0245
# Iter 60: Best Score = 181.0245
# Iter 61: Best Score = 181.0245
# Iter 62: Best Score = 181.0245
# Iter 63: Best Score = 181.0245
# Iter 64: Best Score = 181.0245
# Iter 65: Best Score = 181.0245
# Iter 66: Best Score = 181.0245
# Iter 67: Best Score = 181.0245
# Iter 68: Best Score = 181.0245
# Iter 69: Best Score = 181.0245
# Iter 70: Best Score = 181.0245
# Iter 71: Best Score = 181.0245
# Iter 72: Best Score = 181.0245
# Iter 73: Best Score = 181.0245
# Iter 74: Best Score = 181.0245
# Iter 75: Best Score = 181.0245
# Iter 76: Best Score = 181.0245
# Iter 77: Best Score = 181.0245
# Iter 78: Best Score = 181.0245
# Iter 79: Best Score = 181.0245
# Iter 80: Best Score = 181.0245
# Iter 81: Best Score = 181.0245
# Iter 82: Best Score = 181.0245
# Iter 83: Best Score = 181.0245
# Iter 84: Best Score = 181.0245
# Iter 85: Best Score = 181.0245
# Iter 86: Best Score = 181.0245
# Iter 87: Best Score = 181.0245
# Iter 88: Best Score = 181.0245
# Iter 89: Best Score = 181.0245
# Iter 90: Best Score = 181.0245
# Iter 91: Best Score = 181.0245
# Iter 92: Best Score = 181.0245
# Iter 93: Best Score = 181.0245
# Iter 94: Best Score = 181.0245
# Iter 95: Best Score = 181.0245
# Iter 96: Best Score = 181.0245
# Iter 97: Best Score = 181.0245
# Iter 98: Best Score = 181.0245
# Iter 99: Best Score = 181.0245
# Iter 100: Best Score = 181.0245
# Iter 101: Best Score = 181.0245
# Iter 102: Best Score = 181.0245
# Iter 103: Best Score = 181.0245
# Iter 104: Best Score = 181.0245
# Iter 105: Best Score = 181.0245
# Iter 106: Best Score = 181.0245
# Iter 107: Best Score = 181.0245
# Iter 108: Best Score = 181.0245
# Iter 109: Best Score = 181.0245
# Iter 110: Best Score = 181.0245
# Iter 111: Best Score = 181.0245
# Iter 112: Best Score = 181.0245
# Iter 113: Best Score = 181.0245
# Iter 114: Best Score = 181.0245
# Iter 115: Best Score = 181.0245
# Iter 116: Best Score = 181.0245
# Iter 117: Best Score = 181.0245
# Iter 118: Best Score = 181.0245
# Iter 119: Best Score = 181.0245
# Iter 120: Best Score = 181.0245
# Iter 121: Best Score = 181.0245
# Iter 122: Best Score = 181.0245
# Iter 123: Best Score = 181.0245
# Iter 124: Best Score = 181.0245
# Iter 125: Best Score = 181.0245
# Iter 126: Best Score = 181.0245
# Iter 127: Best Score = 181.0245
# Iter 128: Best Score = 181.0245
# Iter 129: Best Score = 181.0245
# Iter 130: Best Score = 181.0245
# Iter 131: Best Score = 181.0245
# Iter 132: Best Score = 181.0245
# Iter 133: Best Score = 181.0245
# Iter 134: Best Score = 181.0245
# Iter 135: Best Score = 181.0245
# Iter 136: Best Score = 181.0245
# Iter 137: Best Score = 181.0245
# Iter 138: Best Score = 181.0245
# Iter 139: Best Score = 181.0245
# Iter 140: Best Score = 181.0245
# Iter 141: Best Score = 181.0245
# Iter 142: Best Score = 181.0245
# Iter 143: Best Score = 181.0245
# Iter 144: Best Score = 181.0245
# Iter 145: Best Score = 182.3962
# Iter 146: Best Score = 182.3962
# Iter 147: Best Score = 182.3962
# Iter 148: Best Score = 182.3962
# Iter 149: Best Score = 182.5021
# Iter 150: Best Score = 182.9236
# Iter 151: Best Score = 182.9236
# Iter 152: Best Score = 182.9236
# Iter 153: Best Score = 182.9236
# Iter 154: Best Score = 182.9236
# Iter 155: Best Score = 183.7173
# Iter 156: Best Score = 184.2693
# Iter 157: Best Score = 184.2693
# Iter 158: Best Score = 184.7386
# Iter 159: Best Score = 184.7386
# Iter 160: Best Score = 184.7386
# Iter 161: Best Score = 184.7386
# Iter 162: Best Score = 184.7386
# Iter 163: Best Score = 184.7386
# Iter 164: Best Score = 184.7386
# Iter 165: Best Score = 184.7386
# Iter 166: Best Score = 184.7386
# Iter 167: Best Score = 184.7386
# Iter 168: Best Score = 184.7386
# Iter 169: Best Score = 184.7386
# Iter 170: Best Score = 184.7386
# Iter 171: Best Score = 184.7386
# Iter 172: Best Score = 184.7386
# Iter 173: Best Score = 185.1244
# Iter 174: Best Score = 185.1244
# Iter 175: Best Score = 186.8305
# Iter 176: Best Score = 187.1613
# Iter 177: Best Score = 189.0693
# Iter 178: Best Score = 189.0693
# Iter 179: Best Score = 189.0693
# Iter 180: Best Score = 189.0693
# Iter 181: Best Score = 190.9744
# Iter 182: Best Score = 190.9744
# Iter 183: Best Score = 190.9744
# Iter 184: Best Score = 190.9744
# Iter 185: Best Score = 190.9744
# Iter 186: Best Score = 191.4653
# Iter 187: Best Score = 191.4653
# Iter 188: Best Score = 191.4653
# Iter 189: Best Score = 191.4653
# Iter 190: Best Score = 191.9379
# Iter 191: Best Score = 191.9379
# Iter 192: Best Score = 192.3033
# Iter 193: Best Score = 192.3684
# Iter 194: Best Score = 192.3684
# Iter 195: Best Score = 192.3684
# Iter 196: Best Score = 193.2757
# Iter 197: Best Score = 193.2757
# Iter 198: Best Score = 193.2757
# Iter 199: Best Score = 193.2757
# Iter 200: Best Score = 193.2757
# Iter 1: Best Score = 157.0295
# Iter 2: Best Score = 157.5706
# Iter 3: Best Score = 159.0781
# Iter 4: Best Score = 159.0781
# Iter 5: Best Score = 159.0781
# Iter 6: Best Score = 159.0781
# Iter 7: Best Score = 159.0781
# Iter 8: Best Score = 159.0781
# Iter 9: Best Score = 159.0781
# Iter 10: Best Score = 159.9563
# Iter 11: Best Score = 159.9563
# Iter 12: Best Score = 159.9563
# Iter 13: Best Score = 162.9369
# Iter 14: Best Score = 162.9369
# Iter 15: Best Score = 162.9369
# Iter 16: Best Score = 162.9369
# Iter 17: Best Score = 162.9369
# Iter 18: Best Score = 164.4289
# Iter 19: Best Score = 169.1857
# Iter 20: Best Score = 171.3673
# Iter 21: Best Score = 172.2715
# Iter 22: Best Score = 172.2715
# Iter 23: Best Score = 172.2715
# Iter 24: Best Score = 172.2715
# Iter 25: Best Score = 172.3548
# Iter 26: Best Score = 172.3548
# Iter 27: Best Score = 173.4905
# Iter 28: Best Score = 173.4905
# Iter 29: Best Score = 173.4905
# Iter 30: Best Score = 173.4905
# Iter 31: Best Score = 174.3411
# Iter 32: Best Score = 174.3411
# Iter 33: Best Score = 174.3411
# Iter 34: Best Score = 174.3411
# Iter 35: Best Score = 174.3411
# Iter 36: Best Score = 174.3411
# Iter 37: Best Score = 174.3411
# Iter 38: Best Score = 174.3411
# Iter 39: Best Score = 174.3411
# Iter 40: Best Score = 174.3411
# Iter 41: Best Score = 174.3411
# Iter 42: Best Score = 174.3411
# Iter 43: Best Score = 174.3411
# Iter 44: Best Score = 174.3411
# Iter 45: Best Score = 174.3411
# Iter 46: Best Score = 174.3411
# Iter 47: Best Score = 174.3411
# Iter 48: Best Score = 174.3411
# Iter 49: Best Score = 174.3517
# Iter 50: Best Score = 174.3517
# Iter 51: Best Score = 174.3517
# Iter 52: Best Score = 174.3517
# Iter 53: Best Score = 174.3517
# Iter 54: Best Score = 174.3517
# Iter 55: Best Score = 174.3517
# Iter 56: Best Score = 174.3517
# Iter 57: Best Score = 176.1703
# Iter 58: Best Score = 176.1703
# Iter 59: Best Score = 176.1703
# Iter 60: Best Score = 176.1703
# Iter 61: Best Score = 176.1703
# Iter 62: Best Score = 176.1703
# Iter 63: Best Score = 176.1703
# Iter 64: Best Score = 176.1703
# Iter 65: Best Score = 176.1703
# Iter 66: Best Score = 176.1703
# Iter 67: Best Score = 176.1703
# Iter 68: Best Score = 176.1703
# Iter 69: Best Score = 176.1703
# Iter 70: Best Score = 176.1703
# Iter 71: Best Score = 176.1703
# Iter 72: Best Score = 176.1703
# Iter 73: Best Score = 176.1703
# Iter 74: Best Score = 176.1703
# Iter 75: Best Score = 176.1703
# Iter 76: Best Score = 176.1703
# Iter 77: Best Score = 176.1703
# Iter 78: Best Score = 176.1703
# Iter 79: Best Score = 176.1703
# Iter 80: Best Score = 176.1703
# Iter 81: Best Score = 177.0278
# Iter 82: Best Score = 177.6682
# Iter 83: Best Score = 177.6682
# Iter 84: Best Score = 177.8496
# Iter 85: Best Score = 177.8496
# Iter 86: Best Score = 177.8496
# Iter 87: Best Score = 177.8496
# Iter 88: Best Score = 177.8496
# Iter 89: Best Score = 177.8496
# Iter 90: Best Score = 177.8496
# Iter 91: Best Score = 178.1945
# Iter 92: Best Score = 180.7292
# Iter 93: Best Score = 180.7292
# Iter 94: Best Score = 180.7292
# Iter 95: Best Score = 181.9947
# Iter 96: Best Score = 183.2693
# Iter 97: Best Score = 183.7336
# Iter 98: Best Score = 183.7336
# Iter 99: Best Score = 183.7336
# Iter 100: Best Score = 183.7336
# Iter 101: Best Score = 183.7336
# Iter 102: Best Score = 184.3271
# Iter 103: Best Score = 184.3271
# Iter 104: Best Score = 184.3271
# Iter 105: Best Score = 185.6817
# Iter 106: Best Score = 185.6817
# Iter 107: Best Score = 185.6817
# Iter 108: Best Score = 185.6817
# Iter 109: Best Score = 185.6817
# Iter 110: Best Score = 185.6817
# Iter 111: Best Score = 185.6817
# Iter 112: Best Score = 186.5007
# Iter 113: Best Score = 186.5007
# Iter 114: Best Score = 186.5007
# Iter 115: Best Score = 186.5722
# Iter 116: Best Score = 188.2959
# Iter 117: Best Score = 188.2959
# Iter 118: Best Score = 188.2959
# Iter 119: Best Score = 189.9676
# Iter 120: Best Score = 189.9676
# Iter 121: Best Score = 190.3395
# Iter 122: Best Score = 190.3395
# Iter 123: Best Score = 190.3395
# Iter 124: Best Score = 191.9565
# Iter 125: Best Score = 191.9565
# Iter 126: Best Score = 191.9565
# Iter 127: Best Score = 191.9565
# Iter 128: Best Score = 191.9565
# Iter 129: Best Score = 192.7056
# Iter 130: Best Score = 192.7056
# Iter 131: Best Score = 192.7056
# Iter 132: Best Score = 193.7423
# Iter 133: Best Score = 193.7423
# Iter 134: Best Score = 193.7423
# Iter 135: Best Score = 193.7423
# Iter 136: Best Score = 193.7423
# Iter 137: Best Score = 193.7423
# Iter 138: Best Score = 193.7423
# Iter 139: Best Score = 193.7423
# Iter 140: Best Score = 193.7423
# Iter 141: Best Score = 194.3666
# Iter 142: Best Score = 194.4943
# Iter 143: Best Score = 194.4943
# Iter 144: Best Score = 194.4943
# Iter 145: Best Score = 195.7914
# Iter 146: Best Score = 195.7914
# Iter 147: Best Score = 195.7914
# Iter 148: Best Score = 195.7914
# Iter 149: Best Score = 195.7914
# Iter 150: Best Score = 195.7914
# Iter 151: Best Score = 195.7914
# Iter 152: Best Score = 195.8617
# Iter 153: Best Score = 196.7032
# Iter 154: Best Score = 197.5541
# Iter 155: Best Score = 197.5541
# Iter 156: Best Score = 197.5541
# Iter 157: Best Score = 198.0344
# Iter 158: Best Score = 198.0344
# Iter 159: Best Score = 198.0344
# Iter 160: Best Score = 198.0344
# Iter 161: Best Score = 198.0344
# Iter 162: Best Score = 198.0344
# Iter 163: Best Score = 198.0344
# Iter 164: Best Score = 198.0344
# Iter 165: Best Score = 198.0344
# Iter 166: Best Score = 198.0344
# Iter 167: Best Score = 198.0344
# Iter 168: Best Score = 198.0344
# Iter 169: Best Score = 198.0344
# Iter 170: Best Score = 198.0344
# Iter 171: Best Score = 198.0344
# Iter 172: Best Score = 198.0344
# Iter 173: Best Score = 198.0344
# Iter 174: Best Score = 198.0344
# Iter 175: Best Score = 198.0344
# Iter 176: Best Score = 198.0344
# Iter 177: Best Score = 198.4434
# Iter 178: Best Score = 198.4434
# Iter 179: Best Score = 198.4434
# Iter 180: Best Score = 198.4434
# Iter 181: Best Score = 198.4434
# Iter 182: Best Score = 198.4434
# Iter 183: Best Score = 198.4434
# Iter 184: Best Score = 198.4434
# Iter 185: Best Score = 198.9163
# Iter 186: Best Score = 198.9163
# Iter 187: Best Score = 198.9515
# Iter 188: Best Score = 198.9515
# Iter 189: Best Score = 198.9515
# Iter 190: Best Score = 198.9515
# Iter 191: Best Score = 198.9515
# Iter 192: Best Score = 198.9515
# Iter 193: Best Score = 198.9515
# Iter 194: Best Score = 198.9515
# Iter 195: Best Score = 198.9515
# Iter 196: Best Score = 198.9515
# Iter 197: Best Score = 198.9515
# Iter 198: Best Score = 198.9515
# Iter 199: Best Score = 198.9515
# Iter 200: Best Score = 198.9515
# Iter 1: Best Score = 175.5481
# Iter 2: Best Score = 175.5481
# Iter 3: Best Score = 175.5481
# Iter 4: Best Score = 176.3398
# Iter 5: Best Score = 176.3398
# Iter 6: Best Score = 177.104
# Iter 7: Best Score = 178.8026
# Iter 8: Best Score = 178.8026
# Iter 9: Best Score = 178.8026
# Iter 10: Best Score = 178.8026
# Iter 11: Best Score = 178.8026
# Iter 12: Best Score = 178.8026
# Iter 13: Best Score = 179.8043
# Iter 14: Best Score = 179.8043
# Iter 15: Best Score = 179.8043
# Iter 16: Best Score = 180.2752
# Iter 17: Best Score = 180.2752
# Iter 18: Best Score = 182.1876
# Iter 19: Best Score = 182.1876
# Iter 20: Best Score = 182.1876
# Iter 21: Best Score = 182.1876
# Iter 22: Best Score = 182.1876
# Iter 23: Best Score = 182.1876
# Iter 24: Best Score = 182.1876
# Iter 25: Best Score = 182.1876
# Iter 26: Best Score = 182.1876
# Iter 27: Best Score = 182.1876
# Iter 28: Best Score = 182.1876
# Iter 29: Best Score = 182.1876
# Iter 30: Best Score = 182.1876
# Iter 31: Best Score = 182.1876
# Iter 32: Best Score = 182.1876
# Iter 33: Best Score = 182.1876
# Iter 34: Best Score = 182.1876
# Iter 35: Best Score = 182.1876
# Iter 36: Best Score = 182.1876
# Iter 37: Best Score = 182.1876
# Iter 38: Best Score = 182.1876
# Iter 39: Best Score = 182.1876
# Iter 40: Best Score = 182.1876
# Iter 41: Best Score = 182.1876
# Iter 42: Best Score = 182.1876
# Iter 43: Best Score = 182.1876
# Iter 44: Best Score = 182.1876
# Iter 45: Best Score = 182.1876
# Iter 46: Best Score = 182.1876
# Iter 47: Best Score = 182.1876
# Iter 48: Best Score = 182.1876
# Iter 49: Best Score = 182.1876
# Iter 50: Best Score = 182.1876
# Iter 51: Best Score = 182.1876
# Iter 52: Best Score = 182.1876
# Iter 53: Best Score = 182.1876
# Iter 54: Best Score = 182.1876
# Iter 55: Best Score = 182.1876
# Iter 56: Best Score = 182.1876
# Iter 57: Best Score = 182.1876
# Iter 58: Best Score = 182.1876
# Iter 59: Best Score = 182.1876
# Iter 60: Best Score = 182.1876
# Iter 61: Best Score = 182.1876
# Iter 62: Best Score = 182.1876
# Iter 63: Best Score = 182.1876
# Iter 64: Best Score = 182.1876
# Iter 65: Best Score = 182.1876
# Iter 66: Best Score = 182.1876
# Iter 67: Best Score = 182.1876
# Iter 68: Best Score = 182.1876
# Iter 69: Best Score = 182.1876
# Iter 70: Best Score = 182.1876
# Iter 71: Best Score = 182.1876
# Iter 72: Best Score = 182.1876
# Iter 73: Best Score = 182.1876
# Iter 74: Best Score = 182.1876
# Iter 75: Best Score = 182.1876
# Iter 76: Best Score = 182.1876
# Iter 77: Best Score = 182.1876
# Iter 78: Best Score = 182.1876
# Iter 79: Best Score = 182.1876
# Iter 80: Best Score = 182.1876
# Iter 81: Best Score = 182.1876
# Iter 82: Best Score = 182.1876
# Iter 83: Best Score = 182.1876
# Iter 84: Best Score = 182.1876
# Iter 85: Best Score = 182.1876
# Iter 86: Best Score = 182.1876
# Iter 87: Best Score = 182.1876
# Iter 88: Best Score = 182.1876
# Iter 89: Best Score = 182.1876
# Iter 90: Best Score = 182.1876
# Iter 91: Best Score = 182.1876
# Iter 92: Best Score = 182.1876
# Iter 93: Best Score = 182.1876
# Iter 94: Best Score = 182.1876
# Iter 95: Best Score = 182.1876
# Iter 96: Best Score = 182.1876
# Iter 97: Best Score = 182.1876
# Iter 98: Best Score = 182.1876
# Iter 99: Best Score = 182.1876
# Iter 100: Best Score = 182.1876
# Iter 101: Best Score = 182.1876
# Iter 102: Best Score = 182.1876
# Iter 103: Best Score = 182.1876
# Iter 104: Best Score = 182.1876
# Iter 105: Best Score = 182.1876
# Iter 106: Best Score = 182.1876
# Iter 107: Best Score = 182.1876
# Iter 108: Best Score = 182.1876
# Iter 109: Best Score = 182.1876
# Iter 110: Best Score = 182.1876
# Iter 111: Best Score = 182.1876
# Iter 112: Best Score = 182.2832
# Iter 113: Best Score = 182.2832
# Iter 114: Best Score = 182.2832
# Iter 115: Best Score = 182.2832
# Iter 116: Best Score = 183.7879
# Iter 117: Best Score = 183.7879
# Iter 118: Best Score = 184.2651
# Iter 119: Best Score = 184.2651
# Iter 120: Best Score = 184.5983
# Iter 121: Best Score = 184.5983
# Iter 122: Best Score = 184.5983
# Iter 123: Best Score = 184.5983
# Iter 124: Best Score = 185.0979
# Iter 125: Best Score = 185.0979
# Iter 126: Best Score = 185.0979
# Iter 127: Best Score = 186.8522
# Iter 128: Best Score = 186.8522
# Iter 129: Best Score = 186.8522
# Iter 130: Best Score = 186.8522
# Iter 131: Best Score = 186.8522
# Iter 132: Best Score = 186.8522
# Iter 133: Best Score = 186.8522
# Iter 134: Best Score = 186.8522
# Iter 135: Best Score = 188.271
# Iter 136: Best Score = 188.271
# Iter 137: Best Score = 188.271
# Iter 138: Best Score = 188.271
# Iter 139: Best Score = 188.271
# Iter 140: Best Score = 188.271
# Iter 141: Best Score = 188.271
# Iter 142: Best Score = 188.3049
# Iter 143: Best Score = 188.3049
# Iter 144: Best Score = 189.3738
# Iter 145: Best Score = 189.3738
# Iter 146: Best Score = 189.3738
# Iter 147: Best Score = 189.3738
# Iter 148: Best Score = 189.3738
# Iter 149: Best Score = 190.0108
# Iter 150: Best Score = 190.0108
# Iter 151: Best Score = 190.0108
# Iter 152: Best Score = 191.0661
# Iter 153: Best Score = 191.0661
# Iter 154: Best Score = 191.0661
# Iter 155: Best Score = 192.5521
# Iter 156: Best Score = 192.5521
# Iter 157: Best Score = 192.9285
# Iter 158: Best Score = 192.9285
# Iter 159: Best Score = 194.3939
# Iter 160: Best Score = 194.3939
# Iter 161: Best Score = 194.3939
# Iter 162: Best Score = 194.3939
# Iter 163: Best Score = 194.3939
# Iter 164: Best Score = 194.3939
# Iter 165: Best Score = 194.8997
# Iter 166: Best Score = 195.8079
# Iter 167: Best Score = 195.8079
# Iter 168: Best Score = 195.8079
# Iter 169: Best Score = 195.8079
# Iter 170: Best Score = 195.8079
# Iter 171: Best Score = 195.8079
# Iter 172: Best Score = 195.9704
# Iter 173: Best Score = 195.9704
# Iter 174: Best Score = 195.9704
# Iter 175: Best Score = 195.9704
# Iter 176: Best Score = 196.2379
# Iter 177: Best Score = 196.2379
# Iter 178: Best Score = 196.2379
# Iter 179: Best Score = 196.2379
# Iter 180: Best Score = 196.2379
# Iter 181: Best Score = 196.2379
# Iter 182: Best Score = 196.2379
# Iter 183: Best Score = 196.2379
# Iter 184: Best Score = 196.2379
# Iter 185: Best Score = 196.2379
# Iter 186: Best Score = 196.2379
# Iter 187: Best Score = 196.2379
# Iter 188: Best Score = 196.2379
# Iter 189: Best Score = 196.2379
# Iter 190: Best Score = 196.3455
# Iter 191: Best Score = 196.3455
# Iter 192: Best Score = 196.3455
# Iter 193: Best Score = 196.4553
# Iter 194: Best Score = 197.2351
# Iter 195: Best Score = 197.2351
# Iter 196: Best Score = 197.2351
# Iter 197: Best Score = 198.3438
# Iter 198: Best Score = 198.3438
# Iter 199: Best Score = 198.3438
# Iter 200: Best Score = 198.3438
# Iter 1: Best Score = 181.5422
# Iter 2: Best Score = 181.5422
# Iter 3: Best Score = 181.5422
# Iter 4: Best Score = 181.5422
# Iter 5: Best Score = 181.5422
# Iter 6: Best Score = 181.5422
# Iter 7: Best Score = 181.5422
# Iter 8: Best Score = 181.5422
# Iter 9: Best Score = 181.5422
# Iter 10: Best Score = 181.5422
# Iter 11: Best Score = 181.5422
# Iter 12: Best Score = 181.5422
# Iter 13: Best Score = 181.5422
# Iter 14: Best Score = 181.5422
# Iter 15: Best Score = 181.5422
# Iter 16: Best Score = 181.5422
# Iter 17: Best Score = 181.5422
# Iter 18: Best Score = 181.5422
# Iter 19: Best Score = 181.5422
# Iter 20: Best Score = 181.5422
# Iter 21: Best Score = 181.5422
# Iter 22: Best Score = 181.5422
# Iter 23: Best Score = 181.5422
# Iter 24: Best Score = 181.5422
# Iter 25: Best Score = 181.5422
# Iter 26: Best Score = 181.5422
# Iter 27: Best Score = 181.5422
# Iter 28: Best Score = 181.5422
# Iter 29: Best Score = 181.5422
# Iter 30: Best Score = 181.5422
# Iter 31: Best Score = 181.5422
# Iter 32: Best Score = 181.5422
# Iter 33: Best Score = 181.5422
# Iter 34: Best Score = 181.5422
# Iter 35: Best Score = 181.5422
# Iter 36: Best Score = 181.5422
# Iter 37: Best Score = 181.5422
# Iter 38: Best Score = 181.5422
# Iter 39: Best Score = 181.5422
# Iter 40: Best Score = 181.5422
# Iter 41: Best Score = 181.5422
# Iter 42: Best Score = 181.5422
# Iter 43: Best Score = 181.5422
# Iter 44: Best Score = 181.5422
# Iter 45: Best Score = 181.5422
# Iter 46: Best Score = 181.5422
# Iter 47: Best Score = 181.5422
# Iter 48: Best Score = 181.5422
# Iter 49: Best Score = 181.5422
# Iter 50: Best Score = 181.5422
# Iter 51: Best Score = 181.5422
# Iter 52: Best Score = 181.5422
# Iter 53: Best Score = 181.5422
# Iter 54: Best Score = 181.5422
# Iter 55: Best Score = 181.5422
# Iter 56: Best Score = 181.5422
# Iter 57: Best Score = 181.5422
# Iter 58: Best Score = 181.5422
# Iter 59: Best Score = 181.5422
# Iter 60: Best Score = 181.5422
# Iter 61: Best Score = 181.5422
# Iter 62: Best Score = 181.5422
# Iter 63: Best Score = 181.5422
# Iter 64: Best Score = 181.5422
# Iter 65: Best Score = 181.5422
# Iter 66: Best Score = 181.5422
# Iter 67: Best Score = 181.5422
# Iter 68: Best Score = 181.5422
# Iter 69: Best Score = 181.5422
# Iter 70: Best Score = 181.5422
# Iter 71: Best Score = 181.5422
# Iter 72: Best Score = 181.5422
# Iter 73: Best Score = 181.5422
# Iter 74: Best Score = 181.5422
# Iter 75: Best Score = 181.5422
# Iter 76: Best Score = 181.5422
# Iter 77: Best Score = 181.5422
# Iter 78: Best Score = 181.5422
# Iter 79: Best Score = 181.5422
# Iter 80: Best Score = 181.5422
# Iter 81: Best Score = 181.5422
# Iter 82: Best Score = 181.5422
# Iter 83: Best Score = 181.5422
# Iter 84: Best Score = 181.5422
# Iter 85: Best Score = 181.5422
# Iter 86: Best Score = 181.5422
# Iter 87: Best Score = 181.5422
# Iter 88: Best Score = 181.5422
# Iter 89: Best Score = 181.5422
# Iter 90: Best Score = 181.5422
# Iter 91: Best Score = 181.5422
# Iter 92: Best Score = 181.5422
# Iter 93: Best Score = 181.5422
# Iter 94: Best Score = 181.5422
# Iter 95: Best Score = 181.5422
# Iter 96: Best Score = 181.5422
# Iter 97: Best Score = 181.5422
# Iter 98: Best Score = 181.5422
# Iter 99: Best Score = 181.5422
# Iter 100: Best Score = 181.5422
# Iter 101: Best Score = 181.5422
# Iter 102: Best Score = 181.5422
# Iter 103: Best Score = 181.5422
# Iter 104: Best Score = 181.5422
# Iter 105: Best Score = 181.5422
# Iter 106: Best Score = 181.5422
# Iter 107: Best Score = 181.5422
# Iter 108: Best Score = 181.5422
# Iter 109: Best Score = 181.5422
# Iter 110: Best Score = 181.5422
# Iter 111: Best Score = 181.5422
# Iter 112: Best Score = 181.5422
# Iter 113: Best Score = 181.5422
# Iter 114: Best Score = 181.5422
# Iter 115: Best Score = 181.5422
# Iter 116: Best Score = 181.5422
# Iter 117: Best Score = 181.5422
# Iter 118: Best Score = 184.2777
# Iter 119: Best Score = 186.1403
# Iter 120: Best Score = 186.1403
# Iter 121: Best Score = 186.672
# Iter 122: Best Score = 186.672
# Iter 123: Best Score = 186.672
# Iter 124: Best Score = 186.672
# Iter 125: Best Score = 186.672
# Iter 126: Best Score = 186.672
# Iter 127: Best Score = 186.672
# Iter 128: Best Score = 186.672
# Iter 129: Best Score = 186.672
# Iter 130: Best Score = 188.3614
# Iter 131: Best Score = 188.3614
# Iter 132: Best Score = 188.3614
# Iter 133: Best Score = 188.3614
# Iter 134: Best Score = 188.3614
# Iter 135: Best Score = 188.3614
# Iter 136: Best Score = 188.3614
# Iter 137: Best Score = 188.3614
# Iter 138: Best Score = 189.8796
# Iter 139: Best Score = 189.8796
# Iter 140: Best Score = 191.1909
# Iter 141: Best Score = 191.1909
# Iter 142: Best Score = 191.1909
# Iter 143: Best Score = 192.1588
# Iter 144: Best Score = 192.1588
# Iter 145: Best Score = 192.1588
# Iter 146: Best Score = 192.1588
# Iter 147: Best Score = 192.1588
# Iter 148: Best Score = 192.1588
# Iter 149: Best Score = 192.1588
# Iter 150: Best Score = 192.2587
# Iter 151: Best Score = 192.2926
# Iter 152: Best Score = 192.2926
# Iter 153: Best Score = 192.2926
# Iter 154: Best Score = 192.2926
# Iter 155: Best Score = 192.2926
# Iter 156: Best Score = 192.2926
# Iter 157: Best Score = 192.2926
# Iter 158: Best Score = 192.7932
# Iter 159: Best Score = 192.7932
# Iter 160: Best Score = 192.7932
# Iter 161: Best Score = 192.7932
# Iter 162: Best Score = 193.4418
# Iter 163: Best Score = 193.7239
# Iter 164: Best Score = 193.7239
# Iter 165: Best Score = 193.7239
# Iter 166: Best Score = 193.7239
# Iter 167: Best Score = 193.7239
# Iter 168: Best Score = 193.7239
# Iter 169: Best Score = 193.7239
# Iter 170: Best Score = 193.7239
# Iter 171: Best Score = 194.6385
# Iter 172: Best Score = 194.6385
# Iter 173: Best Score = 194.6385
# Iter 174: Best Score = 194.6385
# Iter 175: Best Score = 194.6385
# Iter 176: Best Score = 194.6385
# Iter 177: Best Score = 194.6385
# Iter 178: Best Score = 195.4865
# Iter 179: Best Score = 195.4865
# Iter 180: Best Score = 195.4865
# Iter 181: Best Score = 195.4865
# Iter 182: Best Score = 195.4865
# Iter 183: Best Score = 195.4865
# Iter 184: Best Score = 195.4865
# Iter 185: Best Score = 195.4865
# Iter 186: Best Score = 195.4865
# Iter 187: Best Score = 195.4865
# Iter 188: Best Score = 195.4865
# Iter 189: Best Score = 195.4865
# Iter 190: Best Score = 195.4865
# Iter 191: Best Score = 195.4865
# Iter 192: Best Score = 195.4865
# Iter 193: Best Score = 195.4865
# Iter 194: Best Score = 195.4865
# Iter 195: Best Score = 195.4865
# Iter 196: Best Score = 195.4865
# Iter 197: Best Score = 195.4865
# Iter 198: Best Score = 195.6035
# Iter 199: Best Score = 195.6035
# Iter 200: Best Score = 195.7945
# Iter 1: Best Score = 148.4968
# Iter 2: Best Score = 149.9178
# Iter 3: Best Score = 153.8946
# Iter 4: Best Score = 153.8946
# Iter 5: Best Score = 153.8946
# Iter 6: Best Score = 153.8946
# Iter 7: Best Score = 153.8946
# Iter 8: Best Score = 153.8946
# Iter 9: Best Score = 153.8946
# Iter 10: Best Score = 153.8946
# Iter 11: Best Score = 156.0545
# Iter 12: Best Score = 156.0545
# Iter 13: Best Score = 156.0545
# Iter 14: Best Score = 156.0545
# Iter 15: Best Score = 156.9115
# Iter 16: Best Score = 157.0875
# Iter 17: Best Score = 157.0875
# Iter 18: Best Score = 157.0875
# Iter 19: Best Score = 158.6453
# Iter 20: Best Score = 158.6453
# Iter 21: Best Score = 158.6453
# Iter 22: Best Score = 158.6453
# Iter 23: Best Score = 158.6453
# Iter 24: Best Score = 158.6453
# Iter 25: Best Score = 158.6453
# Iter 26: Best Score = 158.6453
# Iter 27: Best Score = 158.6453
# Iter 28: Best Score = 158.6453
# Iter 29: Best Score = 158.6453
# Iter 30: Best Score = 158.9101
# Iter 31: Best Score = 160.4504
# Iter 32: Best Score = 160.4504
# Iter 33: Best Score = 160.4504
# Iter 34: Best Score = 161.3484
# Iter 35: Best Score = 162.7407
# Iter 36: Best Score = 164.8216
# Iter 37: Best Score = 166.0798
# Iter 38: Best Score = 166.5639
# Iter 39: Best Score = 168.9691
# Iter 40: Best Score = 168.9691
# Iter 41: Best Score = 169.0536
# Iter 42: Best Score = 169.0536
# Iter 43: Best Score = 169.0536
# Iter 44: Best Score = 169.0536
# Iter 45: Best Score = 169.0536
# Iter 46: Best Score = 169.0536
# Iter 47: Best Score = 169.0536
# Iter 48: Best Score = 169.0536
# Iter 49: Best Score = 169.0536
# Iter 50: Best Score = 169.0536
# Iter 51: Best Score = 169.0536
# Iter 52: Best Score = 169.0536
# Iter 53: Best Score = 169.0536
# Iter 54: Best Score = 169.0536
# Iter 55: Best Score = 169.0536
# Iter 56: Best Score = 169.0536
# Iter 57: Best Score = 169.0536
# Iter 58: Best Score = 169.0536
# Iter 59: Best Score = 169.0536
# Iter 60: Best Score = 169.0536
# Iter 61: Best Score = 169.0536
# Iter 62: Best Score = 169.0536
# Iter 63: Best Score = 169.0536
# Iter 64: Best Score = 170.7718
# Iter 65: Best Score = 171.1348
# Iter 66: Best Score = 173.0262
# Iter 67: Best Score = 173.7192
# Iter 68: Best Score = 173.779
# Iter 69: Best Score = 173.779
# Iter 70: Best Score = 175.3386
# Iter 71: Best Score = 175.3386
# Iter 72: Best Score = 175.3386
# Iter 73: Best Score = 175.9319
# Iter 74: Best Score = 176.1558
# Iter 75: Best Score = 177.3438
# Iter 76: Best Score = 177.3438
# Iter 77: Best Score = 177.3438
# Iter 78: Best Score = 177.3438
# Iter 79: Best Score = 177.3438
# Iter 80: Best Score = 178.6311
# Iter 81: Best Score = 178.6311
# Iter 82: Best Score = 178.6311
# Iter 83: Best Score = 178.6311
# Iter 84: Best Score = 178.6311
# Iter 85: Best Score = 178.6311
# Iter 86: Best Score = 178.6311
# Iter 87: Best Score = 178.8337
# Iter 88: Best Score = 178.8337
# Iter 89: Best Score = 178.8337
# Iter 90: Best Score = 178.8337
# Iter 91: Best Score = 178.8337
# Iter 92: Best Score = 178.8337
# Iter 93: Best Score = 182.0138
# Iter 94: Best Score = 182.0138
# Iter 95: Best Score = 182.0138
# Iter 96: Best Score = 183.3487
# Iter 97: Best Score = 183.3487
# Iter 98: Best Score = 183.3487
# Iter 99: Best Score = 183.3487
# Iter 100: Best Score = 183.3487
# Iter 101: Best Score = 183.3487
# Iter 102: Best Score = 184.4633
# Iter 103: Best Score = 184.4633
# Iter 104: Best Score = 184.8594
# Iter 105: Best Score = 187.2857
# Iter 106: Best Score = 188.2021
# Iter 107: Best Score = 188.2021
# Iter 108: Best Score = 188.2021
# Iter 109: Best Score = 188.2039
# Iter 110: Best Score = 188.2039
# Iter 111: Best Score = 188.2039
# Iter 112: Best Score = 188.2039
# Iter 113: Best Score = 188.2039
# Iter 114: Best Score = 188.2039
# Iter 115: Best Score = 188.2039
# Iter 116: Best Score = 188.2039
# Iter 117: Best Score = 188.2039
# Iter 118: Best Score = 188.2039
# Iter 119: Best Score = 188.2039
# Iter 120: Best Score = 188.2039
# Iter 121: Best Score = 188.5142
# Iter 122: Best Score = 188.5142
# Iter 123: Best Score = 188.5142
# Iter 124: Best Score = 188.5142
# Iter 125: Best Score = 188.5142
# Iter 126: Best Score = 188.5142
# Iter 127: Best Score = 188.5142
# Iter 128: Best Score = 189.752
# Iter 129: Best Score = 190.0713
# Iter 130: Best Score = 190.0713
# Iter 131: Best Score = 190.1569
# Iter 132: Best Score = 190.1569
# Iter 133: Best Score = 190.1569
# Iter 134: Best Score = 190.1569
# Iter 135: Best Score = 190.1569
# Iter 136: Best Score = 192.6166
# Iter 137: Best Score = 192.6166
# Iter 138: Best Score = 192.6166
# Iter 139: Best Score = 192.6166
# Iter 140: Best Score = 192.6166
# Iter 141: Best Score = 192.6166
# Iter 142: Best Score = 192.6166
# Iter 143: Best Score = 192.6166
# Iter 144: Best Score = 192.6166
# Iter 145: Best Score = 192.6166
# Iter 146: Best Score = 192.6166
# Iter 147: Best Score = 192.6166
# Iter 148: Best Score = 192.6166
# Iter 149: Best Score = 192.6166
# Iter 150: Best Score = 192.6166
# Iter 151: Best Score = 192.6166
# Iter 152: Best Score = 192.6166
# Iter 153: Best Score = 192.6166
# Iter 154: Best Score = 192.6166
# Iter 155: Best Score = 192.6319
# Iter 156: Best Score = 192.6319
# Iter 157: Best Score = 192.6319
# Iter 158: Best Score = 192.6319
# Iter 159: Best Score = 192.6319
# Iter 160: Best Score = 192.6319
# Iter 161: Best Score = 192.6319
# Iter 162: Best Score = 193.5917
# Iter 163: Best Score = 194.4698
# Iter 164: Best Score = 194.4698
# Iter 165: Best Score = 194.4698
# Iter 166: Best Score = 194.4698
# Iter 167: Best Score = 194.5787
# Iter 168: Best Score = 194.5787
# Iter 169: Best Score = 194.5787
# Iter 170: Best Score = 194.5787
# Iter 171: Best Score = 194.5787
# Iter 172: Best Score = 194.5787
# Iter 173: Best Score = 194.5787
# Iter 174: Best Score = 194.5787
# Iter 175: Best Score = 194.5787
# Iter 176: Best Score = 194.5787
# Iter 177: Best Score = 194.5787
# Iter 178: Best Score = 194.5787
# Iter 179: Best Score = 194.5787
# Iter 180: Best Score = 194.5787
# Iter 181: Best Score = 194.5787
# Iter 182: Best Score = 194.5787
# Iter 183: Best Score = 194.6089
# Iter 184: Best Score = 194.6089
# Iter 185: Best Score = 194.6089
# Iter 186: Best Score = 194.6089
# Iter 187: Best Score = 194.6089
# Iter 188: Best Score = 194.6089
# Iter 189: Best Score = 194.6089
# Iter 190: Best Score = 194.6089
# Iter 191: Best Score = 194.6089
# Iter 192: Best Score = 194.6089
# Iter 193: Best Score = 194.6089
# Iter 194: Best Score = 194.6089
# Iter 195: Best Score = 194.6089
# Iter 196: Best Score = 194.6089
# Iter 197: Best Score = 194.6089
# Iter 198: Best Score = 194.6089
# Iter 199: Best Score = 194.6089
# Iter 200: Best Score = 195.2349
# Iter 1: Best Score = 178.9856
# Iter 2: Best Score = 178.9856
# Iter 3: Best Score = 180.0259
# Iter 4: Best Score = 180.0259
# Iter 5: Best Score = 180.0259
# Iter 6: Best Score = 180.0259
# Iter 7: Best Score = 180.0259
# Iter 8: Best Score = 180.0259
# Iter 9: Best Score = 180.0259
# Iter 10: Best Score = 180.0259
# Iter 11: Best Score = 180.8375
# Iter 12: Best Score = 180.8375
# Iter 13: Best Score = 180.8375
# Iter 14: Best Score = 180.8375
# Iter 15: Best Score = 180.8375
# Iter 16: Best Score = 180.8375
# Iter 17: Best Score = 180.8375
# Iter 18: Best Score = 180.8375
# Iter 19: Best Score = 180.8375
# Iter 20: Best Score = 180.8375
# Iter 21: Best Score = 180.8375
# Iter 22: Best Score = 180.8375
# Iter 23: Best Score = 180.8375
# Iter 24: Best Score = 180.8375
# Iter 25: Best Score = 180.8375
# Iter 26: Best Score = 180.8375
# Iter 27: Best Score = 180.8375
# Iter 28: Best Score = 180.8375
# Iter 29: Best Score = 180.8375
# Iter 30: Best Score = 181.0504
# Iter 31: Best Score = 181.0504
# Iter 32: Best Score = 181.3021
# Iter 33: Best Score = 181.3021
# Iter 34: Best Score = 181.3021
# Iter 35: Best Score = 181.3021
# Iter 36: Best Score = 181.3021
# Iter 37: Best Score = 181.3021
# Iter 38: Best Score = 181.3021
# Iter 39: Best Score = 181.3021
# Iter 40: Best Score = 181.3021
# Iter 41: Best Score = 181.3021
# Iter 42: Best Score = 181.3021
# Iter 43: Best Score = 181.3021
# Iter 44: Best Score = 181.3021
# Iter 45: Best Score = 181.3021
# Iter 46: Best Score = 181.3021
# Iter 47: Best Score = 181.3021
# Iter 48: Best Score = 181.3021
# Iter 49: Best Score = 181.3021
# Iter 50: Best Score = 181.3021
# Iter 51: Best Score = 181.3021
# Iter 52: Best Score = 181.3021
# Iter 53: Best Score = 181.3021
# Iter 54: Best Score = 181.3021
# Iter 55: Best Score = 181.3021
# Iter 56: Best Score = 181.3021
# Iter 57: Best Score = 181.3021
# Iter 58: Best Score = 181.3021
# Iter 59: Best Score = 182.82
# Iter 60: Best Score = 183.564
# Iter 61: Best Score = 183.8513
# Iter 62: Best Score = 183.8513
# Iter 63: Best Score = 183.8513
# Iter 64: Best Score = 184.8525
# Iter 65: Best Score = 187.3819
# Iter 66: Best Score = 187.3819
# Iter 67: Best Score = 187.3819
# Iter 68: Best Score = 188.2727
# Iter 69: Best Score = 189.9887
# Iter 70: Best Score = 189.9887
# Iter 71: Best Score = 189.9887
# Iter 72: Best Score = 190.926
# Iter 73: Best Score = 190.926
# Iter 74: Best Score = 191.7795
# Iter 75: Best Score = 192.5818
# Iter 76: Best Score = 192.5818
# Iter 77: Best Score = 192.6237
# Iter 78: Best Score = 192.6237
# Iter 79: Best Score = 192.6237
# Iter 80: Best Score = 192.6237
# Iter 81: Best Score = 192.6237
# Iter 82: Best Score = 192.6237
# Iter 83: Best Score = 192.6237
# Iter 84: Best Score = 192.6237
# Iter 85: Best Score = 192.6237
# Iter 86: Best Score = 192.6237
# Iter 87: Best Score = 192.6237
# Iter 88: Best Score = 192.6237
# Iter 89: Best Score = 192.6237
# Iter 90: Best Score = 192.6237
# Iter 91: Best Score = 192.6237
# Iter 92: Best Score = 192.6237
# Iter 93: Best Score = 192.6237
# Iter 94: Best Score = 192.6237
# Iter 95: Best Score = 192.6237
# Iter 96: Best Score = 192.6237
# Iter 97: Best Score = 192.6237
# Iter 98: Best Score = 192.6237
# Iter 99: Best Score = 192.6237
# Iter 100: Best Score = 192.6237
# Iter 101: Best Score = 192.6237
# Iter 102: Best Score = 192.6237
# Iter 103: Best Score = 192.6237
# Iter 104: Best Score = 192.6237
# Iter 105: Best Score = 192.6237
# Iter 106: Best Score = 192.6237
# Iter 107: Best Score = 192.6237
# Iter 108: Best Score = 192.6237
# Iter 109: Best Score = 192.6237
# Iter 110: Best Score = 192.6237
# Iter 111: Best Score = 192.6237
# Iter 112: Best Score = 192.6237
# Iter 113: Best Score = 192.6237
# Iter 114: Best Score = 193.6895
# Iter 115: Best Score = 193.6895
# Iter 116: Best Score = 193.6895
# Iter 117: Best Score = 193.6895
# Iter 118: Best Score = 193.9831
# Iter 119: Best Score = 194.0971
# Iter 120: Best Score = 194.0971
# Iter 121: Best Score = 194.0971
# Iter 122: Best Score = 194.0971
# Iter 123: Best Score = 194.0971
# Iter 124: Best Score = 194.2648
# Iter 125: Best Score = 194.2974
# Iter 126: Best Score = 194.3997
# Iter 127: Best Score = 194.6121
# Iter 128: Best Score = 195.3772
# Iter 129: Best Score = 195.3772
# Iter 130: Best Score = 195.3772
# Iter 131: Best Score = 195.3772
# Iter 132: Best Score = 195.3772
# Iter 133: Best Score = 195.3772
# Iter 134: Best Score = 196.5605
# Iter 135: Best Score = 196.5605
# Iter 136: Best Score = 196.5605
# Iter 137: Best Score = 196.5605
# Iter 138: Best Score = 196.5605
# Iter 139: Best Score = 196.5605
# Iter 140: Best Score = 196.5605
# Iter 141: Best Score = 196.5605
# Iter 142: Best Score = 196.5605
# Iter 143: Best Score = 196.5605
# Iter 144: Best Score = 197.364
# Iter 145: Best Score = 197.364
# Iter 146: Best Score = 197.364
# Iter 147: Best Score = 197.364
# Iter 148: Best Score = 197.4205
# Iter 149: Best Score = 197.4205
# Iter 150: Best Score = 197.4205
# Iter 151: Best Score = 197.4205
# Iter 152: Best Score = 197.4205
# Iter 153: Best Score = 197.4205
# Iter 154: Best Score = 197.4205
# Iter 155: Best Score = 197.4205
# Iter 156: Best Score = 197.4205
# Iter 157: Best Score = 197.4205
# Iter 158: Best Score = 197.4205
# Iter 159: Best Score = 197.4205
# Iter 160: Best Score = 197.4205
# Iter 161: Best Score = 197.4205
# Iter 162: Best Score = 197.4205
# Iter 163: Best Score = 197.4205
# Iter 164: Best Score = 197.4205
# Iter 165: Best Score = 197.7664
# Iter 166: Best Score = 198.5259
# Iter 167: Best Score = 198.7463
# Iter 168: Best Score = 198.7463
# Iter 169: Best Score = 198.7463
# Iter 170: Best Score = 198.7463
# Iter 171: Best Score = 198.7463
# Iter 172: Best Score = 198.7463
# Iter 173: Best Score = 198.7463
# Iter 174: Best Score = 198.7463
# Iter 175: Best Score = 198.7463
# Iter 176: Best Score = 198.7463
# Iter 177: Best Score = 198.7463
# Iter 178: Best Score = 198.7463
# Iter 179: Best Score = 198.7463
# Iter 180: Best Score = 198.7463
# Iter 181: Best Score = 198.7463
# Iter 182: Best Score = 198.7463
# Iter 183: Best Score = 198.7463
# Iter 184: Best Score = 198.7463
# Iter 185: Best Score = 198.8707
# Iter 186: Best Score = 198.8707
# Iter 187: Best Score = 198.8707
# Iter 188: Best Score = 198.8707
# Iter 189: Best Score = 198.8707
# Iter 190: Best Score = 198.8707
# Iter 191: Best Score = 198.8707
# Iter 192: Best Score = 198.8707
# Iter 193: Best Score = 198.8707
# Iter 194: Best Score = 198.8707
# Iter 195: Best Score = 198.8707
# Iter 196: Best Score = 198.8707
# Iter 197: Best Score = 198.8707
# Iter 198: Best Score = 198.8707
# Iter 199: Best Score = 198.8707
# Iter 200: Best Score = 198.8707
# Iter 1: Best Score = 169.2673
# Iter 2: Best Score = 169.2673
# Iter 3: Best Score = 169.2673
# Iter 4: Best Score = 169.2673
# Iter 5: Best Score = 169.2673
# Iter 6: Best Score = 169.2673
# Iter 7: Best Score = 169.2673
# Iter 8: Best Score = 169.2673
# Iter 9: Best Score = 169.2673
# Iter 10: Best Score = 169.2673
# Iter 11: Best Score = 169.2673
# Iter 12: Best Score = 169.2673
# Iter 13: Best Score = 169.2673
# Iter 14: Best Score = 169.2673
# Iter 15: Best Score = 169.2673
# Iter 16: Best Score = 169.2673
# Iter 17: Best Score = 169.2673
# Iter 18: Best Score = 169.2673
# Iter 19: Best Score = 169.2673
# Iter 20: Best Score = 169.2673
# Iter 21: Best Score = 169.2673
# Iter 22: Best Score = 169.2673
# Iter 23: Best Score = 169.2673
# Iter 24: Best Score = 169.2673
# Iter 25: Best Score = 169.2673
# Iter 26: Best Score = 169.2673
# Iter 27: Best Score = 169.2673
# Iter 28: Best Score = 169.2673
# Iter 29: Best Score = 169.2673
# Iter 30: Best Score = 169.2673
# Iter 31: Best Score = 169.2673
# Iter 32: Best Score = 169.2673
# Iter 33: Best Score = 169.2673
# Iter 34: Best Score = 169.2673
# Iter 35: Best Score = 169.2673
# Iter 36: Best Score = 169.2673
# Iter 37: Best Score = 169.2673
# Iter 38: Best Score = 170.9844
# Iter 39: Best Score = 173.2262
# Iter 40: Best Score = 173.2262
# Iter 41: Best Score = 173.2262
# Iter 42: Best Score = 173.2262
# Iter 43: Best Score = 173.2262
# Iter 44: Best Score = 173.2262
# Iter 45: Best Score = 173.2262
# Iter 46: Best Score = 173.2262
# Iter 47: Best Score = 173.2262
# Iter 48: Best Score = 173.2262
# Iter 49: Best Score = 173.2262
# Iter 50: Best Score = 173.2262
# Iter 51: Best Score = 173.2262
# Iter 52: Best Score = 173.2262
# Iter 53: Best Score = 173.2262
# Iter 54: Best Score = 173.2262
# Iter 55: Best Score = 173.2262
# Iter 56: Best Score = 173.2262
# Iter 57: Best Score = 173.2262
# Iter 58: Best Score = 173.2262
# Iter 59: Best Score = 173.2262
# Iter 60: Best Score = 173.2262
# Iter 61: Best Score = 173.2262
# Iter 62: Best Score = 173.2262
# Iter 63: Best Score = 173.2262
# Iter 64: Best Score = 173.2262
# Iter 65: Best Score = 173.2262
# Iter 66: Best Score = 173.2262
# Iter 67: Best Score = 173.2262
# Iter 68: Best Score = 173.2262
# Iter 69: Best Score = 173.2262
# Iter 70: Best Score = 173.2262
# Iter 71: Best Score = 173.2262
# Iter 72: Best Score = 173.2262
# Iter 73: Best Score = 173.2262
# Iter 74: Best Score = 173.2262
# Iter 75: Best Score = 173.2262
# Iter 76: Best Score = 173.2262
# Iter 77: Best Score = 173.2262
# Iter 78: Best Score = 173.2262
# Iter 79: Best Score = 173.2262
# Iter 80: Best Score = 173.2262
# Iter 81: Best Score = 173.2262
# Iter 82: Best Score = 173.2262
# Iter 83: Best Score = 173.2262
# Iter 84: Best Score = 173.2262
# Iter 85: Best Score = 173.2262
# Iter 86: Best Score = 173.2262
# Iter 87: Best Score = 173.5985
# Iter 88: Best Score = 173.5985
# Iter 89: Best Score = 173.5985
# Iter 90: Best Score = 173.5985
# Iter 91: Best Score = 176.2451
# Iter 92: Best Score = 177.286
# Iter 93: Best Score = 177.286
# Iter 94: Best Score = 177.286
# Iter 95: Best Score = 177.8562
# Iter 96: Best Score = 177.8562
# Iter 97: Best Score = 177.8562
# Iter 98: Best Score = 179.6093
# Iter 99: Best Score = 180.9713
# Iter 100: Best Score = 181.1869
# Iter 101: Best Score = 181.2254
# Iter 102: Best Score = 182.39
# Iter 103: Best Score = 182.39
# Iter 104: Best Score = 182.39
# Iter 105: Best Score = 182.39
# Iter 106: Best Score = 182.39
# Iter 107: Best Score = 182.39
# Iter 108: Best Score = 182.39
# Iter 109: Best Score = 182.39
# Iter 110: Best Score = 182.39
# Iter 111: Best Score = 182.39
# Iter 112: Best Score = 182.39
# Iter 113: Best Score = 182.682
# Iter 114: Best Score = 182.682
# Iter 115: Best Score = 182.682
# Iter 116: Best Score = 183.0482
# Iter 117: Best Score = 183.0482
# Iter 118: Best Score = 184.6913
# Iter 119: Best Score = 184.6913
# Iter 120: Best Score = 184.6913
# Iter 121: Best Score = 184.6913
# Iter 122: Best Score = 185.5303
# Iter 123: Best Score = 186.3452
# Iter 124: Best Score = 186.3452
# Iter 125: Best Score = 186.6326
# Iter 126: Best Score = 186.6326
# Iter 127: Best Score = 186.6326
# Iter 128: Best Score = 187.5508
# ...
# Iter 103: Best Score = 189.0236
# Iter 104: Best Score = 189.6786
# Iter 105: Best Score = 189.6786
# Iter 106: Best Score = 189.6786
# Iter 107: Best Score = 190.3131
# Iter 108: Best Score = 190.3131
# Iter 109: Best Score = 190.3131
# Iter 110: Best Score = 190.3131
# Iter 111: Best Score = 190.3131
# Iter 112: Best Score = 190.3131
# Iter 113: Best Score = 190.3131
# Iter 114: Best Score = 191.7594
# Iter 115: Best Score = 192.4272
# Iter 116: Best Score = 192.4272
# Iter 117: Best Score = 192.4272
# Iter 118: Best Score = 192.4272
# Iter 119: Best Score = 192.4272
# Iter 120: Best Score = 192.4272
# Iter 121: Best Score = 192.4272
# Iter 122: Best Score = 193.2935
# Iter 123: Best Score = 193.2935
# Iter 124: Best Score = 193.2935
# Iter 125: Best Score = 193.2935
# Iter 126: Best Score = 193.5002
# Iter 127: Best Score = 193.5002
# Iter 128: Best Score = 193.5002
# Iter 129: Best Score = 193.5002
# Iter 130: Best Score = 193.5002
# Iter 131: Best Score = 193.5002
# Iter 132: Best Score = 193.5002
# Iter 133: Best Score = 193.5002
# Iter 134: Best Score = 194.054
# Iter 135: Best Score = 194.054
# Iter 136: Best Score = 194.054
# Iter 137: Best Score = 195.343
# Iter 138: Best Score = 195.343
# Iter 139: Best Score = 195.343
# Iter 140: Best Score = 195.343
# Iter 141: Best Score = 195.343
# Iter 142: Best Score = 195.343
# Iter 143: Best Score = 195.343
# Iter 144: Best Score = 195.343
# Iter 145: Best Score = 195.343
# Iter 146: Best Score = 195.343
# Iter 147: Best Score = 195.343
# Iter 148: Best Score = 195.343
# Iter 149: Best Score = 195.343
# Iter 150: Best Score = 195.347
# Iter 151: Best Score = 195.347
# Iter 152: Best Score = 195.347
# Iter 153: Best Score = 195.347
# Iter 154: Best Score = 195.347
# Iter 155: Best Score = 195.347
# Iter 156: Best Score = 195.347
# Iter 157: Best Score = 195.347
# Iter 158: Best Score = 195.347
# Iter 159: Best Score = 195.347
# Iter 160: Best Score = 196.2141
# Iter 161: Best Score = 196.2141
# Iter 162: Best Score = 196.2141
# Iter 163: Best Score = 196.7898
# Iter 164: Best Score = 196.7898
# Iter 165: Best Score = 196.7898
# Iter 166: Best Score = 196.7898
# Iter 167: Best Score = 196.7898
# Iter 168: Best Score = 196.7898
# Iter 169: Best Score = 196.7898
# Iter 170: Best Score = 196.7898
# Iter 171: Best Score = 196.7898
# Iter 172: Best Score = 196.7898
# Iter 173: Best Score = 196.7898
# Iter 174: Best Score = 196.7898
# Iter 175: Best Score = 196.7898
# Iter 176: Best Score = 196.7898
# Iter 177: Best Score = 196.7898
# Iter 178: Best Score = 196.7898
# Iter 179: Best Score = 196.9347
# Iter 180: Best Score = 196.9347
# Iter 181: Best Score = 196.9347
# Iter 182: Best Score = 196.9347
# Iter 183: Best Score = 196.9347
# Iter 184: Best Score = 196.9347
# Iter 185: Best Score = 196.9347
# Iter 186: Best Score = 196.9347
# Iter 187: Best Score = 196.9347
# Iter 188: Best Score = 196.9347
# Iter 189: Best Score = 196.9347
# Iter 190: Best Score = 196.9347
# Iter 191: Best Score = 196.9347
# Iter 192: Best Score = 196.9347
# Iter 193: Best Score = 196.9347
# Iter 194: Best Score = 196.9347
# Iter 195: Best Score = 196.9347
# Iter 196: Best Score = 196.9347
# Iter 197: Best Score = 196.9347
# Iter 198: Best Score = 196.9347
# Iter 199: Best Score = 196.9347
# Iter 200: Best Score = 196.9347
# Iter 1: Best Score = 174.9328
# Iter 2: Best Score = 174.9328
# Iter 3: Best Score = 176.2039
# Iter 4: Best Score = 176.2039
# Iter 5: Best Score = 176.2039
# Iter 6: Best Score = 176.2039
# Iter 7: Best Score = 177.3585
# Iter 8: Best Score = 177.8375
# Iter 9: Best Score = 177.8375
# Iter 10: Best Score = 179.3979
# Iter 11: Best Score = 180.6151
# Iter 12: Best Score = 182.2599
# Iter 13: Best Score = 182.2599
# Iter 14: Best Score = 182.2599
# Iter 15: Best Score = 182.2599
# Iter 16: Best Score = 182.2599
# Iter 17: Best Score = 182.2599
# Iter 18: Best Score = 182.2599
# Iter 19: Best Score = 182.2599
# Iter 20: Best Score = 182.2599
# Iter 21: Best Score = 182.2599
# Iter 22: Best Score = 182.2599
# Iter 23: Best Score = 182.2599
# Iter 24: Best Score = 182.2599
# Iter 25: Best Score = 182.2599
# Iter 26: Best Score = 182.2599
# Iter 27: Best Score = 182.2599
# Iter 28: Best Score = 182.2599
# Iter 29: Best Score = 182.2599
# Iter 30: Best Score = 182.2599
# Iter 31: Best Score = 182.2599
# Iter 32: Best Score = 182.2599
# Iter 33: Best Score = 182.2599
# Iter 34: Best Score = 182.2599
# Iter 35: Best Score = 182.2599
# Iter 36: Best Score = 182.2599
# Iter 37: Best Score = 182.2599
# Iter 38: Best Score = 182.2599
# Iter 39: Best Score = 182.2599
# Iter 40: Best Score = 182.2599
# Iter 41: Best Score = 182.2599
# Iter 42: Best Score = 182.2599
# Iter 43: Best Score = 182.2599
# Iter 44: Best Score = 182.2599
# Iter 45: Best Score = 182.2599
# Iter 46: Best Score = 182.2599
# Iter 47: Best Score = 182.2599
# Iter 48: Best Score = 182.2599
# Iter 49: Best Score = 182.2599
# Iter 50: Best Score = 182.77
# Iter 51: Best Score = 183.1716
# Iter 52: Best Score = 183.1716
# Iter 53: Best Score = 183.1716
# Iter 54: Best Score = 183.1716
# Iter 55: Best Score = 183.1716
# Iter 56: Best Score = 183.1716
# Iter 57: Best Score = 183.1716
# Iter 58: Best Score = 183.1716
# Iter 59: Best Score = 183.1716
# Iter 60: Best Score = 183.1716
# Iter 61: Best Score = 183.1716
# Iter 62: Best Score = 183.1716
# Iter 63: Best Score = 183.1716
# Iter 64: Best Score = 183.1716
# Iter 65: Best Score = 183.1716
# Iter 66: Best Score = 183.1716
# Iter 67: Best Score = 183.1716
# Iter 68: Best Score = 183.1716
# Iter 69: Best Score = 183.1716
# Iter 70: Best Score = 183.1716
# Iter 71: Best Score = 183.1716
# Iter 72: Best Score = 183.1716
# Iter 73: Best Score = 183.1716
# Iter 74: Best Score = 183.1716
# Iter 75: Best Score = 183.1716
# Iter 76: Best Score = 183.1716
# Iter 77: Best Score = 183.1716
# Iter 78: Best Score = 183.1716
# Iter 79: Best Score = 183.1716
# Iter 80: Best Score = 183.1716
# Iter 81: Best Score = 183.1716
# Iter 82: Best Score = 183.1716
# Iter 83: Best Score = 183.1716
# Iter 84: Best Score = 183.1716
# Iter 85: Best Score = 183.1716
# Iter 86: Best Score = 183.1716
# Iter 87: Best Score = 183.1716
# Iter 88: Best Score = 183.1716
# Iter 89: Best Score = 183.1716
# Iter 90: Best Score = 183.1716
# Iter 91: Best Score = 183.67
# Iter 92: Best Score = 184.8553
# Iter 93: Best Score = 184.8553
# Iter 94: Best Score = 184.8553
# Iter 95: Best Score = 184.8553
# Iter 96: Best Score = 184.8553
# Iter 97: Best Score = 184.8553
# Iter 98: Best Score = 184.8553
# Iter 99: Best Score = 187.1095
# Iter 100: Best Score = 188.7942
# Iter 101: Best Score = 188.7942
# Iter 102: Best Score = 188.7942
# Iter 103: Best Score = 188.7942
# Iter 104: Best Score = 189.4848
# Iter 105: Best Score = 189.4848
# Iter 106: Best Score = 189.9223
# Iter 107: Best Score = 189.9223
# Iter 108: Best Score = 189.9223
# Iter 109: Best Score = 190.9371
# Iter 110: Best Score = 190.9371
# Iter 111: Best Score = 190.9371
# Iter 112: Best Score = 190.9371
# Iter 113: Best Score = 190.9371
# Iter 114: Best Score = 191.5029
# Iter 115: Best Score = 191.5029
# Iter 116: Best Score = 191.5029
# Iter 117: Best Score = 191.5029
# Iter 118: Best Score = 191.5029
# Iter 119: Best Score = 192.5274
# Iter 120: Best Score = 192.5274
# Iter 121: Best Score = 192.623
# Iter 122: Best Score = 192.623
# Iter 123: Best Score = 192.623
# Iter 124: Best Score = 192.623
# Iter 125: Best Score = 192.7447
# Iter 126: Best Score = 193.8212
# Iter 127: Best Score = 193.8212
# Iter 128: Best Score = 193.8212
# Iter 129: Best Score = 193.8212
# Iter 130: Best Score = 193.8212
# Iter 131: Best Score = 193.8212
# Iter 132: Best Score = 193.8212
# Iter 133: Best Score = 193.8212
# Iter 134: Best Score = 193.8212
# Iter 135: Best Score = 194.7302
# Iter 136: Best Score = 194.7302
# Iter 137: Best Score = 194.7302
# Iter 138: Best Score = 194.7302
# Iter 139: Best Score = 194.7302
# Iter 140: Best Score = 195.5143
# Iter 141: Best Score = 195.5143
# Iter 142: Best Score = 195.6395
# Iter 143: Best Score = 195.6395
# Iter 144: Best Score = 195.8108
# Iter 145: Best Score = 195.8108
# Iter 146: Best Score = 195.8108
# Iter 147: Best Score = 197.341
# Iter 148: Best Score = 197.341
# Iter 149: Best Score = 197.4274
# Iter 150: Best Score = 197.4274
# Iter 151: Best Score = 197.4274
# Iter 152: Best Score = 197.4274
# Iter 153: Best Score = 197.4274
# Iter 154: Best Score = 197.4274
# Iter 155: Best Score = 197.4274
# Iter 156: Best Score = 197.4274
# Iter 157: Best Score = 197.5315
# Iter 158: Best Score = 197.5315
# Iter 159: Best Score = 197.5315
# Iter 160: Best Score = 197.5315
# Iter 161: Best Score = 198.6494
# Iter 162: Best Score = 198.6494
# Iter 163: Best Score = 198.6494
# Iter 164: Best Score = 198.9868
# Iter 165: Best Score = 198.9868
# Iter 166: Best Score = 198.9868
# Iter 167: Best Score = 198.9868
# Iter 168: Best Score = 198.9868
# Iter 169: Best Score = 198.9868
# Iter 170: Best Score = 198.9868
# Iter 171: Best Score = 198.9868
# Iter 172: Best Score = 198.9868
# Iter 173: Best Score = 198.9868
# Iter 174: Best Score = 198.9868
# Iter 175: Best Score = 198.9868
# Iter 176: Best Score = 198.9868
# Iter 177: Best Score = 198.9868
# Iter 178: Best Score = 198.9868
# Iter 179: Best Score = 198.9868
# Iter 180: Best Score = 199.4352
# Iter 181: Best Score = 199.4352
# Iter 182: Best Score = 199.4352
# Iter 183: Best Score = 199.4352
# Iter 184: Best Score = 199.4352
# Iter 185: Best Score = 199.4352
# Iter 186: Best Score = 199.4352
# Iter 187: Best Score = 199.4352
# Iter 188: Best Score = 199.4352
# Iter 189: Best Score = 199.4352
# Iter 190: Best Score = 199.4352
# Iter 191: Best Score = 199.4352
# Iter 192: Best Score = 199.4352
# Iter 193: Best Score = 199.5181
# Iter 194: Best Score = 199.5181
# Iter 195: Best Score = 199.5181
# Iter 196: Best Score = 199.5181
# Iter 197: Best Score = 199.5181
# Iter 198: Best Score = 199.5181
# Iter 199: Best Score = 199.5181
# Iter 200: Best Score = 199.5181
# Iter 1: Best Score = 187.9787
# Iter 2: Best Score = 187.9787
# Iter 3: Best Score = 187.9787
# Iter 4: Best Score = 187.9787
# Iter 5: Best Score = 187.9787
# Iter 6: Best Score = 187.9787
# Iter 7: Best Score = 187.9787
# Iter 8: Best Score = 187.9787
# Iter 9: Best Score = 187.9787
# Iter 10: Best Score = 187.9787
# Iter 11: Best Score = 187.9787
# Iter 12: Best Score = 187.9787
# Iter 13: Best Score = 187.9787
# Iter 14: Best Score = 187.9787
# Iter 15: Best Score = 187.9787
# Iter 16: Best Score = 187.9787
# Iter 17: Best Score = 187.9787
# Iter 18: Best Score = 187.9787
# Iter 19: Best Score = 187.9787
# Iter 20: Best Score = 187.9787
# Iter 21: Best Score = 187.9787
# Iter 22: Best Score = 187.9787
# Iter 23: Best Score = 187.9787
# Iter 24: Best Score = 187.9787
# Iter 25: Best Score = 187.9787
# Iter 26: Best Score = 187.9787
# Iter 27: Best Score = 187.9787
# Iter 28: Best Score = 187.9787
# Iter 29: Best Score = 187.9787
# Iter 30: Best Score = 187.9787
# Iter 31: Best Score = 187.9787
# Iter 32: Best Score = 187.9787
# Iter 33: Best Score = 187.9787
# Iter 34: Best Score = 187.9787
# Iter 35: Best Score = 187.9787
# Iter 36: Best Score = 187.9787
# Iter 37: Best Score = 187.9787
# Iter 38: Best Score = 187.9787
# Iter 39: Best Score = 187.9787
# Iter 40: Best Score = 187.9787
# Iter 41: Best Score = 187.9787
# Iter 42: Best Score = 187.9787
# Iter 43: Best Score = 187.9787
# Iter 44: Best Score = 187.9787
# Iter 45: Best Score = 187.9787
# Iter 46: Best Score = 187.9787
# Iter 47: Best Score = 187.9787
# Iter 48: Best Score = 187.9787
# Iter 49: Best Score = 187.9787
# Iter 50: Best Score = 187.9787
# Iter 51: Best Score = 187.9787
# Iter 52: Best Score = 187.9787
# Iter 53: Best Score = 187.9787
# Iter 54: Best Score = 187.9787
# Iter 55: Best Score = 187.9787
# Iter 56: Best Score = 187.9787
# Iter 57: Best Score = 187.9787
# Iter 58: Best Score = 187.9787
# Iter 59: Best Score = 187.9787
# Iter 60: Best Score = 187.9787
# Iter 61: Best Score = 187.9787
# Iter 62: Best Score = 187.9787
# Iter 63: Best Score = 187.9787
# Iter 64: Best Score = 187.9787
# Iter 65: Best Score = 187.9787
# Iter 66: Best Score = 187.9787
# Iter 67: Best Score = 187.9787
# Iter 68: Best Score = 187.9787
# Iter 69: Best Score = 187.9787
# Iter 70: Best Score = 187.9787
# Iter 71: Best Score = 187.9787
# Iter 72: Best Score = 187.9787
# Iter 73: Best Score = 187.9787
# Iter 74: Best Score = 187.9787
# Iter 75: Best Score = 187.9787
# Iter 76: Best Score = 187.9787
# Iter 77: Best Score = 187.9787
# Iter 78: Best Score = 187.9787
# Iter 79: Best Score = 187.9787
# Iter 80: Best Score = 187.9787
# Iter 81: Best Score = 187.9787
# Iter 82: Best Score = 187.9787
# Iter 83: Best Score = 187.9787
# Iter 84: Best Score = 187.9787
# Iter 85: Best Score = 187.9787
# Iter 86: Best Score = 187.9787
# Iter 87: Best Score = 187.9787
# Iter 88: Best Score = 187.9787
# Iter 89: Best Score = 187.9787
# Iter 90: Best Score = 187.9787
# Iter 91: Best Score = 187.9787
# Iter 92: Best Score = 187.9787
# Iter 93: Best Score = 187.9787
# Iter 94: Best Score = 187.9787
# Iter 95: Best Score = 188.0648
# Iter 96: Best Score = 188.8743
# Iter 97: Best Score = 188.8743
# Iter 98: Best Score = 189.3333
# Iter 99: Best Score = 191.5879
# Iter 100: Best Score = 191.5879
# Iter 101: Best Score = 191.5879
# Iter 102: Best Score = 191.7086
# Iter 103: Best Score = 191.7086
# Iter 104: Best Score = 191.7086
# Iter 105: Best Score = 191.8237
# Iter 106: Best Score = 191.8237
# Iter 107: Best Score = 191.8237
# Iter 108: Best Score = 191.8237
# Iter 109: Best Score = 191.871
# Iter 110: Best Score = 191.871
# Iter 111: Best Score = 191.871
# Iter 112: Best Score = 191.871
# Iter 113: Best Score = 191.871
# Iter 114: Best Score = 191.871
# Iter 115: Best Score = 191.9379
# Iter 116: Best Score = 191.9379
# Iter 117: Best Score = 193.5618
# Iter 118: Best Score = 193.5618
# Iter 119: Best Score = 193.5618
# Iter 120: Best Score = 193.5618
# Iter 121: Best Score = 193.5618
# Iter 122: Best Score = 193.5618
# Iter 123: Best Score = 193.5618
# Iter 124: Best Score = 193.5618
# Iter 125: Best Score = 193.5618
# Iter 126: Best Score = 194.4027
# Iter 127: Best Score = 194.4027
# Iter 128: Best Score = 194.4027
# Iter 129: Best Score = 194.4027
# Iter 130: Best Score = 194.4027
# Iter 131: Best Score = 195.2115
# Iter 132: Best Score = 195.2115
# Iter 133: Best Score = 195.2115
# Iter 134: Best Score = 195.2115
# Iter 135: Best Score = 195.3808
# Iter 136: Best Score = 196.5052
# Iter 137: Best Score = 196.5052
# Iter 138: Best Score = 196.9834
# Iter 139: Best Score = 196.9834
# Iter 140: Best Score = 196.9834
# Iter 141: Best Score = 197.2273
# Iter 142: Best Score = 197.2273
# Iter 143: Best Score = 197.2273
# Iter 144: Best Score = 197.2273
# Iter 145: Best Score = 197.2273
# Iter 146: Best Score = 197.2273
# Iter 147: Best Score = 197.2273
# Iter 148: Best Score = 197.591
# Iter 149: Best Score = 197.9817
# Iter 150: Best Score = 197.9817
# Iter 151: Best Score = 197.9817
# Iter 152: Best Score = 198.2801
# Iter 153: Best Score = 198.2801
# Iter 154: Best Score = 198.2801
# Iter 155: Best Score = 198.2801
# Iter 156: Best Score = 198.2801
# Iter 157: Best Score = 198.2801
# Iter 158: Best Score = 198.2801
# Iter 159: Best Score = 198.2801
# Iter 160: Best Score = 198.2801
# Iter 161: Best Score = 198.2801
# Iter 162: Best Score = 198.2801
# Iter 163: Best Score = 198.2801
# Iter 164: Best Score = 198.2801
# Iter 165: Best Score = 198.2801
# Iter 166: Best Score = 198.2801
# Iter 167: Best Score = 198.2801
# Iter 168: Best Score = 198.2801
# Iter 169: Best Score = 198.2801
# Iter 170: Best Score = 198.2801
# Iter 171: Best Score = 198.4995
# Iter 172: Best Score = 198.4995
# Iter 173: Best Score = 198.4995
# Iter 174: Best Score = 198.4995
# Iter 175: Best Score = 198.4995
# Iter 176: Best Score = 198.4995
# Iter 177: Best Score = 198.4995
# Iter 178: Best Score = 198.4995
# Iter 179: Best Score = 198.8773
# Iter 180: Best Score = 198.8895
# Iter 181: Best Score = 198.8895
# Iter 182: Best Score = 198.8895
# Iter 183: Best Score = 198.8895
# Iter 184: Best Score = 198.8895
# Iter 185: Best Score = 198.8895
# Iter 186: Best Score = 198.8895
# Iter 187: Best Score = 198.8895
# Iter 188: Best Score = 198.8895
# Iter 189: Best Score = 198.8895
# Iter 190: Best Score = 198.8895
# Iter 191: Best Score = 199.4501
# Iter 192: Best Score = 199.4501
# Iter 193: Best Score = 199.4501
# Iter 194: Best Score = 199.4501
# Iter 195: Best Score = 199.4501
# Iter 196: Best Score = 199.4501
# Iter 197: Best Score = 199.4501
# Iter 198: Best Score = 199.4501
# Iter 199: Best Score = 199.4501
# Iter 200: Best Score = 199.4501
# Valid solutions: 100/100 (100.00%)
# Mean fitness: 197.8053
# Std deviation of fitness: 1.3517
# Mean computation time: 0.4482 seconds
# Std deviation of time: 0.0227 seconds
# (np.float64(197.80531259780295),
#  np.float64(1.3517417882363156),
#  np.float64(0.44821456432342527),
#  np.float64(0.022662248246207016))
